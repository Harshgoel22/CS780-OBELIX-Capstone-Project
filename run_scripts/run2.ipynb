# %%
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: numpy in c:\users\hgoel\anaconda3\envs\torch_new\lib\site-packages (from -r ../requirements.txt (line 1)) (2.2.6)
# Collecting opencv-python (from -r ../requirements.txt (line 2))
#   Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.13.0.92

# %%
import sys
sys.path.append("..")
from obelix import OBELIX
from algorithms.ddqn_agent2 import DDQN
from configurations.config_p1_sub2 import config
# Out:
# device used:  cuda

# %%
env = OBELIX(
    scaling_factor=5,
    arena_size=500,
    max_steps=1000,
    wall_obstacles=False,
    difficulty=0,
    box_speed=2
)
ddqnAgent = DDQN(env, config)

# %%
ddqnTrainRewardsList1, ddqnTrainTimeList1, ddqnEvalRewardsList1, ddqnWallClockTimeList1, ddqnTotalStepsList1, ddqnFinalEvalReward1 = ddqnAgent.runDDQN()
# Out:
# Episode 0: TR -49840.0 | ER -12125.0 | TT 20.28982901573181 | WC 37.5295033454895 | TS 1000
# Episode 1: TR -15368.0 | ER -12528.0 | TT 55.84640622138977 | WC 69.96139764785767 | TS 1000
# Episode 2: TR 66609.0 | ER -206851.0 | TT 84.67552161216736 | WC 99.49717020988464 | TS 1000
# Episode 3: TR -17576.0 | ER -18000.0 | TT 113.76338362693787 | WC 128.15025520324707 | TS 1000
# Episode 4: TR -14995.0 | ER -18000.0 | TT 140.84583163261414 | WC 154.19718098640442 | TS 1000
# Episode 5: TR 18835.0 | ER -16500.0 | TT 160.10596585273743 | WC 173.32352805137634 | TS 413
# Episode 6: TR -20698.0 | ER -18000.0 | TT 186.5675985813141 | WC 208.51524019241333 | TS 1000
# Episode 7: TR -51672.0 | ER -12500.0 | TT 228.90361046791077 | WC 249.25738382339478 | TS 1000
# Episode 8: TR -14552.0 | ER -18000.0 | TT 269.57836151123047 | WC 290.3552255630493 | TS 1000
# Episode 9: TR -40487.0 | ER -18000.0 | TT 311.09800720214844 | WC 331.906042098999 | TS 1000
# Episode 10: TR -54616.0 | ER -18000.0 | TT 353.4913430213928 | WC 375.8737585544586 | TS 1000
# Episode 11: TR -25051.0 | ER -13125.0 | TT 396.6120545864105 | WC 414.6411590576172 | TS 1000
# Episode 12: TR -25562.0 | ER -18000.0 | TT 433.01252603530884 | WC 451.2515113353729 | TS 1000
# Episode 13: TR -17170.0 | ER -13413.0 | TT 469.5257692337036 | WC 487.5112862586975 | TS 1000
# Episode 14: TR -16390.0 | ER -18000.0 | TT 505.7256500720978 | WC 523.7531626224518 | TS 1000
# Episode 15: TR -51432.0 | ER -15762.0 | TT 542.1000940799713 | WC 560.3969399929047 | TS 1000
# Episode 16: TR -7175.0 | ER -15000.0 | TT 573.5180594921112 | WC 587.7979397773743 | TS 732
# Episode 17: TR -18000.0 | ER -18000.0 | TT 600.4529342651367 | WC 613.6037547588348 | TS 1000
# Episode 18: TR -39094.0 | ER -18000.0 | TT 626.3561325073242 | WC 639.0206515789032 | TS 1000
# Episode 19: TR -52825.0 | ER -18000.0 | TT 651.630044221878 | WC 664.6572813987732 | TS 1000
# Episode 20: TR -20786.0 | ER -18000.0 | TT 676.9741554260254 | WC 690.733077287674 | TS 1000
# Episode 49: TR -17936.0 | ER -18000.0 | TT 1593.1432826519012 | WC 1617.426828622818 | TS 1000
# Episode 50: TR 79601.0 | ER -207448.0 | TT 1637.948251247406 | WC 1656.0820605754852 | TS 1000
# Episode 51: TR -58653.0 | ER -12500.0 | TT 1676.3588962554932 | WC 1697.7644159793854 | TS 1000
# Episode 52: TR -41880.0 | ER -13086.0 | TT 1718.8472619056702 | WC 1739.2121860980988 | TS 1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 ddqnTrainRewardsList1, ddqnTrainTimeList1, ddqnEvalRewardsList1, ddqnWallClockTimeList1, ddqnTotalStepsList1, ddqnFinalEvalReward1 = ddqnAgent.runDDQN()
#
# File c:\Users\hgoel\MTech_Resources\DRL\Capstone_Project\CS780-OBELIX\run_scripts\..\algorithms\ddqn_agent2.py:109, in DDQN.runDDQN(self)
#      98 def runDDQN(self):
#      99     #this is the main method, it trains the agent, performs bookkeeping while training and finally evaluates
#     100     #the agent and returns the following quantities:
#    (...)
#     107
#     108     #Your code goes in here
# --> 109     trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, totalStepsList = self.trainAgent()
#     110     finalEvalReward = self.evaluateAgent()
#     111     return trainRewardsList, trainTimeList, evalRewardsList, wallClockTimeList, totalStepsList, finalEvalReward
#
# File c:\Users\hgoel\MTech_Resources\DRL\Capstone_Project\CS780-OBELIX\run_scripts\..\algorithms\ddqn_agent2.py:134, in DDQN.trainAgent(self)
#     131 action = self.explorationStrategyTrainFn(self.nnOnline, state, self.epsilons[episode])
#     133 # observed the new experience by taking one step in the env
# --> 134 next_state, reward, done = self.env.step(self.actions[action], render=False)
#     136 # each experience holds the info of curr_state, action_taken, next_state, reward_got, whether_terminated
#     137 experience = (state, action, reward, next_state, done)
#
# File c:\Users\hgoel\MTech_Resources\DRL\Capstone_Project\CS780-OBELIX\run_scripts\..\obelix.py:671, in OBELIX.step(self, move, render)
#     668         self.active_state = "U"
#     670 self._update_frames(show=render)
# --> 671 self.get_feedback()
#     672 self.update_reward()
#     673 self.check_done_state()
#
# File c:\Users\hgoel\MTech_Resources\DRL\Capstone_Project\CS780-OBELIX\run_scripts\..\obelix.py:583, in OBELIX.get_feedback(self)
#     577 for i in range(self.sensor_feedback_masks.shape[0]):
#     578     self.sensor_feedback[2 * i] = np.any(
#     579         (self.sensor_feedback_masks[i] + combined_object_frame[:, :, 0]) == 150
#     580     ) or np.any(
#     581         (self.sensor_feedback_masks[i] + self.neg_circle_frame[:, :, 0]) == 150
#     582     )
# --> 583     self.sensor_feedback[2 * i + 1] = np.any(
#     584         (self.sensor_feedback_masks[i] + combined_object_frame[:, :, 0]) == 200
#     585     ) or np.any(
#     586         (self.sensor_feedback_masks[i] + self.neg_circle_frame[:, :, 0]) == 200
#     587     )
#     588 self.sensor_feedback[17] = self.stuck_flag
#
# File c:\Users\hgoel\anaconda3\envs\torch_new\lib\site-packages\numpy\_core\fromnumeric.py:2472, in _any_dispatcher(a, axis, out, keepdims, where)
#    2464         return res
#    2466     return _wrapreduction(
#    2467         a, np.add, 'sum', axis, dtype, out,
#    2468         keepdims=keepdims, initial=initial, where=where
#    2469     )
# -> 2472 def _any_dispatcher(a, axis=None, out=None, keepdims=None, *,
#    2473                     where=np._NoValue):
#    2474     return (a, where, out)
#    2477 @array_function_dispatch(_any_dispatcher)
#    2478 def any(a, axis=None, out=None, keepdims=np._NoValue, *, where=np._NoValue):
#
# KeyboardInterrupt:
