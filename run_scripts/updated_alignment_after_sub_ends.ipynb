# %%
# %pip install numpy opencv-python torch matplotlib scipy
import numpy as np
import cv2
import torch
import torch.nn as nn
import torch.nn.functional as F
import random  
import time    
import os      
import matplotlib.pyplot as plt
from scipy.ndimage import uniform_filter1d
from collections import deque

from obelix import OBELIX # Environment class needs to be present in the same folder named obelix
# Out:
# Requirement already satisfied: numpy in c:\users\hgoel\anaconda3\lib\site-packages (2.2.6)
# Requirement already satisfied: opencv-python in c:\users\hgoel\anaconda3\lib\site-packages (4.12.0.88)
# Requirement already satisfied: torch in c:\users\hgoel\anaconda3\lib\site-packages (2.12.0.dev20260306+cu128)
# Requirement already satisfied: matplotlib in c:\users\hgoel\anaconda3\lib\site-packages (3.10.6)
# Requirement already satisfied: scipy in c:\users\hgoel\anaconda3\lib\site-packages (1.17.0)
# Requirement already satisfied: filelock in c:\users\hgoel\anaconda3\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\hgoel\anaconda3\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\users\hgoel\anaconda3\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\hgoel\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\hgoel\anaconda3\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\hgoel\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\hgoel\anaconda3\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hgoel\anaconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hgoel\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hgoel\anaconda3\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hgoel\anaconda3\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\hgoel\anaconda3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\hgoel\anaconda3\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hgoel\anaconda3\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hgoel\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hgoel\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hgoel\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hgoel\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Helper Functions

# %%
def decayEpsilon(epsilon, decay_strategy, max_episodes):
    """
    Returns a numpy array of epsilon values per episode according to a decay strategy.

    decay_strategy: list of tuples (decay_type, decay_val)
        decay_val = {'s': start_episode, 'e': end_episode, 'ival': initial_value, 'fval': final_value}
    """
    epsilons = np.zeros(max_episodes, dtype=np.float32)
    next_decay_episode = 0

    for decay_type, decay_val in decay_strategy:
        s = decay_val['s']
        e = decay_val['e']

        # Fill gaps before this decay segment
        if next_decay_episode < s:
            epsilons[next_decay_episode:s] = decay_val.get('ival', epsilon)

        # Length of current decay segment
        length = e - s + 1
        length = min(length, len(epsilons) - s)  # avoid overshooting

        if decay_type == "linear":
            start_val = decay_val['ival']
            end_val = decay_val['fval']
            epsilons[s:s+length] = np.linspace(start_val, end_val, num=length, dtype=np.float32)

        elif decay_type == "exponential":
            start_val = decay_val['ival']
            end_val = decay_val['fval']
            # decay rate
            decay_rate = np.log(end_val / start_val) / (length - 1)
            epsilons[s:s+length] = start_val * np.exp(decay_rate * np.arange(length))

        else:
            # constant value
            epsilons[s:s+length] = decay_val.get('ival', epsilon)

        next_decay_episode = e + 1

    # Fill remaining episodes if any
    if next_decay_episode < max_episodes:
        epsilons[next_decay_episode:] = decay_val.get('fval', epsilon)

    return epsilons

# %%
def huberLoss(error, delta, weights=None, norm=False):
    #this function calculates the huber loss for the error using the delta parameter

    #Your code goes in here
    abs_error = torch.abs(error)
    quadratic = torch.clamp(abs_error, max=delta)
    linear = abs_error - quadratic

    loss = 0.5 * quadratic**2 + delta * linear

    if weights is None:
        hLoss = torch.mean(loss)
    elif not norm:
        hLoss = torch.mean(weights * loss)
    else:
        hLoss = weights * loss
        hLoss = hLoss.sum() / weights.sum()
    return hLoss

# %% [markdown]
# ### Action Selection Logic

# %%
def selectGreedyActionREP_COMP(net, state, **kwargs):
    device = next(net.parameters()).device

    if not isinstance(state, torch.Tensor):
        state = torch.FloatTensor(state).to(device)
    if state.ndim == 1:
        state = state.unsqueeze(0)  # [1, state_dim]

    with torch.no_grad():
        q_values, _, _, hx, cx = net(state, kwargs['hx'], kwargs['cx'])

    # selecting action with highest q value
    greedyAction = torch.argmax(q_values, dim=1).item()

    return greedyAction, hx, cx


def selectEpsilonGreedyActionREP_NOISY(net, state, epsilon, **kwargs):
    device = next(net.parameters()).device

    if not isinstance(state, torch.Tensor):
        state = torch.FloatTensor(state).to(device)
    if state.ndim == 1:
        state = state.unsqueeze(0)
    
    with torch.no_grad():
        q_values, _, _, hx, cx = net(state, kwargs['hx'], kwargs['cx'])
        
    q_values = q_values.squeeze(0)
    
    # actions = ["L45", "L22", "FW", "R22", "R45"]
    prob_dist = torch.tensor([0.15, 0.15, 0.40, 0.15, 0.15], device=device)
   
    # noisy exploration
    if np.random.rand() >= epsilon:
        # here, i have planned to use noisy exploration-exploitation initially it promotes exploration later as noise_std
        # decays it switches to exploiting the action learnt.
        noise_std = kwargs.get('noise_std', 0.2)
        episode = kwargs.get('episode', 0)
        max_episodes = kwargs.get('max_episodes', 800)

        # decay from noise_std → 0.02 over training
        decay_factor = max(0.1, 1.0 - episode / max_episodes)
        effective_std = noise_std * decay_factor

        # finding noisy q values by adding radnomess and then selct action
        noise_q = q_values + effective_std * torch.randn_like(q_values)
        action = torch.argmax(noise_q).item()

    else:
        # and for epsilon times, still dont want to go completely random, so i tried out biased exploration here
        # with FW action having higher chances of being selected
        # although i wont help me because other actions favours spinning and there prob. dist is still more diversed.
        action = torch.multinomial(prob_dist, 1).item()

    return action, hx, cx

# %% [markdown]
# ### Sequence Replay Buffer

# %%
class SeqReplayBuffer():
    def __init__(self, bufferSize, seq_len = 8, batchSize = 32, **kwargs):

        #Your code goes in here
        self.bufferSize = bufferSize
        self.seqLen = seq_len
        self.batchSize = batchSize
        self.max_steps = kwargs['max_steps']

        self.actions = ["L45", "L22", "FW", "R22", "R45"]

        # this is for storing complete sequences of expereinces in an episode
        self.buffer = deque(maxlen=self.bufferSize)
        # this is for storng experiences within an episodes and gets reset after an episode ends.
        self.temporaryBuffer = deque(maxlen=self.max_steps)
        # this holds the priorities of individual expereinces being selectedd ahead
        # once episode finishes then all these sequnce priorities stores in priorites deque and thos gets reset
        self.temporaryPriorities = deque(maxlen=self.max_steps)

        self.alpha = kwargs.get("alpha")
        self.beta = kwargs.get("beta")
        self.beta_rate = kwargs.get("beta_rate")

        # this holds the priorites for each experience within a sequence
        self.priorities = deque(maxlen=self.bufferSize)
        # this holds the priorites for complete episodes to select which episode sequences to select first
        # then seq_num number of experiences within the episode will be selected based on 'priorities' deque.
        self.prioritiesOverEpisodes = deque(maxlen=self.bufferSize)

    def storeStepwiseExperiences(self, experience):
        #Your code goes in here
        max_priority = 1.0 if len(self.temporaryPriorities) == 0 else max(self.temporaryPriorities)
        self.temporaryBuffer.append(experience)
        self.temporaryPriorities.append(max_priority)

    def store(self):
        #Your code goes in here
        timeSeriesExperiences = list(self.temporaryBuffer)
        timeSeriesPriorities = list(self.temporaryPriorities)

        self.temporaryBuffer.clear()
        self.temporaryPriorities.clear()

        self.buffer.append(timeSeriesExperiences)
        self.priorities.append(timeSeriesPriorities)
        max_priority = 1.0 if len(self.prioritiesOverEpisodes) == 0 else max(self.prioritiesOverEpisodes)
        self.prioritiesOverEpisodes.append(max_priority)


    def update(self, td_errors_all, indices, start_indices):
        # td_errors_all shape: (B, seq_len)
        # indices shape: (B, ep_idx)
        if isinstance(td_errors_all, list):
            # list of tensors → stack along dim=1
            td_errors_all = torch.stack(td_errors_all, dim=1).detach().cpu().numpy()
        elif isinstance(td_errors_all, torch.Tensor):
            # single tensor → just detach and convert
            td_errors_all = td_errors_all.detach().cpu().numpy()
        else:
            raise TypeError(f"td_errors_all must be Tensor or list of Tensors, got {type(td_errors_all)}")
        
        for batch_idx, ep_idx in enumerate(indices):
            start = start_indices[batch_idx]
            episode_stepwise = self.priorities[ep_idx]

            # updating only the sampled segment
            episode_stepwise[start:start+td_errors_all.shape[1]] = td_errors_all[batch_idx].tolist()

            # updating episode-level priority as mean of stepwise
            self.prioritiesOverEpisodes[ep_idx] = np.mean(episode_stepwise) + 1e-6


    def sample(self, **kwargs):
        priorities = np.array(self.prioritiesOverEpisodes, dtype=np.float32)

        # cleaning priorities if nan exists
        priorities = np.nan_to_num(priorities, nan=1e-6, posinf=1.0, neginf=1e-6)
        priorities = np.abs(priorities) + 1e-6
        probs = priorities ** self.alpha

        # cleaning probabailtites
        probs = np.nan_to_num(probs, nan=0.0, posinf=1.0, neginf=0.0)
        prob_sum = probs.sum()

        if prob_sum <= 0 or not np.isfinite(prob_sum):
            probs = np.ones(len(probs)) / len(probs)
        else:
            probs = probs / prob_sum

        batch_experiences = []
        batch_weights = []
        start_indices = []

        N = self.length()
        batch = min(self.batchSize, N)

        # selcting the episodes indices from where sequencial expeiences being sampled, using probs calculatedd above
        indices = np.random.choice(N, batch, replace=True, p=probs)
        updatedBeta = min(1.0, self.beta + self.beta_rate * kwargs['running_step'])

        for idx in indices:
            episode = self.buffer[idx]
            ep_prios = self.priorities[idx]

            ep_prios = np.nan_to_num(ep_prios, nan=1e-6, posinf=1.0, neginf=1e-6)
            valid_len = len(episode) - self.seqLen + 1

            # since i have tried both things here, first seleecting the sequence starting point rnadomly or using prioriites stored
            if kwargs.get('priority_seq_sampling', False):
                if valid_len > 0:
                    # considering segment seq priorities till len(seq) - seq_len since starting index will be decided among them only
                    segment_prios = ep_prios[:valid_len]
                    segment_prios = np.abs(segment_prios) + 1e-6
                    segment_probs = segment_prios ** self.alpha
                    segment_probs /= segment_probs.sum()

                    start = np.random.choice(valid_len, p=segment_probs)
                else:
                    start = 0
            else:
                # pick a random contiguous segment
                if valid_len > 0:
                    start = np.random.randint(0, valid_len)
                else:
                    start = 0

            segment = episode[start:start+self.seqLen]
            segment_prios = ep_prios[start:start+self.seqLen]
            segment_prios = list(segment_prios)

            # Pad if episode shorter than seqLen
            while len(segment) < self.seqLen:
                segment.append(segment[-1])
                segment_prios.append(1e-6)

            batch_experiences.append(segment)
            start_indices.append(start)

            # weight computation for eliminating priority overestimation caused by sampling action based on prioties (dervied using td-error)
            seg_prios_np = np.abs(np.array(segment_prios, dtype=np.float32))
            seg_prios_np = np.nan_to_num(seg_prios_np, nan=1e-6)
            mean_prio = max(seg_prios_np.mean(), 1e-6)

            w = (N * mean_prio) ** (-updatedBeta)
            batch_weights.append(w)

        batch_weights = np.array(batch_weights, dtype=np.float32)

        # normalizing safely
        max_w = batch_weights.max()
        if max_w <= 0 or not np.isfinite(max_w):
            batch_weights = np.ones_like(batch_weights)
        else:
            batch_weights /= max_w

        return batch_experiences, indices, batch_weights, start_indices

  
    def splitExperiences(self, sequences):
        # sequences: list of list of (s,a,r,ns,d)
        batch_size = len(sequences)
        seq_len = len(sequences[0])

        states = np.zeros((batch_size, seq_len, len(sequences[0][0][0])), dtype=np.float32)
        actions = np.zeros((batch_size, seq_len), dtype=np.int64)
        rewards = np.zeros((batch_size, seq_len), dtype=np.float32)
        nextStates = np.zeros((batch_size, seq_len, len(sequences[0][0][0])), dtype=np.float32)
        dones = np.zeros((batch_size, seq_len), dtype=np.float32)

        for i, seq in enumerate(sequences):
            for t, (s, a, r, ns, d) in enumerate(seq):
                states[i, t] = np.array(s, dtype=np.float32)
                actions[i, t] = a
                rewards[i, t] = r
                nextStates[i, t] = np.array(ns, dtype=np.float32)
                dones[i, t] = d

        return states, actions, rewards, nextStates, dones
    
    
    def length(self):
        #Your code goes in here
        #
        buffersize = len(self.buffer)
        return buffersize

# %% [markdown]
# ### Network Class

# %%
class KnowledgeNet(nn.Module):
    def __init__(self, inDim=18, outDim=5, f_hDim=[512, 256], lstm_hDim=128, for_hDim=[256, 256], inv_hDim=[256, 256], activation=nn.ReLU):
        super(KnowledgeNet, self).__init__()
        self.activation = activation

        prevDim = inDim
        layers = []
        for nextDim in f_hDim:
            layers.append(nn.Linear(prevDim, nextDim))
            layers.append(self.activation())
            prevDim = nextDim
        self.features = nn.Sequential(*layers)
        self.lstmCell = nn.LSTMCell(prevDim, lstm_hDim)

        # Q head 
        self.values = nn.Linear(lstm_hDim, 1)
        self.advantages = nn.Linear(lstm_hDim, outDim)

        # bad state head (for deciding whether current state in which robot is, either good (away from wall) or bad (touching wall))
        self.bad_state_head = nn.Linear(lstm_hDim, 1)

        # Forward model: (z_t,a_t) -> z_{t+1}
        prevDim = lstm_hDim + outDim
        forward_layers = []
        for nextDim in for_hDim:
            forward_layers.append(nn.Linear(prevDim, nextDim))
            forward_layers.append(self.activation())
            prevDim = nextDim
        forward_layers.append(nn.Linear(prevDim, lstm_hDim))
        self.forward_model = nn.Sequential(*forward_layers)

        # Inverse model: (z_t, z_{t+1}) -> a_t
        prevDim = 2 * lstm_hDim
        inverse_layers = []
        for nextDim in inv_hDim:
            inverse_layers.append(nn.Linear(prevDim, nextDim))
            inverse_layers.append(self.activation())
            prevDim = nextDim
        inverse_layers.append(nn.Linear(prevDim, outDim))
        self.inverse_model = nn.Sequential(*inverse_layers)

        # latent represenation
        self.latent_proj = nn.Sequential(
            nn.Linear(lstm_hDim, lstm_hDim),
            nn.ReLU(),
            nn.LayerNorm(lstm_hDim)
        )

        # Bump Head (for decinding whther infrared bit detcted robot or wall)
        self.bump_head = nn.Sequential(
            nn.Linear(lstm_hDim+2, 128),
            nn.ReLU(),
            nn.Linear(128, 1)
        )


    def _init_weights(self):
        # Linear layers in features block
        for layer in self.features:
            if isinstance(layer, nn.Linear):
                nn.init.xavier_uniform_(layer.weight)
                nn.init.zeros_(layer.bias)

        # LSTMCell has 4 gates, weights are stacked
        nn.init.xavier_uniform_(self.lstmCell.weight_ih)
        nn.init.xavier_uniform_(self.lstmCell.weight_hh)
        nn.init.zeros_(self.lstmCell.bias_ih)
        nn.init.zeros_(self.lstmCell.bias_hh)

        # Q Heads
        nn.init.xavier_uniform_(self.values.weight)
        nn.init.zeros_(self.values.bias)
        nn.init.xavier_uniform_(self.advantages.weight)
        nn.init.zeros_(self.advantages.bias)

        # Forward Model
        for layer in self.forward_model:
            if isinstance(layer, nn.Linear):
                nn.init.xavier_uniform_(layer.weight)
                nn.init.zeros_(layer.bias)

        # Inverse Model
        for layer in self.inverse_model:
            if isinstance(layer, nn.Linear):
                nn.init.xavier_uniform_(layer.weight)
                nn.init.zeros_(layer.bias)

        # Bump Head
        for layer in self.bump_head:
            if isinstance(layer, nn.Linear):
                nn.init.xavier_uniform_(layer.weight)
                nn.init.zeros_(layer.bias)


    def forward(self, x, hx, cx):
        x_f = self.features(x)

        # here hx is hidden state for passing shport tem context to the next state
        # while cx holds the long term context and decides based on experiencing the env what to retain and what to forget
        hx, cx = self.lstmCell(x_f, (hx, cx))

        z_t = self.latent_proj(hx) # latent representaion

        v = self.values(z_t)
        adv = self.advantages(z_t)
        q = v + (adv - adv.mean(dim=1, keepdim=True))

        bad_state_logit = self.bad_state_head(z_t)
        return q, z_t, bad_state_logit, hx, cx

# %% [markdown]
# ### Final Algorithm

# %%
class D3QN_PER():
    def __init__(self, env1, env2, config):
        #Your code goes in here
        self.seed = config['seed']
        np.random.seed(self.seed)
        torch.manual_seed(self.seed)
        random.seed(self.seed)
        torch.cuda.manual_seed_all(self.seed)
        self.env1 = env1
        self.env2 = env2

        self.gamma = config['gamma']
        self.tau = config['tau']
        self.alpha = config['alpha']
        self.beta = config['beta']
        self.beta_rate = config['beta_rate']
        self.delta = config['delta']
        self.seqLen = config['seq_len']
        self.f_hDim = config['f_hDim']
        self.lstm_hDim = config['lstm_hDim']
        self.burn_in = config['burn_in']
        self.minSamples = config['minSamples']
        self.sampleAction = config['sample_action'] if 'sample_action' in config else False
        
        self.for_hDim = config['for_hDim']
        self.inv_hDim = config['inv_hDim']
        self.alpha_f = config['alpha_f']
        self.beta_i = config['beta_i']
        self.eta = config['eta']
        self.noise_std = config['noise_std']

        self.MAX_TRAIN_EPISODES = config['MAX_TRAIN_EPISODES']
        self.MAX_EVAL_EPISODES = config['MAX_EVAL_EPISODES']

        self.bufferSize = config['bufferSize']
        self.batchSize = config['batchSize']
        self.updateFrequency = config['updateFrequency']
        self.max_steps = config['max_steps']
        self.device = config['device']

        self.explorationStrategyTrainFn = config['explorationStrategyTrainFn']
        self.explorationStrategyEvalFn = config['explorationStrategyEvalFn']

        self.epsilons = decayEpsilon(
            config['epsilon'],
            config['eps_decay_strategy'],
            self.MAX_TRAIN_EPISODES
        )

        self.initBookKeeping()

        stateDim = 18 
        self.actions = ["L45", "L22", "FW", "R22", "R45"]
        actionDim = len(self.actions)

        self.loss_fn = config['loss_fn']
        self.model_path = config['model_path']

        # creating Q network
        self.nnTarget = KnowledgeNet(
            stateDim, actionDim, f_hDim = self.f_hDim, 
            lstm_hDim = self.lstm_hDim, for_hDim=self.for_hDim, 
            inv_hDim=self.inv_hDim
        ).to(self.device)

        self.nnOnline = KnowledgeNet(
            stateDim, actionDim, f_hDim = self.f_hDim, 
            lstm_hDim = self.lstm_hDim, for_hDim=self.for_hDim, 
            inv_hDim=self.inv_hDim
        ).to(self.device)

        self.nnOnline._init_weights()
        self.updateNetwork(self.nnOnline, self.nnTarget)

        # defining the optimizer using optimizerFn with optimizerLR
        self.optimizer = config['optimizerFn'](self.nnOnline.parameters(), lr=config['optimizerLR'])

        # created replay buffer for D3QN-PER
        self.rBuffer = SeqReplayBuffer(
            self.bufferSize, seq_len=self.seqLen, 
            batchSize=self.batchSize, max_steps=self.max_steps,
            alpha=self.alpha, beta=self.beta, beta_rate=self.beta_rate
        )

    def initBookKeeping(self):
        # Your code goes in here
        self.trainRewardsList = []
        self.evalRewardsList1 = []
        self.evalRewardsList2 = []
        self.trainTimeList = []
        self.wallClockTimeList = []
        self.totalStepsList = []
        self.startTime = time.time()

    def performBookKeeping(self, train = True):
        # Your code goes in here
        currentTime = time.time()
        if train:
            trainTime = currentTime - self.startTime
            self.trainTimeList.append(trainTime)
        else :
            wallClock = currentTime - self.startTime
            self.wallClockTimeList.append(wallClock)

    def runD3QN_PER(self):
        #Your code goes in here
        trainRewardsList, trainTimeList, evalRewardsList1, evalRewardsList2, wallClockTimeList, totalStepsList = self.trainAgent()
        return trainRewardsList, trainTimeList, evalRewardsList1, evalRewardsList2, wallClockTimeList, totalStepsList
    
    def trainAgent(self):
        #Your code goes in here
        self.updateNetwork(self.nnOnline, self.nnTarget)
        for episode in range(self.MAX_TRAIN_EPISODES):
            # Early Exit 
            if os.path.exists("STOP_TRAINING"):
                print(f"Stop signal detected at episode {episode + 1}. Saving and exiting.")
                torch.save(self.nnOnline.state_dict(), f"{self.model_path}/manual_stop_ep{episode + 1}.pth")
                os.remove("STOP_TRAINING")
                break
            
            # training on both envs with and without walls so that agent can visualize betterly
            # and dont overfit to single env
            envs = [self.env1, self.env2]
            envName = ["with walls", "without walls"]
            env_idx = random.randint(0, len(envs) - 1)
            env = envs[env_idx]
            
            self.nnOnline.to(self.device)
            self.nnTarget.to(self.device)
            # first of all, getting the current state of the agent
            state = env.reset(seed = self.seed + 10 * episode)
            
            hx = torch.zeros(1, self.lstm_hDim).to(self.device)
            cx = torch.zeros(1, self.lstm_hDim).to(self.device)
            done = False
            totalRewards = 0
            totalSteps = 0

            while not done:
                # selecting action based on epislon based noisy exploraiton-exploitation
                action, hx, cx = self.explorationStrategyTrainFn(
                    self.nnOnline, state, self.epsilons[episode], 
                    hx=hx, cx=cx, noise_std=self.noise_std,
                    episode=episode,
                    max_episodes=self.MAX_TRAIN_EPISODES
                )

                # observed the new experience by taking one step in the env
                next_state, reward, done = env.step(self.actions[action], render=False)

                # each experience holds the info of curr_state, action_taken, next_state, reward_got, whether_terminated
                experience = (state, action, reward, next_state, done)

                # stotring stepwise expeirinces into the temnproray replay buffer
                self.rBuffer.storeStepwiseExperiences(experience)

                # training will be started only when seq replay buffer has enough samples to sample from the buffer
                # otherwise training will be skewed and hurts eventually
                if self.rBuffer.length() >= self.minSamples and (totalSteps + 1) % 4 == 0:
                    batch_experiences, indices, batch_weights, start_indices = self.rBuffer.sample(running_step=totalSteps)
                    if batch_experiences is None  or indices is None or batch_weights is None or start_indices is None:
                        continue
                    experiences = (batch_experiences, indices, batch_weights, start_indices)
                    self.trainNetwork(episode, experiences)

                state = next_state
                totalRewards += reward
                totalSteps += 1

                """Now updating the target network based on steps"""
                if (totalSteps+1) % self.updateFrequency == 0:
                    self.updateNetwork(self.nnOnline, self.nnTarget)

            # finally calling store method to store stepwise experiences into the replay buffer
            self.rBuffer.store()
            self.performBookKeeping(train=True)

            # appending the totalReward and totalSteps in bookKeeping variables
            self.trainRewardsList.append(totalRewards)
            self.totalStepsList.append(totalSteps)

            # evaluating after every 20th episode and logging accordingly
            if (episode + 1) % 20 == 0:
                evalRewardsFor2Envs = self.evaluateAgent()
                self.evalRewardsList1.append(evalRewardsFor2Envs[0])
                self.evalRewardsList2.append(evalRewardsFor2Envs[1])
                self.performBookKeeping(train=False)
                print(f"Episode {episode+1}: TR({envName[env_idx]}) {self.trainRewardsList[-1]:.3f} | ER(with wall) {self.evalRewardsList1[-1]:.3f} | ER(without wall) {self.evalRewardsList2[-1]:.3f} | TT {self.trainTimeList[-1]:.3f} | WC {self.wallClockTimeList[-1]:.3f} | TS {self.totalStepsList[-1]:.0f}")
                torch.save(self.nnOnline.state_dict(), f"{self.model_path}/lstm_d3qn_rep_bh_dual_w_{episode+1}.pth")

            else:
                print(f"Episode {episode+1}: TR({envName[env_idx]}) {self.trainRewardsList[-1]:.3f} | TT {self.trainTimeList[-1]:.3f} | TS {self.totalStepsList[-1]:.0f}")

        return self.trainRewardsList, self.trainTimeList, self.evalRewardsList1, self.evalRewardsList2, self.wallClockTimeList, self.totalStepsList
    
    def trainNetwork(self, episode, experiences):
        #Your code goes in here
        self.nnOnline.train()
        self.nnTarget.train()
        batch_experiences, indices, batch_weights, start_indices = experiences
        ss, acts, rs, sNexts, dones = self.rBuffer.splitExperiences(batch_experiences)

        # converting python lists into torch tensors
        ss = torch.FloatTensor(ss).to(self.device)
        acts = torch.LongTensor(acts).to(self.device)
        rs = torch.FloatTensor(rs).to(self.device)
        sNexts = torch.FloatTensor(sNexts).to(self.device)
        dones = torch.FloatTensor(dones).to(self.device)
        weights = torch.FloatTensor(batch_weights).to(self.device)

        B, T, _ = ss.shape

        # Initializing LSTM hidden states
        hx = torch.zeros(B, self.lstm_hDim).to(self.device)
        cx = torch.zeros(B, self.lstm_hDim).to(self.device)

        loss = 0.0
        td_errors_all = []

        # Burn-in steps (required for LSTM to have past context)
        with torch.no_grad():
            for t in range(self.burn_in):
                _, _, _, hx, cx = self.nnOnline(ss[:, t], hx, cx)

        
        for t in range(self.burn_in, T):
            qs, z_t, bad_state_logit, hx, cx = self.nnOnline(ss[:,t], hx, cx)

            hx_next = hx.detach()
            cx_next = cx.detach()

            # finding z_nexts used by inverse network for determing action in order to 
            # learn good latent represenations and also used by forward model as target
            # for determining loss in order to update its params 
            with torch.no_grad():
                _, z_next, _,  _, _ = self.nnOnline(sNexts[:,t], hx_next, cx_next)
            
            # Forward Model
            # it expects actions in one-hot vector encoding rather than numerics and then predidcts the possiible
            # next representation of the robot and whjich will be learnt based on the z_nexts from next states
            # represenations
            a_onehot = F.one_hot(acts[:,t], num_classes=len(self.actions)).float()
            forward_input = torch.cat([z_t, a_onehot], dim=1)
            z_next_pred = self.nnOnline.forward_model(forward_input)
            forward_loss = F.mse_loss(z_next_pred, z_next.detach(), reduction='none').mean(dim=1)

            # inverse model
            # it accepts output from the forward model and based on current and predicted next state represenation
            # predicts the possible actions which is known to us (and acts as target) for determinign loss
            # so it tries to improve the prediction made by forward model which eventually improves the latent
            # representations
            inverse_input = torch.cat([z_t, z_next.detach()], dim=1)
            a_pred_logits = self.nnOnline.inverse_model(inverse_input)
            inverse_loss = F.cross_entropy(a_pred_logits, acts[:,t], reduction='none')

            # reward shaping
            # i found that vaired and unpropotinality in rewards making the robot to learn
            # good behaviors so i log scaled the rewards by preserving their signs
            # and it allows the agent to explore without being in fear of hitting the wall
            rs_env = torch.sign(rs) * torch.log1p(torch.abs(rs))
            rs_env = torch.where(
                rs_env > 0,
                4.0 * rs_env,          # amplify positives so that if its sensors detects box, it can move towards it and tries to follow it
                rs_env                 # keep negatives same
            )

            # Intrinsic Reward
            # added intrisic reward based on by how much extent it shifts from its current represenatations
            # but later decayed it, since represenations also got changed when it rortates so it eveuntally spins without
            # properly decaying intrinsic reward over episode
            intrinsic_reward = torch.norm(z_next_pred - z_next.detach(), dim=1)
            intrinsic_reward = intrinsic_reward / (intrinsic_reward.std().detach() + 1e-8)
            eta = self.eta * (1 - episode / (0.7 * self.MAX_TRAIN_EPISODES))

            
            # Only motivating the robot when reward is negative. rest handled by progress reward 
            intrinsic_reward = (intrinsic_reward + 1e-3) * (rs_env[:, t] <= 0)

            # bad state loss
            bump = ss[:, t, 16].unsqueeze(1)
            stuck = ss[:, t, 17].unsqueeze(1)

            # bump head expected curr latent represenation along with last two bit info to determine
            # whether ahead is wall or box and it will be trained by using binary targets coming from
            # td_error < mean of last few td errors
            # idea was that since td error tells which action performs well than expected so that means
            # if it is more negative than mean of few td errors then this is a wall and not a bump but still
            # it is in itself is not fully corret so leave on neural network to leanr by interaction and temporal
            # learning.
            bump_input = torch.cat([z_t.detach(), bump, stuck], dim=1)
            bump_bad_logit = self.nnOnline.bump_head(bump_input)
            bump_bad_prob = torch.sigmoid(bump_bad_logit)
            
            # for bad state head, target is defiend as below because stuck is always bad and gets set when either stuck at wall or boundary
            # and have to decide whow much percent of bump is bad using the prob dist from bump logits.
            bad_state_target = stuck + bump * bump_bad_prob.detach().squeeze(1)
            bad_state_penalty = stuck.squeeze(1) + bump.squeeze(1) * bump_bad_prob.detach().squeeze(1)
            bad_state_bump_loss = torch.clip(0.5 * ((bad_state_target - bad_state_logit.squeeze(1)) ** 2), 0, 2).mean()
            
            # Since agent still getting stuck so used this also to avoid getting stuck (extra safety)
            stuck_loss = F.binary_cross_entropy_with_logits(
                bad_state_logit.squeeze(1),
                stuck.squeeze(1)
            )

            # rewarding if sensor detects box 
            # initally my idea was to give more bonus when sensor bits and inrared detects box then over taking forward action, 
            # it should get some bonus but if given more time, this logic can be improved since
            # my agent suffers from this alignment problem still.
            extra_bonus_for_getting_attached_to_box_if_detected = ((bump_bad_prob.squeeze(1) < 0.08).float() * ss[:, t, 16] * ss[:, t, 4:12].mean(dim=1) * (acts[:,t]==2).float()).mean()
            progress_reward =  0.15 * torch.mean(ss[:, t,:16], dim=1) + 0.4 * extra_bonus_for_getting_attached_to_box_if_detected - 0.05 * bad_state_penalty

            total_reward = rs_env[:,t] + max(0.005, eta) * intrinsic_reward + progress_reward

            # D3QN Loss     
            qs_next, _, _, _, _ = self.nnOnline(sNexts[:, t], hx_next, cx_next)
            a_next = qs_next.argmax(dim=1)

            qt_next, _, _, _, _ = self.nnTarget(sNexts[:, t], hx_next, cx_next)
            max_q = qt_next.gather(1, a_next.unsqueeze(1)).squeeze(1)

            td_target = total_reward + self.gamma * max_q.detach() * (1 - dones[:, t])

            q_val = qs.gather(1, acts[:, t].unsqueeze(1)).squeeze(1)
            td_error = td_target - q_val
            td_errors_all.append(td_error)

            # finding bump loss 
            last_few = min(4, len(td_errors_all))
            recent_errors = td_errors_all[-last_few:]
            recent_tensors = [t.detach().float().mean() if isinstance(t, torch.Tensor) else torch.tensor(float(t)) for t in recent_errors]
            mean_of_last_4_td_errors = torch.stack(recent_tensors).mean().item()

            bump_target = (td_error.detach() < mean_of_last_4_td_errors).float()
            bump_loss = (bump.squeeze(1) * F.binary_cross_entropy_with_logits(
                bump_bad_logit.squeeze(1),
                bump_target,
                reduction='none'
            )).mean()

            if self.loss_fn == 'HuberLoss':
                d3qn_loss = huberLoss(td_error, self.delta, weights, norm=True)
            else:
                # weights here are for correcting prioritity bias
                d3qn_loss = (weights * td_error.pow(2)).sum().mean() / weights.sum()


            # total loss
            loss += (
                d3qn_loss + 
                self.alpha_f * (weights * forward_loss).mean() +
                self.beta_i * (weights * inverse_loss).mean() +
                0.1 * bump_loss +
                0.2 * bad_state_bump_loss +
                0.4 * stuck_loss
            )

            done_mask = dones[:,t].unsqueeze(1)
            hx = hx * (1 - done_mask)
            cx = cx * (1 - done_mask)
        
        loss = loss / (T - self.burn_in)

        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.nnOnline.parameters(), 10)
        self.optimizer.step()
        
        self.rBuffer.update(td_errors_all, indices, start_indices)


    def updateNetwork(self, onlineNet, targetNet):
        #this function updates the onlineNetwork with the target network
        # Your code goes in here
        
        for target_param, online_param in zip(targetNet.parameters(), onlineNet.parameters()):
            target_param.data.copy_(self.tau * online_param.data + (1 - self.tau) * target_param.data)


    def evaluateAgent(self):
        #this function evaluates the agent using the value network, it evaluates agent for MAX_EVAL_EPISODES
        #Your code goes in here

        self.nnOnline.eval()
        self.nnTarget.eval()
        feval = []

        for env in [self.env1, self.env2]:
            temp_eval = []
            for e in range(self.MAX_EVAL_EPISODES):
                # selecting seed randomly for preventing overfitting
                seed = random.randint(0, 10000)
                state = env.reset(seed = seed)
                totalReward = 0
                done = False
                hx = torch.zeros(1, self.lstm_hDim).to(self.device)
                cx = torch.zeros(1, self.lstm_hDim).to(self.device)

                while not done:
                    # during evaluation, action must be selected greedily based on what our model learnt
                    action, hx, cx = self.explorationStrategyEvalFn(self.nnOnline, state, hx=hx, cx=cx)
                    next_state, reward, done = env.step(self.actions[action], render=False)

                    totalReward += reward
                    state = next_state

                temp_eval.append(totalReward)
            feval.append(np.mean(temp_eval).item())

        return feval

# %% [markdown]
# ### Configuration File

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print('device used: ', device)

config = {
    'seed': 333,
    'gamma': 0.99,
    'bufferSize': 1_000_000,
    'batchSize': 32,
    'optimizerFn': torch.optim.Adam,
    'optimizerLR': 1e-4,
    'MAX_TRAIN_EPISODES': 1000,
    'MAX_EVAL_EPISODES': 5,
    'updateFrequency': 80,
    'explorationStrategyTrainFn': selectEpsilonGreedyActionREP_NOISY,
    'explorationStrategyEvalFn': selectGreedyActionREP_COMP,
    'max_steps': 1000,
    'epsilon': 0.98,
    'eps_decay_strategy': [
        ("linear", {'s': 0, 'e': 499, 'ival': 1.0, 'fval': 0.35}),
        ("exponential", {'s': 500, 'e': 999, 'ival': 0.35, 'fval': 0.05})
    ],
    'device': device,
    'delta': 0.99,
    'tau': 0.005,
    'alpha': 0.58,
    'beta': 0.42,
    'beta_rate': 0.0002,
    'f_hDim': [324, 256],
    'lstm_hDim': 128,
    'model_path': './model_weights/trial',
    'loss_fn': 'HuberLoss',
    'seq_len': 30,
    'burn_in': 10,
    'minSamples': 40, # represents to collection of one whole sequqnce of experiences
    'for_hDim': [224, 128],
    'inv_hDim': [224, 128],
    'alpha_f': 0.12,
    'beta_i': 0.15,
    'eta': 0.08,
    'noise_std': 0.2
}
# Out:
# device used:  cuda

# %% [markdown]
# ### Training

# %%
env1 = OBELIX(
    scaling_factor=5,
    arena_size=500,
    max_steps=1000,
    wall_obstacles=True,
    difficulty=3,
    box_speed=4,
)

env2 = OBELIX(
    scaling_factor=5,
    arena_size=500,
    max_steps=1000,
    wall_obstacles=False,
    difficulty=2,
)

D3QN_PER_LSTM_with_REP_BAD_HEAD_Agent = D3QN_PER(env1, env2, config)

# %%
d3qnPerTrainRewardsList, d3qnPerTrainTimeList, d3qnPerEvalRewardsList1, d3qnPerEvalRewardsList2, d3qnPerWallClockTimeList, d3qnPerTotalStepsList = D3QN_PER_LSTM_with_REP_BAD_HEAD_Agent.runD3QN_PER()
# Out:
# Episode 1: TR(without walls) -15200.000 | TT 9.014 | TS 1000
# Episode 2: TR(without walls) -37468.000 | TT 17.359 | TS 1000
# Episode 3: TR(with walls) -27534.000 | TT 24.550 | TS 866
# Episode 4: TR(without walls) -59800.000 | TT 32.825 | TS 1000
# Episode 5: TR(with walls) -19384.000 | TT 38.417 | TS 713
# Episode 6: TR(without walls) 1885.000 | TT 40.402 | TS 247
# Episode 7: TR(without walls) -24000.000 | TT 48.439 | TS 1000
# Episode 8: TR(without walls) -40786.000 | TT 56.831 | TS 1000
# Episode 9: TR(without walls) -87800.000 | TT 64.812 | TS 1000
# Episode 10: TR(with walls) -39967.000 | TT 72.597 | TS 1000
# Episode 11: TR(without walls) -33200.000 | TT 80.468 | TS 1000
# Episode 12: TR(with walls) -17526.000 | TT 82.334 | TS 241
# Episode 13: TR(without walls) 1463.000 | TT 87.554 | TS 654
# Episode 14: TR(with walls) -44181.000 | TT 96.080 | TS 1000
# Episode 15: TR(without walls) -42972.000 | TT 103.333 | TS 1000
# Episode 16: TR(with walls) -55775.000 | TT 111.229 | TS 1000
# Episode 17: TR(without walls) -942.000 | TT 114.777 | TS 474
# Episode 18: TR(without walls) -41000.000 | TT 122.473 | TS 1000
# Episode 19: TR(without walls) -61798.000 | TT 130.066 | TS 1000
# Episode 20: TR(without walls) -73600.000 | ER(with wall) -941.800 | ER(without wall) -986.800 | TT 137.583 | WC 240.885 | TS 1000
# Episode 21: TR(with walls) -11874.000 | TT 251.516 | TS 1000
# Episode 22: TR(with walls) 2015.000 | TT 252.728 | TS 116
# Episode 23: TR(with walls) -65884.000 | TT 261.478 | TS 807
# Episode 24: TR(with walls) -69792.000 | TT 272.429 | TS 1000
# Episode 25: TR(without walls) -48572.000 | TT 282.948 | TS 1000
# Episode 26: TR(with walls) -70171.000 | TT 293.677 | TS 1000
# Episode 27: TR(without walls) -6462.000 | TT 302.283 | TS 794
# Episode 28: TR(with walls) -28833.000 | TT 310.408 | TS 765
# Episode 29: TR(without walls) -24785.000 | TT 321.004 | TS 1000
# Episode 30: TR(with walls) -46771.000 | TT 331.639 | TS 1000
# Episode 31: TR(with walls) -73296.000 | TT 342.299 | TS 1000
# Episode 32: TR(with walls) -40672.000 | TT 353.275 | TS 1000
# Episode 33: TR(without walls) -22384.000 | TT 363.695 | TS 1000
# Episode 34: TR(without walls) -3788.000 | TT 373.544 | TS 920
# Episode 35: TR(without walls) 1513.000 | TT 379.900 | TS 599
# Episode 36: TR(without walls) -9469.000 | TT 390.835 | TS 1000
# Episode 37: TR(without walls) -20972.000 | TT 401.448 | TS 1000
# Episode 38: TR(with walls) 1567.000 | TT 407.575 | TS 565
# Episode 39: TR(without walls) -4384.000 | TT 418.826 | TS 1000
# Episode 40: TR(without walls) -7777.000 | ER(with wall) -499.000 | ER(without wall) -983.000 | TT 430.698 | WC 542.302 | TS 1000
# Episode 41: TR(without walls) -75184.000 | TT 619.856 | TS 1000
# Episode 42: TR(without walls) -11572.000 | TT 697.598 | TS 1000
# Episode 43: TR(with walls) -21480.000 | TT 757.246 | TS 789
# Episode 44: TR(with walls) -20670.000 | TT 827.263 | TS 1000
# Episode 45: TR(with walls) -53168.000 | TT 883.740 | TS 1000
# Episode 46: TR(without walls) 1692.000 | TT 906.660 | TS 440
# Episode 47: TR(with walls) 2094.000 | TT 908.468 | TS 31
# Episode 48: TR(without walls) -17784.000 | TT 966.334 | TS 1000
# Episode 49: TR(with walls) -10184.000 | TT 1028.893 | TS 1000
# Episode 50: TR(without walls) -18600.000 | TT 1090.965 | TS 1000
# Episode 51: TR(without walls) -5572.000 | TT 1154.057 | TS 1000
# Episode 52: TR(without walls) -46600.000 | TT 1206.470 | TS 1000
# Episode 53: TR(without walls) -4771.000 | TT 1255.131 | TS 1000
# Episode 54: TR(with walls) -197480.000 | TT 1303.085 | TS 1000
# Episode 55: TR(with walls) -38971.000 | TT 1351.760 | TS 1000
# Episode 56: TR(with walls) -124268.000 | TT 1400.312 | TS 1000
# Episode 57: TR(with walls) -12303.000 | TT 1431.042 | TS 632
# Episode 58: TR(without walls) -64384.000 | TT 1491.446 | TS 1000
# Episode 59: TR(without walls) -66775.000 | TT 1541.576 | TS 1000
# Episode 60: TR(without walls) -18113.000 | ER(with wall) -27497.400 | ER(without wall) -184493.200 | TT 1572.749 | WC 1636.811 | TS 625
# Episode 61: TR(without walls) 2037.000 | TT 1641.262 | TS 95
# Episode 62: TR(with walls) -26167.000 | TT 1689.832 | TS 1000
# Episode 63: TR(with walls) -52367.000 | TT 1738.770 | TS 1000
# Episode 64: TR(without walls) -50000.000 | TT 1787.583 | TS 1000
# Episode 65: TR(without walls) -16199.000 | TT 1812.692 | TS 513
# Episode 66: TR(without walls) -25689.000 | TT 1861.729 | TS 1000
# Episode 67: TR(without walls) -40400.000 | TT 1910.559 | TS 1000
# Episode 68: TR(without walls) -63000.000 | TT 1960.137 | TS 1000
# Episode 69: TR(with walls) 2051.000 | TT 1963.810 | TS 76
# Episode 70: TR(with walls) -20672.000 | TT 2012.760 | TS 1000
# Episode 71: TR(with walls) -60180.000 | TT 2061.639 | TS 1000
# Episode 72: TR(without walls) -980.000 | TT 2110.768 | TS 1000
# Episode 73: TR(without walls) -973.000 | TT 2160.211 | TS 1000
# Episode 74: TR(without walls) -3572.000 | TT 2249.353 | TS 1000
# Episode 75: TR(without walls) -40184.000 | TT 2333.708 | TS 1000
# Episode 76: TR(with walls) -21502.000 | TT 2384.235 | TS 614
# Episode 77: TR(with walls) 1940.000 | TT 2401.481 | TS 192
# Episode 78: TR(with walls) -32599.000 | TT 2447.743 | TS 531
# Episode 79: TR(without walls) -15400.000 | TT 2522.803 | TS 1000
# Episode 80: TR(with walls) -56868.000 | ER(with wall) -922.400 | ER(without wall) -994.800 | TT 2614.536 | WC 2735.757 | TS 1000
# Episode 81: TR(without walls) -973.000 | TT 2824.435 | TS 1000
# Episode 82: TR(without walls) -34572.000 | TT 2915.287 | TS 1000
# Episode 83: TR(without walls) -18400.000 | TT 3013.163 | TS 1000
# Episode 84: TR(without walls) -17461.000 | TT 3071.770 | TS 593
# Episode 85: TR(without walls) -64784.000 | TT 3165.762 | TS 1000
# Episode 86: TR(with walls) 465.000 | TT 3170.674 | TS 50
# Episode 87: TR(with walls) -33367.000 | TT 3271.354 | TS 1000
# Episode 88: TR(with walls) 2096.000 | TT 3273.980 | TS 29
# Episode 89: TR(without walls) -43132.000 | TT 3356.566 | TS 857
# Episode 90: TR(without walls) -41400.000 | TT 3423.801 | TS 1000
# Episode 91: TR(with walls) -139871.000 | TT 3486.265 | TS 1000
# Episode 92: TR(with walls) -27106.000 | TT 3540.071 | TS 835
# Episode 93: TR(without walls) -20200.000 | TT 3600.968 | TS 1000
# Episode 94: TR(with walls) -30270.000 | TT 3663.591 | TS 1000
# Episode 95: TR(without walls) 1595.000 | TT 3699.041 | TS 537
# Episode 96: TR(without walls) -17384.000 | TT 3766.064 | TS 1000
# Episode 97: TR(without walls) -4071.000 | TT 3824.967 | TS 1000
# Episode 98: TR(with walls) -69679.000 | TT 3895.846 | TS 1000
# Episode 99: TR(with walls) -33069.000 | TT 3962.563 | TS 1000
# Episode 100: TR(without walls) -12800.000 | ER(with wall) -957.400 | ER(without wall) 89.000 | TT 4029.016 | WC 4102.580 | TS 1000
# Episode 101: TR(without walls) 1200.000 | TT 4163.302 | TS 914
# Episode 102: TR(without walls) 1697.000 | TT 4192.271 | TS 435
# Episode 103: TR(with walls) -30168.000 | TT 4253.642 | TS 1000
# Episode 104: TR(without walls) -7242.000 | TT 4321.011 | TS 974
# Episode 105: TR(with walls) -53370.000 | TT 4385.028 | TS 1000
# Episode 106: TR(with walls) -58869.000 | TT 4451.900 | TS 1000
# Episode 107: TR(with walls) -21369.000 | TT 4521.373 | TS 1000
# Episode 108: TR(without walls) -29584.000 | TT 4579.082 | TS 1000
# Episode 109: TR(with walls) -29170.000 | TT 4659.314 | TS 1000
# Episode 110: TR(with walls) -40068.000 | TT 4759.612 | TS 1000
# Episode 111: TR(without walls) -31400.000 | TT 4836.790 | TS 1000
# Episode 112: TR(with walls) 1382.000 | TT 4845.133 | TS 133
# Episode 113: TR(without walls) -30167.000 | TT 4906.597 | TS 1000
# Episode 114: TR(without walls) -38400.000 | TT 4982.448 | TS 1000
# Episode 115: TR(without walls) -15000.000 | TT 5078.890 | TS 1000
# Episode 116: TR(without walls) -56000.000 | TT 5168.247 | TS 1000
# Episode 117: TR(with walls) -34369.000 | TT 5253.414 | TS 1000
# Episode 118: TR(with walls) -39167.000 | TT 5334.279 | TS 1000
# Episode 119: TR(without walls) -54184.000 | TT 5415.005 | TS 1000
# Episode 120: TR(without walls) -60974.000 | ER(with wall) -3503.000 | ER(without wall) 180.600 | TT 5478.319 | WC 5563.758 | TS 1000
# Episode 121: TR(with walls) -27567.000 | TT 5641.038 | TS 1000
# Episode 122: TR(with walls) -29371.000 | TT 5718.933 | TS 1000
# Episode 123: TR(without walls) -6389.000 | TT 5801.073 | TS 1000
# Episode 124: TR(with walls) -53384.000 | TT 5878.971 | TS 1000
# Episode 125: TR(with walls) -49882.000 | TT 5957.414 | TS 1000
# Episode 126: TR(without walls) -31773.000 | TT 6043.298 | TS 1000
# Episode 127: TR(without walls) -10068.000 | TT 6125.730 | TS 1000
# Episode 128: TR(with walls) -36830.000 | TT 6207.996 | TS 962
# Episode 129: TR(without walls) -3069.000 | TT 6295.393 | TS 1000
# Episode 130: TR(without walls) -976.000 | TT 6381.773 | TS 1000
# Episode 131: TR(without walls) -36000.000 | TT 6466.715 | TS 1000
# Episode 132: TR(with walls) -10468.000 | TT 6551.082 | TS 1000
# Episode 133: TR(with walls) -5167.000 | TT 6633.890 | TS 1000
# Episode 134: TR(without walls) -874.000 | TT 6718.307 | TS 1000
# Episode 135: TR(with walls) -14305.000 | TT 6774.339 | TS 627
# Episode 136: TR(with walls) -21273.000 | TT 6828.634 | TS 600
# Episode 137: TR(with walls) -36871.000 | TT 6916.368 | TS 1000
# Episode 138: TR(without walls) -868.000 | TT 7010.201 | TS 1000
# Episode 139: TR(without walls) -24572.000 | TT 7096.546 | TS 1000
# Episode 140: TR(with walls) -32569.000 | ER(with wall) -105664.000 | ER(without wall) -4142.600 | TT 7170.795 | WC 7250.708 | TS 881
# Episode 141: TR(without walls) 1338.000 | TT 7316.358 | TS 782
# Episode 142: TR(with walls) -18575.000 | TT 7376.630 | TS 705
# Episode 143: TR(without walls) 1173.000 | TT 7458.823 | TS 959
# Episode 144: TR(without walls) 1658.000 | TT 7498.441 | TS 474
# Episode 145: TR(without walls) -4584.000 | TT 7584.770 | TS 1000
# Episode 146: TR(with walls) -23167.000 | TT 7673.188 | TS 1000
# Episode 147: TR(with walls) -11068.000 | TT 7757.030 | TS 1000
# Episode 148: TR(with walls) -26269.000 | TT 7843.258 | TS 1000
# Episode 149: TR(with walls) -37582.000 | TT 7927.764 | TS 1000
# Episode 150: TR(with walls) -107384.000 | TT 8014.246 | TS 1000
# Episode 151: TR(without walls) -15972.000 | TT 8101.373 | TS 1000
# Episode 152: TR(without walls) -870.000 | TT 8183.385 | TS 1000
# Episode 153: TR(with walls) -80184.000 | TT 8269.721 | TS 1000
# Episode 154: TR(with walls) -18967.000 | TT 8355.591 | TS 1000
# Episode 155: TR(without walls) -35468.000 | TT 8441.834 | TS 1000
# Episode 156: TR(without walls) -47000.000 | TT 8529.353 | TS 1000
# Episode 157: TR(with walls) -44372.000 | TT 8617.462 | TS 1000
# Episode 158: TR(without walls) -17172.000 | TT 8703.921 | TS 1000
# Episode 159: TR(with walls) -41772.000 | TT 8786.836 | TS 1000
# Episode 160: TR(without walls) -8978.000 | ER(with wall) -178492.400 | ER(without wall) -32154.400 | TT 8857.402 | WC 8967.049 | TS 1000
# Episode 161: TR(with walls) -11767.000 | TT 9049.923 | TS 1000
# Episode 162: TR(without walls) -36984.000 | TT 9131.260 | TS 1000
# Episode 163: TR(with walls) -50680.000 | TT 9215.209 | TS 1000
# Episode 164: TR(without walls) -47184.000 | TT 9302.933 | TS 1000
# Episode 165: TR(with walls) -20665.000 | TT 9353.738 | TS 597
# Episode 166: TR(without walls) -37471.000 | TT 9442.696 | TS 1000
# Episode 167: TR(with walls) -42986.000 | TT 9530.274 | TS 1000
# Episode 168: TR(without walls) 1957.000 | TT 9544.013 | TS 167
# Episode 169: TR(with walls) -29470.000 | TT 9628.142 | TS 1000
# Episode 170: TR(without walls) -57971.000 | TT 9711.333 | TS 1000
# Episode 171: TR(without walls) -17468.000 | TT 9798.303 | TS 1000
# Episode 172: TR(without walls) -872.000 | TT 9878.547 | TS 1000
# Episode 173: TR(with walls) -19367.000 | TT 9959.558 | TS 1000
# Episode 174: TR(with walls) 1973.000 | TT 9970.999 | TS 147
# Episode 175: TR(without walls) -8400.000 | TT 10051.737 | TS 1000
# Episode 176: TR(without walls) -4668.000 | TT 10133.877 | TS 1000
# Episode 177: TR(without walls) -18200.000 | TT 10219.561 | TS 1000
# Episode 178: TR(with walls) -36567.000 | TT 10306.799 | TS 1000
# Episode 179: TR(without walls) -47984.000 | TT 10397.387 | TS 1000
# Episode 180: TR(with walls) -24187.000 | ER(with wall) -109094.600 | ER(without wall) -405.600 | TT 10483.174 | WC 10564.613 | TS 1000
# Episode 181: TR(with walls) -90674.000 | TT 10652.218 | TS 1000
# Episode 182: TR(with walls) -7064.000 | TT 10736.230 | TS 992
# Episode 183: TR(without walls) -40969.000 | TT 10824.262 | TS 1000
# Episode 184: TR(with walls) -10284.000 | TT 10860.495 | TS 414
# Episode 185: TR(without walls) -4976.000 | TT 10948.224 | TS 1000
# Episode 186: TR(with walls) -19568.000 | TT 11030.851 | TS 1000
# Episode 187: TR(with walls) -719.000 | TT 11069.369 | TS 439
# Episode 188: TR(with walls) -17276.000 | TT 11154.595 | TS 1000
# Episode 189: TR(with walls) -27973.000 | TT 11234.496 | TS 1000
# Episode 190: TR(without walls) 1410.000 | TT 11293.389 | TS 722
# Episode 191: TR(without walls) 1411.000 | TT 11341.179 | TS 721
# Episode 192: TR(without walls) 1304.000 | TT 11389.385 | TS 826
# Episode 193: TR(with walls) -32668.000 | TT 11448.221 | TS 1000
# Episode 194: TR(with walls) -5878.000 | TT 11460.476 | TS 209
# Episode 195: TR(without walls) -42800.000 | TT 11519.850 | TS 1000
# Episode 196: TR(without walls) 1896.000 | TT 11533.415 | TS 234
# Episode 197: TR(without walls) -39200.000 | TT 11591.944 | TS 1000
# Episode 198: TR(without walls) 1796.000 | TT 11611.239 | TS 333
# Episode 199: TR(with walls) -51938.000 | TT 11659.098 | TS 868
# Episode 200: TR(without walls) -84200.000 | ER(with wall) -177237.000 | ER(without wall) 781.600 | TT 11717.103 | WC 11782.044 | TS 1000
# Episode 201: TR(without walls) -28372.000 | TT 11839.966 | TS 1000
# Episode 202: TR(without walls) -53586.000 | TT 11898.051 | TS 1000
# Episode 203: TR(with walls) -14604.000 | TT 11929.103 | TS 536
# Episode 204: TR(without walls) -39572.000 | TT 11987.395 | TS 1000
# Episode 205: TR(with walls) -39270.000 | TT 12045.304 | TS 1000
# Episode 206: TR(without walls) -33772.000 | TT 12103.379 | TS 1000
# Episode 207: TR(with walls) -4360.000 | TT 12106.914 | TS 63
# Episode 208: TR(with walls) -78548.000 | TT 12157.365 | TS 868
# Episode 209: TR(without walls) -47372.000 | TT 12215.517 | TS 1000
# Episode 210: TR(with walls) -7304.000 | TT 12240.090 | TS 424
# Episode 211: TR(with walls) -29682.000 | TT 12298.216 | TS 1000
# Episode 212: TR(without walls) -43600.000 | TT 12356.223 | TS 1000
# Episode 213: TR(with walls) -20347.000 | TT 12383.998 | TS 476
# Episode 214: TR(without walls) -48000.000 | TT 12442.154 | TS 1000
# Episode 215: TR(without walls) -6468.000 | TT 12500.147 | TS 1000
# Episode 216: TR(with walls) -55569.000 | TT 12558.113 | TS 1000
# Episode 217: TR(without walls) -10784.000 | TT 12616.987 | TS 1000
# Episode 218: TR(with walls) -1373.000 | TT 12675.052 | TS 1000
# Episode 219: TR(without walls) -44200.000 | TT 12733.150 | TS 1000
# Episode 220: TR(with walls) -15172.000 | ER(with wall) -127454.600 | ER(without wall) -39623.000 | TT 12791.527 | WC 12864.348 | TS 1000
# Episode 221: TR(without walls) 1707.000 | TT 12889.185 | TS 425
# Episode 222: TR(with walls) -28387.000 | TT 12947.167 | TS 1000
# Episode 223: TR(with walls) -36177.000 | TT 13005.207 | TS 1000
# Episode 224: TR(with walls) -70569.000 | TT 13063.217 | TS 1000
# Episode 225: TR(without walls) -72385.000 | TT 13121.253 | TS 1000
# Episode 226: TR(without walls) -31800.000 | TT 13179.638 | TS 1000
# Episode 227: TR(with walls) -5370.000 | TT 13237.785 | TS 1000
# Episode 228: TR(without walls) -43200.000 | TT 13296.011 | TS 1000
# Episode 229: TR(without walls) -52400.000 | TT 13354.511 | TS 1000
# Episode 230: TR(without walls) -17600.000 | TT 13412.892 | TS 1000
# Episode 231: TR(with walls) -81772.000 | TT 13471.134 | TS 1000
# Episode 232: TR(without walls) -11776.000 | TT 13529.320 | TS 1000
# Episode 233: TR(with walls) -48271.000 | TT 13587.733 | TS 1000
# Episode 234: TR(without walls) 1511.000 | TT 13623.945 | TS 618
# Episode 235: TR(with walls) -43367.000 | TT 13682.269 | TS 1000
# Episode 236: TR(without walls) -27572.000 | TT 13740.409 | TS 1000
# Episode 237: TR(with walls) -62180.000 | TT 13798.737 | TS 1000
# Episode 238: TR(without walls) -6455.000 | TT 13844.347 | TS 787
# Episode 239: TR(with walls) -95768.000 | TT 13903.441 | TS 1000
# Episode 240: TR(without walls) 1432.000 | ER(with wall) -134641.400 | ER(without wall) -452.600 | TT 13944.442 | WC 14024.328 | TS 700
# Episode 241: TR(without walls) -30578.000 | TT 14082.685 | TS 1000
# Episode 242: TR(without walls) -6786.000 | TT 14141.127 | TS 1000
# Episode 243: TR(without walls) -35182.000 | TT 14199.519 | TS 1000
# Episode 244: TR(without walls) -63972.000 | TT 14257.936 | TS 1000
# Episode 245: TR(without walls) -972.000 | TT 14316.530 | TS 1000
# Episode 246: TR(without walls) -10184.000 | TT 14358.386 | TS 716
# Episode 247: TR(with walls) -124670.000 | TT 14416.473 | TS 1000
# Episode 248: TR(with walls) -22770.000 | TT 14475.150 | TS 1000
# Episode 249: TR(with walls) -163070.000 | TT 14532.840 | TS 1000
# Episode 250: TR(without walls) -17373.000 | TT 14591.232 | TS 1000
# Episode 251: TR(with walls) -21725.000 | TT 14641.008 | TS 854
# Episode 252: TR(with walls) 1708.000 | TT 14665.470 | TS 421
# Episode 253: TR(without walls) -48000.000 | TT 14723.796 | TS 1000
# Episode 254: TR(without walls) -64980.000 | TT 14782.265 | TS 1000
# Episode 255: TR(without walls) -20984.000 | TT 14840.875 | TS 1000
# Episode 256: TR(with walls) -16272.000 | TT 14899.207 | TS 1000
# Episode 257: TR(without walls) 1248.000 | TT 14950.907 | TS 882
# Episode 258: TR(with walls) -32580.000 | TT 15009.411 | TS 1000
# Episode 259: TR(without walls) 1827.000 | TT 15027.025 | TS 305
# Episode 260: TR(without walls) -40200.000 | ER(with wall) -105052.400 | ER(without wall) -1000.000 | TT 15085.577 | WC 15164.334 | TS 1000
# Episode 261: TR(with walls) -47181.000 | TT 15222.963 | TS 1000
# Episode 262: TR(with walls) -4965.000 | TT 15240.196 | TS 292
# Episode 263: TR(with walls) -40370.000 | TT 15298.358 | TS 1000
# Episode 264: TR(without walls) -19186.000 | TT 15356.925 | TS 1000
# Episode 265: TR(without walls) -34468.000 | TT 15415.464 | TS 1000
# Episode 266: TR(without walls) -35776.000 | TT 15473.885 | TS 1000
# Episode 267: TR(without walls) 1917.000 | TT 15486.157 | TS 215
# Episode 268: TR(with walls) -78767.000 | TT 15544.684 | TS 1000
# Episode 269: TR(without walls) -38374.000 | TT 15603.032 | TS 1000
# Episode 270: TR(with walls) -29269.000 | TT 15661.116 | TS 1000
# Episode 271: TR(with walls) -28273.000 | TT 15708.044 | TS 801
# Episode 272: TR(without walls) -967.000 | TT 15766.251 | TS 1000
# Episode 273: TR(with walls) -79684.000 | TT 15824.647 | TS 1000
# Episode 274: TR(with walls) -41871.000 | TT 15883.302 | TS 1000
# Episode 275: TR(without walls) -1000.000 | TT 15941.836 | TS 1000
# Episode 276: TR(with walls) -24412.000 | TT 15961.707 | TS 342
# Episode 277: TR(with walls) -24272.000 | TT 16020.069 | TS 1000
# Episode 278: TR(with walls) -8779.000 | TT 16078.514 | TS 1000
# Episode 279: TR(without walls) -65583.000 | TT 16136.948 | TS 1000
# Episode 280: TR(with walls) -8007.000 | ER(with wall) -38237.000 | ER(without wall) -38916.800 | TT 16144.409 | WC 16221.855 | TS 129
# Episode 281: TR(without walls) -32372.000 | TT 16280.429 | TS 1000
# Episode 282: TR(with walls) -53270.000 | TT 16339.054 | TS 1000
# Episode 283: TR(with walls) -54869.000 | TT 16397.366 | TS 1000
# Episode 284: TR(with walls) -1776.000 | TT 16455.673 | TS 1000
# Episode 285: TR(without walls) 2105.000 | TT 16456.853 | TS 20
# Episode 286: TR(without walls) 1858.000 | TT 16472.910 | TS 272
# Episode 287: TR(without walls) -35000.000 | TT 16531.429 | TS 1000
# Episode 288: TR(without walls) -7572.000 | TT 16589.792 | TS 1000
# Episode 289: TR(with walls) 1376.000 | TT 16634.141 | TS 756
# Episode 290: TR(with walls) -32384.000 | TT 16692.185 | TS 1000
# Episode 291: TR(with walls) 1954.000 | TT 16702.264 | TS 177
# Episode 292: TR(without walls) -20668.000 | TT 16760.033 | TS 1000
# Episode 293: TR(with walls) -454.000 | TT 16792.885 | TS 566
# Episode 294: TR(with walls) -107174.000 | TT 16851.183 | TS 1000
# Episode 295: TR(with walls) -45870.000 | TT 16909.172 | TS 1000
# Episode 296: TR(without walls) -60331.000 | TT 16959.441 | TS 863
# Episode 297: TR(with walls) -65969.000 | TT 17017.566 | TS 1000
# Episode 298: TR(with walls) -7740.000 | TT 17056.035 | TS 662
# Episode 299: TR(with walls) -15370.000 | TT 17114.274 | TS 1000
# Episode 300: TR(with walls) -6775.000 | ER(with wall) -98668.400 | ER(without wall) -38997.000 | TT 17155.524 | WC 17218.696 | TS 706
# Episode 301: TR(without walls) 1412.000 | TT 17260.685 | TS 719
# Episode 302: TR(without walls) -13372.000 | TT 17318.892 | TS 1000
# Episode 303: TR(with walls) -25587.000 | TT 17377.141 | TS 1000
# Episode 304: TR(with walls) -73367.000 | TT 17435.463 | TS 1000
# Episode 305: TR(with walls) -12181.000 | TT 17493.526 | TS 1000
# Episode 306: TR(with walls) -3870.000 | TT 17551.710 | TS 1000
# Episode 307: TR(with walls) -20504.000 | TT 17576.689 | TS 428
# Episode 308: TR(without walls) -15400.000 | TT 17635.095 | TS 1000
# Episode 309: TR(without walls) -99200.000 | TT 17693.501 | TS 1000
# Episode 310: TR(with walls) -32887.000 | TT 17740.960 | TS 812
# Episode 311: TR(with walls) -21567.000 | TT 17799.437 | TS 1000
# Episode 312: TR(without walls) -58400.000 | TT 17857.771 | TS 1000
# Episode 313: TR(with walls) -20168.000 | TT 17915.999 | TS 1000
# Episode 314: TR(without walls) 1634.000 | TT 17944.983 | TS 498
# Episode 315: TR(with walls) -14974.000 | TT 18003.414 | TS 1000
# Episode 316: TR(without walls) -65200.000 | TT 18061.956 | TS 1000
# Episode 317: TR(with walls) -5969.000 | TT 18120.224 | TS 1000
# Episode 318: TR(without walls) -35800.000 | TT 18178.475 | TS 1000
# Episode 319: TR(with walls) 1910.000 | TT 18190.936 | TS 213
# Episode 320: TR(with walls) -6574.000 | ER(with wall) -164479.200 | ER(without wall) -64694.400 | TT 18249.214 | WC 18313.039 | TS 1000
# Episode 321: TR(without walls) -12600.000 | TT 18371.139 | TS 1000
# Episode 322: TR(without walls) -43800.000 | TT 18429.328 | TS 1000
# Episode 323: TR(without walls) -5000.000 | TT 18487.519 | TS 1000
# Episode 324: TR(without walls) -9184.000 | TT 18545.556 | TS 1000
# Episode 325: TR(without walls) -7972.000 | TT 18603.747 | TS 1000
# Episode 326: TR(with walls) -21084.000 | TT 18661.857 | TS 1000
# Episode 327: TR(without walls) -984.000 | TT 18720.137 | TS 1000
# Episode 328: TR(without walls) 1750.000 | TT 18742.389 | TS 380
# Episode 329: TR(with walls) -29767.000 | TT 18800.749 | TS 1000
# Episode 330: TR(with walls) -49375.000 | TT 18859.057 | TS 1000
# Episode 331: TR(with walls) -2167.000 | TT 18917.039 | TS 1000
# Episode 332: TR(without walls) 1686.000 | TT 18942.815 | TS 446
# Episode 333: TR(without walls) -52584.000 | TT 19001.330 | TS 1000
# Episode 334: TR(without walls) -4171.000 | TT 19059.824 | TS 1000
# Episode 335: TR(with walls) -19086.000 | TT 19118.300 | TS 1000
# Episode 336: TR(with walls) -3167.000 | TT 19176.428 | TS 1000
# Episode 337: TR(without walls) -22868.000 | TT 19234.569 | TS 1000
# Episode 338: TR(without walls) -3777.000 | TT 19287.434 | TS 907
# Episode 339: TR(without walls) -3200.000 | TT 19345.765 | TS 1000
# Episode 340: TR(without walls) 1764.000 | ER(with wall) -59616.400 | ER(without wall) -29736.400 | TT 19367.142 | WC 19455.033 | TS 368
# Episode 341: TR(with walls) -24104.000 | TT 19480.336 | TS 434
# Episode 342: TR(with walls) -29787.000 | TT 19538.644 | TS 1000
# Episode 343: TR(without walls) -19389.000 | TT 19596.876 | TS 1000
# Episode 344: TR(with walls) -13972.000 | TT 19655.443 | TS 1000
# Episode 345: TR(with walls) -55274.000 | TT 19715.138 | TS 1000
# Episode 346: TR(with walls) 1540.000 | TT 19749.952 | TS 575
# Episode 347: TR(without walls) 1507.000 | TT 19786.366 | TS 623
# Episode 348: TR(with walls) -30369.000 | TT 19846.140 | TS 1000
# Episode 349: TR(without walls) 1863.000 | TT 19861.493 | TS 261
# Episode 350: TR(without walls) -22192.000 | TT 19919.855 | TS 1000
# Episode 351: TR(with walls) -44540.000 | TT 19970.727 | TS 871
# Episode 352: TR(without walls) -43972.000 | TT 20029.317 | TS 1000
# Episode 353: TR(without walls) -17400.000 | TT 20087.805 | TS 1000
# Episode 354: TR(with walls) -34169.000 | TT 20145.972 | TS 1000
# Episode 355: TR(with walls) -10567.000 | TT 20205.402 | TS 1000
# Episode 356: TR(with walls) -50847.000 | TT 20239.058 | TS 576
# Episode 357: TR(with walls) -969.000 | TT 20297.331 | TS 1000
# Episode 358: TR(without walls) 1780.000 | TT 20318.024 | TS 352
# Episode 359: TR(without walls) -12400.000 | TT 20376.109 | TS 1000
# Episode 360: TR(with walls) -31574.000 | ER(with wall) -117295.400 | ER(without wall) -34996.600 | TT 20434.234 | WC 20516.943 | TS 1000
# Episode 361: TR(without walls) -40986.000 | TT 20575.053 | TS 1000
# Episode 362: TR(with walls) -31671.000 | TT 20633.171 | TS 1000
# Episode 363: TR(with walls) -28079.000 | TT 20691.742 | TS 1000
# Episode 364: TR(with walls) -6393.000 | TT 20745.809 | TS 925
# Episode 365: TR(with walls) -34175.000 | TT 20803.978 | TS 1000
# Episode 366: TR(with walls) -50025.000 | TT 20836.212 | TS 555
# Episode 367: TR(with walls) -6360.000 | TT 20888.271 | TS 892
# Episode 368: TR(without walls) -10868.000 | TT 20946.544 | TS 1000
# Episode 369: TR(without walls) -23586.000 | TT 21004.757 | TS 1000
# Episode 370: TR(with walls) -17768.000 | TT 21062.676 | TS 1000
# Episode 371: TR(without walls) -12967.000 | TT 21120.973 | TS 1000
# Episode 372: TR(with walls) -40981.000 | TT 21179.147 | TS 1000
# Episode 373: TR(without walls) 1825.000 | TT 21195.632 | TS 287
# Episode 374: TR(with walls) -17670.000 | TT 21254.171 | TS 1000
# Episode 375: TR(with walls) 1686.000 | TT 21279.883 | TS 442
# Episode 376: TR(with walls) -2767.000 | TT 21338.039 | TS 1000
# Episode 377: TR(without walls) 1328.000 | TT 21384.790 | TS 804
# Episode 378: TR(without walls) -68984.000 | TT 21442.891 | TS 1000
# Episode 379: TR(without walls) -13000.000 | TT 21501.153 | TS 1000
# Episode 380: TR(with walls) -32179.000 | ER(with wall) -962.200 | ER(without wall) -991.800 | TT 21559.370 | WC 21639.026 | TS 1000
# Episode 381: TR(without walls) -43000.000 | TT 21697.351 | TS 1000
# Episode 382: TR(without walls) -868.000 | TT 21755.903 | TS 1000
# Episode 383: TR(without walls) 1490.000 | TT 21793.266 | TS 642
# Episode 384: TR(with walls) -71172.000 | TT 21851.614 | TS 1000
# Episode 385: TR(without walls) -25868.000 | TT 21909.801 | TS 1000
# Episode 386: TR(with walls) -23185.000 | TT 21967.675 | TS 1000
# Episode 387: TR(with walls) -32369.000 | TT 22025.744 | TS 1000
# Episode 388: TR(without walls) -33375.000 | TT 22083.814 | TS 1000
# Episode 389: TR(with walls) 1709.000 | TT 22107.954 | TS 413
# Episode 390: TR(with walls) -19771.000 | TT 22166.087 | TS 1000
# Episode 391: TR(with walls) 2054.000 | TT 22169.378 | TS 58
# Episode 392: TR(with walls) -24072.000 | TT 22227.413 | TS 1000
# Episode 393: TR(without walls) -27772.000 | TT 22285.343 | TS 1000
# Episode 394: TR(with walls) -18172.000 | TT 22343.346 | TS 1000
# Episode 395: TR(with walls) -41774.000 | TT 22401.298 | TS 1000
# Episode 396: TR(without walls) -30000.000 | TT 22459.482 | TS 1000
# Episode 397: TR(without walls) -38000.000 | TT 22517.310 | TS 1000
# Episode 398: TR(with walls) 2107.000 | TT 22517.779 | TS 9
# Episode 399: TR(without walls) 1712.000 | TT 22542.154 | TS 420
# Episode 400: TR(with walls) -15589.000 | ER(with wall) -53757.200 | ER(without wall) -56869.200 | TT 22600.088 | WC 22686.935 | TS 1000
# Episode 401: TR(without walls) -27400.000 | TT 22745.163 | TS 1000
# Episode 402: TR(without walls) -978.000 | TT 22803.455 | TS 1000
# Episode 403: TR(without walls) -11974.000 | TT 22861.444 | TS 1000
# Episode 404: TR(with walls) -46769.000 | TT 22919.718 | TS 1000
# Episode 405: TR(without walls) -29195.000 | TT 22978.009 | TS 1000
# Episode 406: TR(with walls) -48172.000 | TT 23036.140 | TS 1000
# Episode 407: TR(without walls) -8972.000 | TT 23094.165 | TS 1000
# Episode 408: TR(with walls) -118888.000 | TT 23151.737 | TS 1000
# Episode 409: TR(with walls) -17272.000 | TT 23210.034 | TS 1000
# Episode 410: TR(without walls) -20586.000 | TT 23268.126 | TS 1000
# Episode 411: TR(with walls) -42971.000 | TT 23325.996 | TS 1000
# Episode 412: TR(without walls) -5384.000 | TT 23384.332 | TS 1000
# Episode 413: TR(with walls) -968.000 | TT 23442.692 | TS 1000
# Episode 414: TR(without walls) -25972.000 | TT 23500.892 | TS 1000
# Episode 415: TR(with walls) -22090.000 | TT 23559.417 | TS 1000
# Episode 416: TR(without walls) -29800.000 | TT 23617.746 | TS 1000
# Episode 417: TR(with walls) -31468.000 | TT 23676.265 | TS 1000
# Episode 418: TR(without walls) -16772.000 | TT 23734.324 | TS 1000
# Episode 419: TR(without walls) -18573.000 | TT 23792.315 | TS 1000
# Episode 420: TR(without walls) -1570.000 | ER(with wall) -193139.600 | ER(without wall) -173025.200 | TT 23850.689 | WC 23931.230 | TS 1000
# Episode 421: TR(with walls) -26368.000 | TT 23989.472 | TS 1000
# Episode 422: TR(without walls) -21382.000 | TT 24047.876 | TS 1000
# Episode 423: TR(with walls) -25068.000 | TT 24106.402 | TS 1000
# Episode 424: TR(without walls) -24000.000 | TT 24164.869 | TS 1000
# Episode 425: TR(without walls) -13200.000 | TT 24223.303 | TS 1000
# Episode 426: TR(with walls) 1903.000 | TT 24236.538 | TS 225
# Episode 427: TR(with walls) -18384.000 | TT 24294.945 | TS 1000
# Episode 428: TR(with walls) -38385.000 | TT 24353.473 | TS 1000
# Episode 429: TR(without walls) -1000.000 | TT 24411.982 | TS 1000
# Episode 430: TR(without walls) -41374.000 | TT 24470.727 | TS 1000
# Episode 431: TR(with walls) -2742.000 | TT 24509.822 | TS 671
# Episode 432: TR(without walls) -972.000 | TT 24568.103 | TS 1000
# Episode 433: TR(with walls) -34769.000 | TT 24626.164 | TS 1000
# Episode 434: TR(with walls) -31172.000 | TT 24684.654 | TS 1000
# Episode 435: TR(without walls) -58184.000 | TT 24742.968 | TS 1000
# Episode 436: TR(without walls) -35984.000 | TT 24801.065 | TS 1000
# Episode 437: TR(with walls) -31584.000 | TT 24859.626 | TS 1000
# Episode 438: TR(with walls) -16569.000 | TT 24917.844 | TS 1000
# Episode 439: TR(without walls) -70600.000 | TT 24976.298 | TS 1000
# Episode 440: TR(without walls) -12973.000 | ER(with wall) -356.800 | ER(without wall) -989.400 | TT 25034.797 | WC 25115.873 | TS 1000
# Episode 441: TR(without walls) -17995.000 | TT 25174.542 | TS 1000
# Episode 442: TR(with walls) -22570.000 | TT 25232.954 | TS 1000
# Episode 443: TR(without walls) -14198.000 | TT 25291.628 | TS 1000
# Episode 444: TR(with walls) -18038.000 | TT 25336.816 | TS 770
# Episode 445: TR(without walls) -20384.000 | TT 25395.335 | TS 1000
# Episode 446: TR(with walls) -21272.000 | TT 25453.768 | TS 1000
# Episode 447: TR(without walls) -3600.000 | TT 25512.279 | TS 1000
# Episode 448: TR(with walls) -972.000 | TT 25570.978 | TS 1000
# Episode 449: TR(with walls) -68868.000 | TT 25629.554 | TS 1000
# Episode 450: TR(with walls) -42571.000 | TT 25687.624 | TS 1000
# Episode 451: TR(with walls) -63375.000 | TT 25745.987 | TS 1000
# Episode 452: TR(without walls) -1000.000 | TT 25804.668 | TS 1000
# Episode 453: TR(with walls) -66666.000 | TT 25863.081 | TS 996
# Episode 454: TR(without walls) -21000.000 | TT 25921.485 | TS 1000
# Episode 455: TR(with walls) -871.000 | TT 25979.722 | TS 1000
# Episode 456: TR(without walls) -7000.000 | TT 26038.068 | TS 1000
# Episode 457: TR(without walls) -6585.000 | TT 26096.660 | TS 1000
# Episode 458: TR(with walls) 1922.000 | TT 26107.679 | TS 190
# Episode 459: TR(with walls) -18971.000 | TT 26165.866 | TS 1000
# Episode 460: TR(with walls) -36058.000 | ER(with wall) -314.200 | ER(without wall) -992.600 | TT 26211.802 | WC 26285.581 | TS 788
# Episode 461: TR(with walls) -36588.000 | TT 26343.786 | TS 1000
# Episode 462: TR(with walls) 1900.000 | TT 26356.997 | TS 225
# Episode 463: TR(with walls) 1928.000 | TT 26368.603 | TS 202
# Episode 464: TR(without walls) -967.000 | TT 26427.023 | TS 1000
# Episode 465: TR(with walls) -50672.000 | TT 26485.796 | TS 1000
# Episode 466: TR(with walls) -71378.000 | TT 26544.295 | TS 1000
# Episode 467: TR(with walls) -52991.000 | TT 26602.573 | TS 1000
# Episode 468: TR(with walls) -66779.000 | TT 26660.885 | TS 1000
# Episode 469: TR(with walls) -25187.000 | TT 26719.063 | TS 1000
# Episode 470: TR(with walls) -34376.000 | TT 26777.525 | TS 1000
# Episode 471: TR(without walls) -14972.000 | TT 26835.860 | TS 1000
# Episode 472: TR(with walls) -22168.000 | TT 26894.347 | TS 1000
# Episode 473: TR(with walls) -22982.000 | TT 26952.982 | TS 1000
# Episode 474: TR(without walls) -56784.000 | TT 27011.520 | TS 1000
# Episode 475: TR(without walls) -33572.000 | TT 27070.178 | TS 1000
# Episode 476: TR(with walls) -56984.000 | TT 27128.745 | TS 1000
# Episode 477: TR(with walls) -54367.000 | TT 27187.510 | TS 1000
# Episode 478: TR(with walls) -55268.000 | TT 27246.138 | TS 1000
# Episode 479: TR(with walls) -66371.000 | TT 27304.440 | TS 1000
# Episode 480: TR(with walls) -78288.000 | ER(with wall) -148856.000 | ER(without wall) -996.800 | TT 27362.562 | WC 27451.391 | TS 1000
# Episode 481: TR(without walls) -38400.000 | TT 27509.868 | TS 1000
# Episode 482: TR(with walls) -32940.000 | TT 27559.627 | TS 852
# Episode 483: TR(without walls) -14115.000 | TT 27574.006 | TS 246
# Episode 484: TR(with walls) -96568.000 | TT 27632.438 | TS 1000
# Episode 485: TR(without walls) -53061.000 | TT 27690.082 | TS 986
# Episode 486: TR(with walls) -8199.000 | TT 27697.570 | TS 131
# Episode 487: TR(without walls) -18600.000 | TT 27756.061 | TS 1000
# Episode 488: TR(with walls) -48868.000 | TT 27814.465 | TS 1000
# Episode 489: TR(without walls) -14200.000 | TT 27872.915 | TS 1000
# Episode 490: TR(with walls) -85070.000 | TT 27931.604 | TS 1000
# Episode 491: TR(with walls) -45071.000 | TT 27990.385 | TS 1000
# Episode 492: TR(without walls) -871.000 | TT 28049.011 | TS 1000
# Episode 493: TR(without walls) -2984.000 | TT 28107.597 | TS 1000
# Episode 494: TR(with walls) -63571.000 | TT 28166.113 | TS 1000
# Episode 495: TR(with walls) 781.000 | TT 28198.052 | TS 545
# Episode 496: TR(with walls) -67872.000 | TT 28256.474 | TS 1000
# Episode 497: TR(with walls) -50980.000 | TT 28315.002 | TS 1000
# Episode 498: TR(with walls) -4992.000 | TT 28333.685 | TS 317
# Episode 499: TR(without walls) -2600.000 | TT 28391.984 | TS 1000
# Episode 500: TR(with walls) -154668.000 | ER(with wall) -5257.000 | ER(without wall) -994.400 | TT 28449.538 | WC 28537.613 | TS 1000
# Episode 501: TR(without walls) -47784.000 | TT 28595.861 | TS 1000
# Episode 502: TR(with walls) 1162.000 | TT 28615.913 | TS 345
# Episode 503: TR(without walls) 1922.000 | TT 28628.065 | TS 210
# Episode 504: TR(with walls) -37849.000 | TT 28684.776 | TS 979
# Episode 505: TR(without walls) -11172.000 | TT 28744.407 | TS 1000
# Episode 506: TR(without walls) -31000.000 | TT 28803.158 | TS 1000
# Episode 507: TR(with walls) 2067.000 | TT 28806.012 | TS 50
# Episode 508: TR(with walls) -14574.000 | TT 28864.944 | TS 1000
# Episode 509: TR(with walls) -8584.000 | TT 28923.689 | TS 1000
# Episode 510: TR(without walls) -868.000 | TT 28982.151 | TS 1000
# Episode 511: TR(with walls) -62773.000 | TT 29040.665 | TS 1000
# Episode 512: TR(without walls) -39400.000 | TT 29099.167 | TS 1000
# Episode 513: TR(without walls) -8582.000 | TT 29157.629 | TS 1000
# Episode 514: TR(without walls) -996.000 | TT 29215.958 | TS 1000
# Episode 515: TR(without walls) -22584.000 | TT 29274.141 | TS 1000
# Episode 516: TR(without walls) -2400.000 | TT 29332.799 | TS 1000
# Episode 517: TR(with walls) -54969.000 | TT 29398.271 | TS 1000
# Episode 518: TR(with walls) -12823.000 | TT 29439.033 | TS 553
# Episode 519: TR(without walls) -40400.000 | TT 29512.617 | TS 1000
# Episode 520: TR(with walls) -54790.000 | ER(with wall) -149113.400 | ER(without wall) 154.800 | TT 29586.805 | WC 29665.420 | TS 1000
# Episode 521: TR(with walls) -45974.000 | TT 29739.773 | TS 1000
# Episode 522: TR(with walls) -44853.000 | TT 29812.051 | TS 962
# Episode 523: TR(without walls) -17000.000 | TT 29885.888 | TS 1000
# Episode 524: TR(with walls) -39728.000 | TT 29918.758 | TS 449
# Episode 525: TR(with walls) -66384.000 | TT 29992.253 | TS 1000
# Episode 526: TR(with walls) -3279.000 | TT 30036.131 | TS 606
# Episode 527: TR(with walls) -89882.000 | TT 30108.958 | TS 1000
# Episode 528: TR(with walls) -38972.000 | TT 30182.225 | TS 1000
# Episode 529: TR(without walls) -12986.000 | TT 30255.017 | TS 1000
# Episode 530: TR(with walls) -1299.000 | TT 30315.656 | TS 831
# Episode 531: TR(without walls) -32972.000 | TT 30388.735 | TS 1000
# Episode 532: TR(without walls) -979.000 | TT 30462.382 | TS 1000
# Episode 533: TR(with walls) -19740.000 | TT 30526.991 | TS 872
# Episode 534: TR(without walls) -71200.000 | TT 30600.372 | TS 1000
# Episode 535: TR(with walls) -54468.000 | TT 30674.564 | TS 1000
# Episode 536: TR(with walls) -23371.000 | TT 30748.567 | TS 1000
# Episode 537: TR(with walls) -19074.000 | TT 30827.750 | TS 1000
# Episode 538: TR(without walls) -21800.000 | TT 30902.443 | TS 1000
# Episode 539: TR(without walls) -8167.000 | TT 30976.235 | TS 1000
# Episode 540: TR(without walls) -985.000 | ER(with wall) -39303.000 | ER(without wall) -183673.400 | TT 31049.897 | WC 31145.017 | TS 1000
# Episode 541: TR(with walls) -38947.000 | TT 31209.701 | TS 877
# Episode 542: TR(with walls) -969.000 | TT 31283.535 | TS 1000
# Episode 543: TR(with walls) -50871.000 | TT 31357.050 | TS 1000
# Episode 544: TR(with walls) -37969.000 | TT 31430.264 | TS 1000
# Episode 545: TR(with walls) -38172.000 | TT 31503.664 | TS 1000
# Episode 546: TR(with walls) -36167.000 | TT 31577.768 | TS 1000
# Episode 547: TR(without walls) -3000.000 | TT 31651.909 | TS 1000
# Episode 548: TR(with walls) -38770.000 | TT 31724.985 | TS 1000
# Episode 549: TR(with walls) -64371.000 | TT 31798.267 | TS 1000
# Episode 550: TR(without walls) -26374.000 | TT 31871.725 | TS 1000
# Episode 551: TR(with walls) -33870.000 | TT 31946.730 | TS 1000
# Episode 552: TR(without walls) -19600.000 | TT 32020.762 | TS 1000
# Episode 553: TR(with walls) -15068.000 | TT 32094.288 | TS 1000
# Episode 554: TR(without walls) -1000.000 | TT 32168.766 | TS 1000
# Episode 555: TR(without walls) -38200.000 | TT 32242.438 | TS 1000
# Episode 556: TR(without walls) -2600.000 | TT 32316.282 | TS 1000
# Episode 557: TR(without walls) -7600.000 | TT 32390.738 | TS 1000
# Episode 558: TR(without walls) -972.000 | TT 32465.119 | TS 1000
# Episode 559: TR(with walls) -15021.000 | TT 32505.434 | TS 550
# Episode 560: TR(without walls) -11468.000 | ER(with wall) -58981.000 | ER(without wall) 175.200 | TT 32580.004 | WC 32638.100 | TS 1000
# Episode 561: TR(with walls) -7740.000 | TT 32687.267 | TS 672
# Episode 562: TR(without walls) -31872.000 | TT 32760.636 | TS 1000
# Episode 563: TR(with walls) -44383.000 | TT 32833.525 | TS 1000
# Episode 564: TR(with walls) -38572.000 | TT 32906.820 | TS 1000
# Episode 565: TR(with walls) -14377.000 | TT 32980.854 | TS 1000
# Episode 566: TR(without walls) -33772.000 | TT 33054.307 | TS 1000
# Episode 567: TR(with walls) -15197.000 | TT 33091.725 | TS 512
# Episode 568: TR(with walls) -52071.000 | TT 33165.376 | TS 1000
# Episode 569: TR(without walls) -2972.000 | TT 33239.356 | TS 1000
# Episode 570: TR(without walls) -19000.000 | TT 33312.976 | TS 1000
# Episode 571: TR(without walls) -25800.000 | TT 33387.426 | TS 1000
# Episode 572: TR(with walls) -62882.000 | TT 33460.915 | TS 1000
# Episode 573: TR(without walls) -22584.000 | TT 33534.422 | TS 1000
# Episode 574: TR(with walls) -36578.000 | TT 33607.319 | TS 1000
# Episode 575: TR(with walls) -25796.000 | TT 33680.798 | TS 1000
# Episode 576: TR(without walls) -48400.000 | TT 33754.119 | TS 1000
# Episode 577: TR(with walls) -35176.000 | TT 33834.651 | TS 1000
# Episode 578: TR(with walls) -41072.000 | TT 33915.748 | TS 1000
# Episode 579: TR(with walls) -4841.000 | TT 33961.130 | TS 572
# Episode 580: TR(without walls) -3972.000 | ER(with wall) -3354.800 | ER(without wall) -984.000 | TT 34023.667 | WC 34102.764 | TS 1000
# Episode 581: TR(without walls) -15772.000 | TT 34156.830 | TS 1000
# Episode 582: TR(with walls) 1079.000 | TT 34193.285 | TS 653
# Episode 583: TR(with walls) -39386.000 | TT 34244.468 | TS 1000
# Episode 584: TR(with walls) -45773.000 | TT 34299.651 | TS 1000
# Episode 585: TR(with walls) -16686.000 | TT 34353.599 | TS 1000
# Episode 586: TR(without walls) -38373.000 | TT 34408.810 | TS 1000
# Episode 587: TR(with walls) -44572.000 | TT 34479.334 | TS 1000
# Episode 588: TR(without walls) -972.000 | TT 34533.782 | TS 1000
# Episode 589: TR(with walls) -49068.000 | TT 34590.434 | TS 1000
# Episode 590: TR(with walls) -79787.000 | TT 34642.117 | TS 1000
# Episode 591: TR(with walls) -21480.000 | TT 34700.426 | TS 1000
# Episode 592: TR(without walls) -23372.000 | TT 34781.306 | TS 1000
# Episode 593: TR(without walls) -10984.000 | TT 34861.632 | TS 1000
# Episode 594: TR(without walls) -28784.000 | TT 34942.375 | TS 1000
# Episode 595: TR(with walls) -869.000 | TT 35022.848 | TS 1000
# Episode 596: TR(with walls) -34791.000 | TT 35097.855 | TS 1000
# Episode 597: TR(with walls) -10545.000 | TT 35170.083 | TS 873
# Episode 598: TR(with walls) 1960.000 | TT 35184.192 | TS 170
# Episode 599: TR(with walls) -37659.000 | TT 35266.105 | TS 982
# Episode 600: TR(without walls) -21776.000 | ER(with wall) -14837.000 | ER(without wall) -997.200 | TT 35349.345 | WC 35453.591 | TS 1000
# Episode 601: TR(without walls) -868.000 | TT 35524.465 | TS 1000
# Episode 602: TR(with walls) -23769.000 | TT 35584.126 | TS 1000
# Episode 603: TR(with walls) -38274.000 | TT 35654.528 | TS 1000
# Episode 604: TR(without walls) -41200.000 | TT 35733.377 | TS 1000
# Episode 605: TR(with walls) -1972.000 | TT 35813.007 | TS 1000
# Episode 606: TR(with walls) -55072.000 | TT 35900.513 | TS 1000
# Episode 607: TR(without walls) -3189.000 | TT 35994.870 | TS 1000
# Episode 608: TR(with walls) -55468.000 | TT 36089.828 | TS 1000
# Episode 609: TR(with walls) -27973.000 | TT 36180.321 | TS 1000
# Episode 610: TR(with walls) 1405.000 | TT 36243.809 | TS 723
# Episode 611: TR(with walls) -34376.000 | TT 36344.861 | TS 1000
# Episode 612: TR(without walls) -26400.000 | TT 36462.821 | TS 1000
# Episode 613: TR(without walls) -868.000 | TT 36601.368 | TS 1000
# Episode 614: TR(without walls) -972.000 | TT 36720.910 | TS 1000
# Episode 615: TR(with walls) -63372.000 | TT 36866.104 | TS 1000
# Episode 616: TR(without walls) -18178.000 | TT 36937.193 | TS 500
# Episode 617: TR(with walls) 1803.000 | TT 36980.610 | TS 326
# Episode 618: TR(with walls) -6068.000 | TT 37097.478 | TS 1000
# Episode 619: TR(with walls) -8770.000 | TT 37199.389 | TS 902
# Episode 620: TR(without walls) -25974.000 | ER(with wall) -31162.000 | ER(without wall) -974.000 | TT 37333.209 | WC 37499.906 | TS 1000
# Episode 621: TR(without walls) -972.000 | TT 37651.984 | TS 1000
# Episode 622: TR(with walls) -42172.000 | TT 37788.807 | TS 1000
# Episode 623: TR(with walls) -6674.000 | TT 37929.680 | TS 1000
# Episode 624: TR(with walls) -981.000 | TT 38063.993 | TS 1000
# Episode 625: TR(without walls) -10600.000 | TT 38216.311 | TS 1000
# Episode 626: TR(without walls) -868.000 | TT 38355.048 | TS 1000
# Episode 627: TR(without walls) -59800.000 | TT 38487.307 | TS 1000
# Episode 628: TR(with walls) -37668.000 | TT 38607.822 | TS 1000
# Episode 629: TR(without walls) -7176.000 | TT 38725.891 | TS 1000
# Episode 630: TR(with walls) -870.000 | TT 38848.089 | TS 1000
# Episode 631: TR(without walls) -31400.000 | TT 38976.169 | TS 1000
# Episode 632: TR(with walls) -64374.000 | TT 39086.509 | TS 1000
# Episode 633: TR(without walls) -45000.000 | TT 39180.799 | TS 1000
# Episode 634: TR(with walls) -1720.000 | TT 39182.938 | TS 26
# Episode 635: TR(with walls) -10367.000 | TT 39276.401 | TS 1000
# Episode 636: TR(with walls) -15577.000 | TT 39373.400 | TS 1000
# Episode 637: TR(with walls) -18870.000 | TT 39474.831 | TS 1000
# Episode 638: TR(without walls) -68400.000 | TT 39575.746 | TS 1000
# Episode 639: TR(without walls) -984.000 | TT 39670.745 | TS 1000
# Episode 640: TR(without walls) -12000.000 | ER(with wall) -926.600 | ER(without wall) -990.200 | TT 39765.739 | WC 39881.546 | TS 1000
# Episode 641: TR(without walls) 1420.000 | TT 39949.121 | TS 712
# Episode 642: TR(with walls) -984.000 | TT 40034.824 | TS 1000
# Episode 643: TR(with walls) -3967.000 | TT 40115.934 | TS 1000
# Episode 644: TR(with walls) -34479.000 | TT 40197.211 | TS 1000
# Episode 645: TR(without walls) -6600.000 | TT 40290.631 | TS 1000
# Episode 646: TR(with walls) -14847.000 | TT 40378.163 | TS 961
# Episode 647: TR(without walls) -52984.000 | TT 40464.390 | TS 1000
# Episode 648: TR(without walls) -56800.000 | TT 40550.511 | TS 1000
# Episode 649: TR(without walls) -48373.000 | TT 40641.894 | TS 1000
# Episode 650: TR(with walls) -2369.000 | TT 40732.405 | TS 1000
# Episode 651: TR(without walls) -12600.000 | TT 40817.506 | TS 1000
# Episode 652: TR(with walls) -50472.000 | TT 40909.373 | TS 1000
# Episode 653: TR(with walls) 1915.000 | TT 40926.296 | TS 199
# Episode 654: TR(with walls) -5814.000 | TT 40990.233 | TS 742
# Episode 655: TR(with walls) -33768.000 | TT 41072.422 | TS 1000
# Episode 656: TR(with walls) -24968.000 | TT 41153.308 | TS 1000
# Episode 657: TR(with walls) -15469.000 | TT 41237.374 | TS 1000
# Episode 658: TR(without walls) -1000.000 | TT 41327.384 | TS 1000
# Episode 659: TR(without walls) -22784.000 | TT 41410.561 | TS 1000
# Episode 660: TR(without walls) -21784.000 | ER(with wall) -486.600 | ER(without wall) -991.200 | TT 41491.189 | WC 41599.511 | TS 1000
# Episode 661: TR(with walls) -876.000 | TT 41682.079 | TS 1000
# Episode 662: TR(without walls) -972.000 | TT 41760.171 | TS 1000
# Episode 663: TR(without walls) -19600.000 | TT 41838.452 | TS 1000
# Episode 664: TR(without walls) -6584.000 | TT 41917.125 | TS 1000
# Episode 665: TR(without walls) -41383.000 | TT 41997.673 | TS 1000
# Episode 666: TR(with walls) -28572.000 | TT 42078.232 | TS 1000
# Episode 667: TR(without walls) -35800.000 | TT 42155.507 | TS 1000
# Episode 668: TR(with walls) -3979.000 | TT 42237.243 | TS 1000
# Episode 669: TR(with walls) -874.000 | TT 42314.058 | TS 1000
# Episode 670: TR(with walls) -9272.000 | TT 42390.351 | TS 1000
# Episode 671: TR(without walls) -1000.000 | TT 42468.944 | TS 1000
# Episode 672: TR(without walls) -14200.000 | TT 42547.037 | TS 1000
# Episode 673: TR(without walls) -12000.000 | TT 42624.260 | TS 1000
# Episode 674: TR(without walls) -21374.000 | TT 42701.726 | TS 1000
# Episode 675: TR(with walls) -36986.000 | TT 42780.663 | TS 1000
# Episode 676: TR(without walls) -980.000 | TT 42858.212 | TS 1000
# Episode 677: TR(with walls) -37769.000 | TT 42935.052 | TS 1000
# Episode 678: TR(without walls) -6784.000 | TT 43012.612 | TS 1000
# Episode 679: TR(with walls) -2881.000 | TT 43090.137 | TS 1000
# Episode 680: TR(with walls) -75468.000 | ER(with wall) -965.600 | ER(without wall) -986.200 | TT 43168.460 | WC 43270.908 | TS 1000
# Episode 681: TR(with walls) -24181.000 | TT 43347.647 | TS 1000
# Episode 682: TR(without walls) -986.000 | TT 43425.320 | TS 1000
# Episode 683: TR(without walls) -48800.000 | TT 43502.861 | TS 1000
# Episode 684: TR(with walls) -4367.000 | TT 43579.832 | TS 1000
# Episode 685: TR(without walls) -4808.000 | TT 43621.183 | TS 540
# Episode 686: TR(without walls) -3788.000 | TT 43698.655 | TS 1000
# Episode 687: TR(without walls) -48974.000 | TT 43776.587 | TS 1000
# Episode 688: TR(with walls) -48790.000 | TT 43854.051 | TS 1000
# Episode 689: TR(without walls) -49200.000 | TT 43931.493 | TS 1000
# Episode 690: TR(with walls) -99967.000 | TT 44009.976 | TS 1000
# Episode 691: TR(without walls) -9400.000 | TT 44088.769 | TS 1000
# Episode 692: TR(with walls) -6668.000 | TT 44166.135 | TS 1000
# Episode 693: TR(with walls) -69384.000 | TT 44244.017 | TS 1000
# Episode 694: TR(with walls) -37576.000 | TT 44321.271 | TS 1000
# Episode 695: TR(without walls) -8986.000 | TT 44399.034 | TS 1000
# Episode 696: TR(with walls) -42572.000 | TT 44476.215 | TS 1000
# Episode 697: TR(without walls) -987.000 | TT 44553.884 | TS 1000
# Episode 698: TR(without walls) -10574.000 | TT 44630.959 | TS 1000
# Episode 699: TR(with walls) -58390.000 | TT 44708.315 | TS 1000
# Episode 700: TR(without walls) -984.000 | ER(with wall) -322.600 | ER(without wall) -992.800 | TT 44785.503 | WC 44879.633 | TS 1000
# Episode 701: TR(with walls) 2054.000 | TT 44885.435 | TS 78
# Episode 702: TR(without walls) -984.000 | TT 44964.676 | TS 1000
# Episode 703: TR(with walls) -37268.000 | TT 45042.379 | TS 1000
# Episode 704: TR(with walls) -31268.000 | TT 45119.695 | TS 1000
# Episode 705: TR(with walls) -36869.000 | TT 45200.186 | TS 1000
# Episode 706: TR(with walls) -58909.000 | TT 45265.189 | TS 834
# Episode 707: TR(with walls) -20670.000 | TT 45342.857 | TS 1000
# Episode 708: TR(with walls) -2369.000 | TT 45424.036 | TS 1000
# ...
# Episode 747: TR(with walls) -53875.000 | TT 48479.451 | TS 1000
# Episode 748: TR(with walls) -974.000 | TT 48555.732 | TS 1000
# Episode 749: TR(without walls) -13992.000 | TT 48632.089 | TS 1000
# Episode 750: TR(without walls) -33772.000 | TT 48708.592 | TS 1000
# Episode 751: TR(without walls) -972.000 | TT 48787.021 | TS 1000
# Episode 752: TR(with walls) 1752.000 | TT 48816.374 | TS 380
# Episode 753: TR(without walls) -21396.000 | TT 48893.670 | TS 1000
# Episode 754: TR(without walls) -972.000 | TT 48971.875 | TS 1000
# Episode 755: TR(without walls) -868.000 | TT 49049.255 | TS 1000
# Episode 756: TR(without walls) -47972.000 | TT 49125.883 | TS 1000
# Episode 757: TR(without walls) -57200.000 | TT 49204.533 | TS 1000
# Episode 758: TR(with walls) -968.000 | TT 49281.606 | TS 1000
# Episode 759: TR(without walls) -24200.000 | TT 49359.924 | TS 1000
# Episode 760: TR(without walls) -972.000 | ER(with wall) -439.400 | ER(without wall) -990.400 | TT 49436.647 | WC 49534.901 | TS 1000
# Episode 761: TR(with walls) -8871.000 | TT 49611.684 | TS 1000
# Episode 762: TR(with walls) -58784.000 | TT 49689.918 | TS 1000
# Episode 763: TR(without walls) -1000.000 | TT 49766.339 | TS 1000
# Episode 764: TR(without walls) -62400.000 | TT 49843.204 | TS 1000
# Episode 765: TR(without walls) -1000.000 | TT 49920.218 | TS 1000
# Episode 766: TR(with walls) -19282.000 | TT 49996.897 | TS 1000
# Episode 767: TR(with walls) -39673.000 | TT 50073.712 | TS 1000
# Episode 768: TR(without walls) -34869.000 | TT 50151.498 | TS 1000
# Episode 769: TR(with walls) 701.000 | TT 50200.035 | TS 631
# Episode 770: TR(with walls) -974.000 | TT 50277.198 | TS 1000
# Episode 771: TR(with walls) 1549.000 | TT 50322.486 | TS 581
# Episode 772: TR(with walls) -17541.000 | TT 50389.253 | TS 871
# Episode 773: TR(with walls) -35068.000 | TT 50466.242 | TS 1000
# Episode 774: TR(without walls) -984.000 | TT 50543.744 | TS 1000
# Episode 775: TR(without walls) -976.000 | TT 50621.721 | TS 1000
# Episode 776: TR(with walls) -10268.000 | TT 50699.229 | TS 1000
# Episode 777: TR(without walls) -974.000 | TT 50776.174 | TS 1000
# Episode 778: TR(with walls) -17769.000 | TT 50853.782 | TS 1000
# Episode 779: TR(without walls) -974.000 | TT 50931.243 | TS 1000
# Episode 780: TR(with walls) -34284.000 | ER(with wall) -901.600 | ER(without wall) -997.000 | TT 51008.772 | WC 51112.157 | TS 1000
# Episode 781: TR(with walls) -972.000 | TT 51189.108 | TS 1000
# Episode 782: TR(without walls) -105000.000 | TT 51266.901 | TS 1000
# Episode 783: TR(without walls) -868.000 | TT 51344.883 | TS 1000
# Episode 784: TR(without walls) -57200.000 | TT 51422.110 | TS 1000
# Episode 785: TR(without walls) -4600.000 | TT 51499.830 | TS 1000
# Episode 786: TR(without walls) -987.000 | TT 51577.238 | TS 1000
# Episode 787: TR(with walls) -13068.000 | TT 51654.486 | TS 1000
# Episode 788: TR(without walls) -50984.000 | TT 51733.110 | TS 1000
# Episode 789: TR(without walls) -29800.000 | TT 51810.968 | TS 1000
# Episode 790: TR(without walls) -59973.000 | TT 51888.482 | TS 1000
# Episode 791: TR(without walls) -10200.000 | TT 51967.397 | TS 1000
# Episode 792: TR(without walls) -15889.000 | TT 52045.424 | TS 1000
# Episode 793: TR(with walls) -60064.000 | TT 52105.223 | TS 782
# Episode 794: TR(without walls) -1000.000 | TT 52181.951 | TS 1000
# Episode 795: TR(without walls) -1000.000 | TT 52258.651 | TS 1000
# Episode 796: TR(with walls) -66879.000 | TT 52336.028 | TS 1000
# Episode 797: TR(without walls) -972.000 | TT 52414.431 | TS 1000
# Episode 798: TR(with walls) -51863.000 | TT 52491.192 | TS 995
# Episode 799: TR(with walls) -20080.000 | TT 52568.155 | TS 1000
# Episode 800: TR(with walls) -870.000 | ER(with wall) -921.800 | ER(without wall) -994.600 | TT 52645.498 | WC 52745.942 | TS 1000
# Episode 801: TR(with walls) -38167.000 | TT 52824.188 | TS 1000
# Episode 802: TR(without walls) -33984.000 | TT 52902.320 | TS 1000
# Episode 803: TR(without walls) -32790.000 | TT 52979.494 | TS 1000
# Episode 804: TR(with walls) -969.000 | TT 53056.372 | TS 1000
# Episode 805: TR(without walls) -5372.000 | TT 53133.728 | TS 1000
# Episode 806: TR(without walls) -974.000 | TT 53211.785 | TS 1000
# Episode 807: TR(without walls) -972.000 | TT 53290.180 | TS 1000
# Episode 808: TR(with walls) -16129.000 | TT 53325.087 | TS 454
# Episode 809: TR(with walls) -991.000 | TT 53403.458 | TS 1000
# Episode 810: TR(with walls) -47668.000 | TT 53479.627 | TS 1000
# Episode 811: TR(without walls) -3000.000 | TT 53557.773 | TS 1000
# Episode 812: TR(without walls) -51584.000 | TT 53634.819 | TS 1000
# Episode 813: TR(with walls) -5868.000 | TT 53712.613 | TS 1000
# Episode 814: TR(without walls) -984.000 | TT 53789.031 | TS 1000
# Episode 815: TR(with walls) -1573.000 | TT 53865.691 | TS 1000
# Episode 816: TR(with walls) 1999.000 | TT 53875.527 | TS 131
# Episode 817: TR(with walls) -973.000 | TT 53952.550 | TS 1000
# Episode 818: TR(without walls) -49374.000 | TT 54029.279 | TS 1000
# Episode 819: TR(without walls) -21384.000 | TT 54106.918 | TS 1000
# Episode 820: TR(without walls) -5190.000 | ER(with wall) -943.000 | ER(without wall) -992.200 | TT 54184.657 | WC 54287.993 | TS 1000
# Episode 821: TR(without walls) -71800.000 | TT 54365.265 | TS 1000
# Episode 822: TR(with walls) -61984.000 | TT 54442.756 | TS 1000
# Episode 823: TR(without walls) -14400.000 | TT 54520.388 | TS 1000
# Episode 824: TR(without walls) -4200.000 | TT 54598.052 | TS 1000
# Episode 825: TR(with walls) 1998.000 | TT 54608.478 | TS 134
# Episode 826: TR(with walls) -11068.000 | TT 54686.664 | TS 1000
# Episode 827: TR(with walls) -23775.000 | TT 54763.599 | TS 1000
# Episode 828: TR(with walls) -37488.000 | TT 54840.097 | TS 1000
# Episode 829: TR(with walls) -40669.000 | TT 54917.113 | TS 1000
# Episode 830: TR(with walls) -81868.000 | TT 54994.352 | TS 1000
# Episode 831: TR(with walls) -13671.000 | TT 55071.357 | TS 1000
# Episode 832: TR(with walls) 1635.000 | TT 55107.345 | TS 476
# Episode 833: TR(without walls) -1000.000 | TT 55184.042 | TS 1000
# Episode 834: TR(with walls) -870.000 | TT 55261.017 | TS 1000
# Episode 835: TR(with walls) -1439.000 | TT 55319.440 | TS 768
# Episode 836: TR(with walls) -52878.000 | TT 55396.426 | TS 1000
# Episode 837: TR(with walls) -10871.000 | TT 55473.287 | TS 1000
# Episode 838: TR(with walls) -3272.000 | TT 55551.413 | TS 1000
# Episode 839: TR(without walls) -12572.000 | TT 55628.397 | TS 1000
# Episode 840: TR(with walls) 1269.000 | ER(with wall) -10695.200 | ER(without wall) -983.600 | TT 55694.302 | WC 55794.717 | TS 863
# Episode 841: TR(without walls) -984.000 | TT 55873.670 | TS 1000
# Episode 842: TR(without walls) -972.000 | TT 55927.200 | TS 1000
# Episode 843: TR(with walls) -3527.000 | TT 55960.797 | TS 655
# Episode 844: TR(with walls) -96184.000 | TT 56012.260 | TS 1000
# Episode 845: TR(without walls) -10799.000 | TT 56067.319 | TS 1000
# Episode 846: TR(with walls) 1827.000 | TT 56084.692 | TS 293
# Episode 847: TR(with walls) -49968.000 | TT 56149.433 | TS 1000
# Episode 848: TR(without walls) -51200.000 | TT 56226.302 | TS 1000
# Episode 849: TR(without walls) -984.000 | TT 56277.461 | TS 1000
# Episode 850: TR(with walls) -870.000 | TT 56328.473 | TS 1000
# Episode 851: TR(without walls) -872.000 | TT 56379.984 | TS 1000
# Episode 852: TR(without walls) -974.000 | TT 56437.435 | TS 1000
# Episode 853: TR(with walls) -9824.000 | TT 56465.026 | TS 549
# Episode 854: TR(with walls) -45268.000 | TT 56516.631 | TS 1000
# Episode 855: TR(with walls) -33172.000 | TT 56569.724 | TS 1000
# Episode 856: TR(with walls) 1779.000 | TT 56587.328 | TS 353
# Episode 857: TR(with walls) -3639.000 | TT 56605.709 | TS 371
# Episode 858: TR(without walls) -974.000 | TT 56655.572 | TS 1000
# Episode 859: TR(without walls) -1000.000 | TT 56706.648 | TS 1000
# Episode 860: TR(with walls) 1222.000 | ER(with wall) -435.000 | ER(without wall) -1000.000 | TT 56752.205 | WC 56819.160 | TS 906
# Episode 861: TR(with walls) -5280.000 | TT 56883.534 | TS 1000
# Episode 862: TR(without walls) -1000.000 | TT 56966.117 | TS 1000
# Episode 863: TR(with walls) -875.000 | TT 57048.401 | TS 1000
# Episode 864: TR(with walls) -870.000 | TT 57131.271 | TS 1000
# Episode 865: TR(with walls) -36468.000 | TT 57213.632 | TS 1000
# Episode 866: TR(with walls) -982.000 | TT 57294.012 | TS 1000
# Episode 867: TR(without walls) -32367.000 | TT 57375.857 | TS 1000
# Episode 868: TR(without walls) -73200.000 | TT 57457.692 | TS 1000
# Episode 869: TR(without walls) -1000.000 | TT 57539.763 | TS 1000
# Episode 870: TR(with walls) -26374.000 | TT 57624.861 | TS 1000
# Episode 871: TR(without walls) -80200.000 | TT 57715.307 | TS 1000
# Episode 872: TR(without walls) -972.000 | TT 57806.518 | TS 1000
# Episode 873: TR(with walls) -20869.000 | TT 57891.198 | TS 1000
# Episode 874: TR(with walls) -974.000 | TT 57975.135 | TS 1000
# Episode 875: TR(without walls) -2584.000 | TT 58056.681 | TS 1000
# Episode 876: TR(without walls) -872.000 | TT 58138.125 | TS 1000
# Episode 877: TR(with walls) -41386.000 | TT 58221.288 | TS 1000
# Episode 878: TR(without walls) -48187.000 | TT 58305.119 | TS 1000
# Episode 879: TR(with walls) -63798.000 | TT 58364.143 | TS 713
# Episode 880: TR(with walls) 1819.000 | ER(with wall) -11800.800 | ER(without wall) -995.200 | TT 58389.379 | WC 58490.146 | TS 304
# Episode 881: TR(with walls) -21484.000 | TT 58530.379 | TS 410
# Episode 882: TR(without walls) -13600.000 | TT 58618.034 | TS 1000
# Episode 883: TR(without walls) -984.000 | TT 58701.385 | TS 1000
# Episode 884: TR(with walls) -51170.000 | TT 58759.011 | TS 702
# Episode 885: TR(with walls) -993.000 | TT 58844.863 | TS 1000
# Episode 886: TR(with walls) -24930.000 | TT 58882.723 | TS 454
# Episode 887: TR(with walls) -985.000 | TT 58965.681 | TS 1000
# Episode 888: TR(with walls) -21268.000 | TT 59052.305 | TS 1000
# Episode 889: TR(with walls) -39687.000 | TT 59144.162 | TS 1000
# Episode 890: TR(without walls) -1000.000 | TT 59230.183 | TS 1000
# Episode 891: TR(without walls) -3572.000 | TT 59320.708 | TS 1000
# Episode 892: TR(without walls) -3800.000 | TT 59407.323 | TS 1000
# Episode 893: TR(without walls) -1000.000 | TT 59493.251 | TS 1000
# Episode 894: TR(with walls) -36184.000 | TT 59583.848 | TS 1000
# Episode 895: TR(with walls) -871.000 | TT 59668.873 | TS 1000
# Episode 896: TR(without walls) -1000.000 | TT 59750.598 | TS 1000
# Episode 897: TR(with walls) -19268.000 | TT 59835.611 | TS 1000
# Episode 898: TR(without walls) -29384.000 | TT 59917.110 | TS 1000
# Episode 899: TR(without walls) -22972.000 | TT 59999.278 | TS 1000
# Episode 900: TR(without walls) -1000.000 | ER(with wall) -93817.400 | ER(without wall) -32545.400 | TT 60085.892 | WC 60183.452 | TS 1000
# Episode 901: TR(with walls) 1872.000 | TT 60205.152 | TS 253
# Episode 902: TR(with walls) -871.000 | TT 60290.152 | TS 1000
# Episode 903: TR(with walls) -874.000 | TT 60374.479 | TS 1000
# Episode 904: TR(with walls) -24469.000 | TT 60459.053 | TS 1000
# Episode 905: TR(without walls) -987.000 | TT 60544.982 | TS 1000
# Episode 906: TR(without walls) -63800.000 | TT 60630.723 | TS 1000
# Episode 907: TR(without walls) -982.000 | TT 60714.807 | TS 1000
# Episode 908: TR(with walls) -992.000 | TT 60801.819 | TS 1000
# Episode 909: TR(with walls) -23572.000 | TT 60884.250 | TS 1000
# Episode 910: TR(without walls) -32372.000 | TT 60963.088 | TS 1000
# Episode 911: TR(with walls) -24772.000 | TT 61041.846 | TS 1000
# Episode 912: TR(with walls) -994.000 | TT 61125.123 | TS 1000
# Episode 913: TR(with walls) 1462.000 | TT 61183.328 | TS 665
# Episode 914: TR(without walls) -18986.000 | TT 61264.513 | TS 1000
# Episode 915: TR(with walls) -32068.000 | TT 61328.531 | TS 1000
# Episode 916: TR(with walls) 543.000 | TT 61375.075 | TS 785
# Episode 917: TR(without walls) -5184.000 | TT 61431.685 | TS 1000
# Episode 918: TR(with walls) -20470.000 | TT 61489.135 | TS 1000
# Episode 919: TR(without walls) -986.000 | TT 61541.996 | TS 1000
# Episode 920: TR(without walls) -972.000 | ER(with wall) -59738.200 | ER(without wall) -188116.400 | TT 61599.725 | WC 61682.953 | TS 1000
# Episode 921: TR(with walls) -2064.000 | TT 61736.264 | TS 790
# Episode 922: TR(without walls) -19000.000 | TT 61802.855 | TS 1000
# Episode 923: TR(without walls) -1000.000 | TT 61862.256 | TS 1000
# Episode 924: TR(with walls) -870.000 | TT 61921.949 | TS 1000
# Episode 925: TR(without walls) -1000.000 | TT 61986.198 | TS 1000
# Episode 926: TR(with walls) -2145.000 | TT 62016.479 | TS 472
# Episode 927: TR(with walls) -14268.000 | TT 62105.459 | TS 1000
# Episode 928: TR(with walls) -4080.000 | TT 62201.940 | TS 1000
# Episode 929: TR(without walls) -1000.000 | TT 62299.298 | TS 1000
# Episode 930: TR(with walls) -5170.000 | TT 62396.254 | TS 1000
# Episode 931: TR(without walls) -1000.000 | TT 62492.045 | TS 1000
# Episode 932: TR(with walls) 2103.000 | TT 62493.652 | TS 17
# Episode 933: TR(with walls) -6442.000 | TT 62566.722 | TS 765
# Episode 934: TR(with walls) -16670.000 | TT 62662.401 | TS 1000
# Episode 935: TR(without walls) -984.000 | TT 62750.550 | TS 1000
# Episode 936: TR(without walls) -1000.000 | TT 62811.809 | TS 1000
# Episode 937: TR(without walls) -1000.000 | TT 62864.325 | TS 1000
# Episode 938: TR(without walls) -4800.000 | TT 62923.287 | TS 1000
# Episode 939: TR(without walls) -9784.000 | TT 62978.878 | TS 1000
# Episode 940: TR(with walls) -10445.000 | ER(with wall) -14698.200 | ER(without wall) -997.200 | TT 62999.113 | WC 63074.795 | TS 372
# Episode 941: TR(with walls) 1224.000 | TT 63124.383 | TS 906
# Episode 942: TR(with walls) 2041.000 | TT 63129.306 | TS 86
# Episode 943: TR(with walls) -24586.000 | TT 63184.900 | TS 1000
# Episode 944: TR(without walls) -972.000 | TT 63241.464 | TS 1000
# Episode 945: TR(without walls) -973.000 | TT 63300.511 | TS 1000
# Episode 946: TR(without walls) -871.000 | TT 63354.418 | TS 1000
# Episode 947: TR(without walls) -18000.000 | TT 63405.319 | TS 1000
# Episode 948: TR(with walls) -9573.000 | TT 63457.752 | TS 1000
# Episode 949: TR(with walls) -868.000 | TT 63512.567 | TS 1000
# Episode 950: TR(without walls) -105577.000 | TT 63567.611 | TS 1000
# Episode 951: TR(without walls) -984.000 | TT 63620.604 | TS 1000
# Episode 952: TR(with walls) -982.000 | TT 63675.969 | TS 1000
# Episode 953: TR(with walls) 2060.000 | TT 63680.418 | TS 72
# Episode 954: TR(with walls) -59868.000 | TT 63734.681 | TS 1000
# Episode 955: TR(without walls) -71000.000 | TT 63787.611 | TS 1000
# Episode 956: TR(without walls) -996.000 | TT 63847.112 | TS 1000
# Episode 957: TR(with walls) -870.000 | TT 63905.370 | TS 1000
# Episode 958: TR(without walls) -1000.000 | TT 63999.788 | TS 1000
# Episode 959: TR(with walls) -880.000 | TT 64083.336 | TS 1000
# Episode 960: TR(with walls) -37988.000 | ER(with wall) -438.000 | ER(without wall) -996.800 | TT 64138.679 | WC 64217.361 | TS 1000
# Episode 961: TR(without walls) -1000.000 | TT 64276.354 | TS 1000
# Episode 962: TR(without walls) -35600.000 | TT 64335.833 | TS 1000
# Episode 963: TR(with walls) -2776.000 | TT 64397.507 | TS 1000
# Episode 964: TR(with walls) -870.000 | TT 64494.854 | TS 1000
# Episode 965: TR(with walls) -978.000 | TT 64590.859 | TS 1000
# Episode 966: TR(without walls) -972.000 | TT 64681.432 | TS 1000
# Episode 967: TR(without walls) 1448.000 | TT 64722.575 | TS 684
# Episode 968: TR(with walls) -23471.000 | TT 64777.794 | TS 1000
# Episode 969: TR(without walls) -972.000 | TT 64862.746 | TS 1000
# Episode 970: TR(without walls) -32400.000 | TT 64930.346 | TS 1000
# Episode 971: TR(without walls) -12200.000 | TT 64987.044 | TS 1000
# Episode 972: TR(without walls) -1000.000 | TT 65070.734 | TS 1000
# Episode 973: TR(without walls) -1000.000 | TT 65139.429 | TS 1000
# Episode 974: TR(with walls) 1935.000 | TT 65155.245 | TS 194
# Episode 975: TR(with walls) -982.000 | TT 65218.809 | TS 1000
# Episode 976: TR(with walls) 1717.000 | TT 65244.935 | TS 410
# Episode 977: TR(with walls) -29376.000 | TT 65309.056 | TS 1000
# Episode 978: TR(with walls) -5787.000 | TT 65372.703 | TS 1000
# Episode 979: TR(without walls) -6774.000 | TT 65433.031 | TS 1000
# Episode 980: TR(without walls) -2367.000 | ER(with wall) -38218.400 | ER(without wall) -993.200 | TT 65510.897 | WC 65614.988 | TS 1000
# Stop signal detected at episode 981. Saving and exiting.

# %% [markdown]
# ### Training and Evaluation Plots

# %%
def smooth(data, window=10):
    return uniform_filter1d(data, size=window)

# --- episode axes --- 
train_eps  = np.arange(1, len(d3qnPerTrainRewardsList) + 1)
eval_eps   = np.arange(20, 20 * len(d3qnPerEvalRewardsList1) + 1, 20)

fig, axes = plt.subplots(2, 3, figsize=(16, 8))
fig.suptitle("D3QN-PER (Final Model) Training and Evaluation Diagnostics (Smoothed)", fontsize=14, fontweight='bold')

plots = [
    (axes[0, 0], train_eps, d3qnPerTrainRewardsList,  "Training Reward per Episode", "Episode", "Reward", "tab:blue"),
    (axes[0, 1], train_eps, d3qnPerTrainTimeList, "Cumm. Train Time per Episode", "Episode", "Time (s)", "tab:orange"),
    (axes[0, 2], train_eps, d3qnPerTotalStepsList, "Total Steps per Episode", "Episode", "Steps", "tab:green"),
    (axes[1, 0], eval_eps,  d3qnPerEvalRewardsList1, "Eval Reward (with walls) over Episode", "Episode", "Reward", "tab:red"),
    (axes[1, 1], eval_eps,  d3qnPerEvalRewardsList2, "Eval Reward (without walls) over Episode", "Episode", "Reward", "tab:purple"),
    (axes[1, 2], eval_eps,  d3qnPerWallClockTimeList, "Wall Clock Time over Episode", "Episode", "Wall Time (s)", "tab:brown"),
]

for ax, x, raw, title, xlabel, ylabel, color in plots:
    raw_arr = np.array(raw)
    win = max(5, len(raw_arr) // 20)          # adaptive window
    sm  = smooth(raw_arr, window=win)

    ax.plot(x, raw_arr, alpha=0.25, color=color, linewidth=0.8, label="Raw")
    ax.plot(x, sm,      color=color, linewidth=1.8, label=f"Smoothed (w={win})")
    ax.set_title(title, fontsize=11)
    ax.set_xlabel(xlabel, fontsize=9)
    ax.set_ylabel(ylabel, fontsize=9)
    ax.legend(fontsize=8)
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig("d3qn_per_diagnostics.png", dpi=150, bbox_inches='tight')
plt.show()
