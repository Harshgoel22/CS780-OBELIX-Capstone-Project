# %%
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: numpy in c:\users\hgoel\anaconda3\lib\site-packages (from -r ../requirements.txt (line 1)) (2.2.6)
# Requirement already satisfied: opencv-python in c:\users\hgoel\anaconda3\lib\site-packages (from -r ../requirements.txt (line 2)) (4.12.0.88)

# %%
import torch
print(torch.version.cuda)
print(torch.cuda.is_available())
# Out:
# 12.8
# True

# %%
import sys
import importlib
sys.path.append("..")

# Import your modules first
import helper
import obelix
import algorithms.knowledge_distillation as kd_agent
import configurations.config_eval_kd1 as config
import algorithms.d3qn_lstm_rep_bh_gae_dual as model

# Reload them to pick up any changes
importlib.reload(helper)
importlib.reload(obelix)
importlib.reload(kd_agent)
importlib.reload(config)
importlib.reload(model)
# Out:
# device used:  cuda
# device used:  cuda
# <module 'algorithms.d3qn_lstm_rep_bh_gae_dual' from 'c:\\Users\\hgoel\\MTech_Resources\\DRL\\Capstone_Project\\CS780-OBELIX\\run_scripts\\..\\algorithms\\d3qn_lstm_rep_bh_gae_dual.py'>

# %%
from helper import plotQuantity
from obelix import OBELIX
from algorithms.knowledge_distillation import KnowledgeDistillationAgent
from configurations.config_eval_kd1 import config
from algorithms.d3qn_lstm_rep_bh_gae_dual import KnowledgeNet

# %%
print(config)
# Out:
# {'seed': 333, 'gamma': 0.99, 'bufferSize': 1000000, 'batchSize': 32, 'optimizerFn': <class 'torch.optim.adam.Adam'>, 'optimLR': 0.0001, 'MAX_TRAIN_EPISODES': 500, 'MAX_EVAL_EPISODES': 5, 'explorationStrategyTrainFn': <function selectEpsilonGreedyActionREP_NOISY at 0x0000017481039580>, 'explorationStrategyEvalFn': <function selectGreedyActionREP_COMP at 0x0000017481039440>, 'max_steps': 1000, 'epsilon': 0.98, 'eps_decay_strategy': [('linear', {'s': 0, 'e': 200, 'ival': 1.0, 'fval': 0.3}), ('exponential', {'s': 201, 'e': 499, 'ival': 0.3, 'fval': 0.02})], 'device': device(type='cuda'), 'beta': 0.3, 'f_hDim': [324, 256], 'lstm_hDim': 128, 'model_path': '../model_weights/model_weights_eval_kd1', 'seq_len': 40, 'burn_in': 10, 'minSamples': 40, 'for_hDim': [224, 128], 'inv_hDim': [224, 128], 'noise_std': 0.05, 'clip_eps': 0.2, 'entropy_coef': 0.01, 'forward_coef': 0.1, 'inverse_coef': 0.04, 'action_dim': 5, 'state_dim': 18, 'tau': 0.2, 'updateTargetFrequency': 20, 'kl_coef': 0.12}

# %%
env1 = OBELIX(
    scaling_factor=5,
    arena_size=500,
    max_steps=1000,
    wall_obstacles=True,
    difficulty=3,
    box_speed=4,
)

env2 = OBELIX(
    scaling_factor=5,
    arena_size=500,
    max_steps=1000,
    wall_obstacles=False,
    difficulty=3,
    box_speed=4,
)

teachers_path = f'{config['model_path']}/teachers'
teachers = []
for i in range(4):
    model = KnowledgeNet(
        f_hDim=[324, 256],
        lstm_hDim=128,
        for_hDim=[224, 128],
        inv_hDim=[224, 128]
    )
    wpath = f"{teachers_path}/model{i+1}.pth"
    model.load_state_dict(torch.load(wpath, map_location="cpu"))
    teachers.append(model)

KD_PPO_Agent = KnowledgeDistillationAgent(env1, env2, teachers, config)

# %%
(kdTrainRewardList, kdTrainTimeList, kdEvalRewardsList1, 
kdEvalRewardsList2, kdWallClockTimeList, kdTotalStepsList,
klList, entropyList, lossList) = KD_PPO_Agent.runKDAgent()
# Out:
# Episode 1: TR(with walls) -43769.000 | TT 5.479 | TS 701
# Episode 2: TR(with walls) -99967.000 | TT 13.465 | TS 1000
# Episode 3: TR(without walls) 1884.000 | TT 15.568 | TS 248
# Episode 4: TR(without walls) -35268.000 | TT 23.662 | TS 1000
# Episode 5: TR(without walls) -4068.000 | TT 31.915 | TS 1000
# Episode 6: TR(without walls) 2097.000 | TT 32.144 | TS 26
# Episode 7: TR(with walls) -6521.000 | TT 35.794 | TS 453
# Episode 8: TR(with walls) -57376.000 | TT 43.728 | TS 1000
# Episode 9: TR(with walls) -112069.000 | TT 51.560 | TS 1000
# Episode 10: TR(without walls) -35468.000 | TT 59.735 | TS 1000
# Episode 11: TR(with walls) -48969.000 | TT 67.469 | TS 1000
# Episode 12: TR(without walls) 1495.000 | TT 72.724 | TS 635
# Episode 13: TR(without walls) -41172.000 | TT 89.141 | TS 1000
# Episode 14: TR(with walls) -21170.000 | TT 104.473 | TS 1000
# Episode 15: TR(without walls) -35268.000 | TT 120.243 | TS 1000
# Episode 16: TR(with walls) -5468.000 | TT 136.087 | TS 1000
# Episode 17: TR(with walls) -42937.000 | TT 149.350 | TS 867
# Episode 18: TR(with walls) -62384.000 | TT 164.768 | TS 1000
# Episode 19: TR(with walls) -36084.000 | TT 180.354 | TS 1000
# Episode 20: TR(with walls) -79169.000 | ER(with wall) -317.400 | ER(without wall) -911.400 | TT 195.966 | WC 337.610 | TS 1000
# Episode 21: TR(without walls) 2101.000 | TT 337.957 | TS 27
# Episode 22: TR(with walls) -45167.000 | TT 353.130 | TS 1000
# Episode 23: TR(with walls) -9678.000 | TT 356.519 | TS 203
# Episode 24: TR(with walls) -28168.000 | TT 372.840 | TS 1000
# Episode 25: TR(with walls) 1942.000 | TT 375.559 | TS 176
# Episode 26: TR(without walls) 1854.000 | TT 379.910 | TS 273
# Episode 27: TR(with walls) -17872.000 | TT 396.900 | TS 1000
# Episode 28: TR(without walls) -64068.000 | TT 413.906 | TS 1000
# Episode 29: TR(with walls) 719.000 | TT 417.400 | TS 213
# Episode 30: TR(with walls) -1446.000 | TT 420.444 | TS 174
# Episode 31: TR(without walls) -17276.000 | TT 438.080 | TS 1000
# Episode 32: TR(without walls) -15575.000 | TT 455.818 | TS 1000
# Episode 33: TR(without walls) -25776.000 | TT 473.394 | TS 1000
# Episode 34: TR(with walls) -39086.000 | TT 490.702 | TS 1000
# Episode 35: TR(without walls) -56176.000 | TT 508.797 | TS 1000
# Episode 36: TR(without walls) 118.000 | TT 512.237 | TS 194
# Episode 37: TR(with walls) -22815.000 | TT 524.939 | TS 745
# Episode 38: TR(with walls) -48771.000 | TT 540.832 | TS 1000
# Episode 39: TR(without walls) -868.000 | TT 556.706 | TS 1000
# Episode 40: TR(without walls) -5027.000 | ER(with wall) -899.000 | ER(without wall) -892.200 | TT 562.480 | WC 695.624 | TS 350
# Episode 41 | step 100 : KL 1.0621409138043723 | Loss 3776309.25 | Entropy 1.0742149273554484
# Episode 41 | step 200 : KL 1.070644332965215 | Loss 2132144.5 | Entropy 1.0209810853004455
# Episode 41 | step 300 : KL 0.9485494395097097 | Loss 2587142.5 | Entropy 1.1425073424975076
# Episode 41 | step 400 : KL 0.6358953485886256 | Loss 2237152.75 | Entropy 1.2408204833666483
# Episode 41 | step 500 : KL 0.5363419542709986 | Loss 2244045.75 | Entropy 1.2946235219637552
# Episode 41 | step 600 : KL 0.364254696170489 | Loss 2074950.75 | Entropy 1.4480254729588826
# Episode 41 | step 700 : KL 0.3183344836036364 | Loss 3271750.0 | Entropy 1.4868892153104147
# Episode 41 | step 800 : KL 0.21564051906267803 | Loss 2604060.0 | Entropy 1.5638640880584718
# Episode 41 | step 900 : KL 0.22452368934949238 | Loss 2060801.25 | Entropy 1.5656978527704875
# Episode 41 | step 1000 : KL 0.17753822524100543 | Loss 2544762.5 | Entropy 1.5754350225130718
# Episode 41: TR(without walls) -11068.000 | TT 788.249 | TS 1000
# Episode 42 | step 100 : KL 0.1661609194551905 | Loss 3000472.0 | Entropy 1.5801626165707907
# Episode 42 | step 200 : KL 0.1796899426728487 | Loss 1546234.25 | Entropy 1.5729765892028809
# Episode 42 | step 300 : KL 0.17783772194137176 | Loss 3020898.75 | Entropy 1.5799030900001525
# Episode 42 | step 400 : KL 0.17429117473463218 | Loss 996370.0625 | Entropy 1.574381907780965
# Episode 42 | step 500 : KL 0.18470517403135697 | Loss 2783194.25 | Entropy 1.5699607928593953
# Episode 42 | step 600 : KL 0.18767915392915407 | Loss 2519570.25 | Entropy 1.5707263231277466
# Episode 42 | step 700 : KL 0.1628617466116945 | Loss 1916785.875 | Entropy 1.5839205861091614
# Episode 42 | step 800 : KL 0.14708555697773892 | Loss 3084747.75 | Entropy 1.5912310123443603
# Episode 42 | step 900 : KL 0.15124200352778036 | Loss 3189106.25 | Entropy 1.5917964259783426
# Episode 42 | step 1000 : KL 0.17687815073877572 | Loss 2576615.5 | Entropy 1.5835985581080119
# Episode 42: TR(without walls) -20883.000 | TT 938.957 | TS 1000
# Episode 43 | step 100 : KL 0.16991972563167412 | Loss 2452653.0 | Entropy 1.577876607577006
# Episode 43 | step 200 : KL 0.1701928885653615 | Loss 1741902.625 | Entropy 1.5865923086802165
# Episode 43 | step 300 : KL 0.14237631810829043 | Loss 1569078.25 | Entropy 1.587220851580302
# Episode 43 | step 400 : KL 0.15457805407543976 | Loss 3382302.25 | Entropy 1.582365127404531
# Episode 43 | step 500 : KL 0.17117426053931314 | Loss 2701939.0 | Entropy 1.5799251794815063
# Episode 43 | step 600 : KL 0.1617607391749819 | Loss 3563468.0 | Entropy 1.5753872513771057
# Episode 43 | step 700 : KL 0.17080512326210737 | Loss 2737081.75 | Entropy 1.5875596006711323
# Episode 43 | step 800 : KL 0.1453111113825192 | Loss 2438507.0 | Entropy 1.597002351284027
# Episode 43 | step 900 : KL 0.12852103629459938 | Loss 3311067.5 | Entropy 1.598208725452423
# Episode 43 | step 1000 : KL 0.14369922367235025 | Loss 4184491.5 | Entropy 1.5922375758488974
# Episode 43: TR(without walls) -32670.000 | TT 1104.623 | TS 1000
# Episode 44 | step 100 : KL 0.1574243330086271 | Loss 2005577.875 | Entropy 1.5823290308316549
# Episode 44 | step 200 : KL 0.11105955634266138 | Loss 4439311.0 | Entropy 1.5827541073163351
# Episode 44 | step 300 : KL 0.11644633176426093 | Loss 1713257.0 | Entropy 1.5841942230860393
# Episode 44 | step 400 : KL 0.11143854471544425 | Loss 1479074.625 | Entropy 1.5814424872398376
# Episode 44 | step 500 : KL 0.12695957385003567 | Loss 2015386.75 | Entropy 1.5739449659983318
# Episode 44 | step 600 : KL 0.13607780672609807 | Loss 2929085.5 | Entropy 1.5689790964126586
# Episode 44 | step 700 : KL 0.15118365759650867 | Loss 2718009.0 | Entropy 1.5710755348205567
# Episode 44 | step 800 : KL 0.14171760566532612 | Loss 1924963.5 | Entropy 1.571446454524994
# Episode 44 | step 900 : KL 0.12268038379649321 | Loss 1283723.875 | Entropy 1.5823668440183003
# Episode 44 | step 1000 : KL 0.14606627598404884 | Loss 1664159.25 | Entropy 1.571198034286499
# Episode 44: TR(with walls) -42172.000 | TT 1261.236 | TS 1000
# Episode 45 | step 100 : KL 0.1512571394443512 | Loss 1429316.75 | Entropy 1.576179019610087
# Episode 45 | step 200 : KL 0.13211383943756422 | Loss 2839724.75 | Entropy 1.5742224017779032
# Episode 45 | step 300 : KL 0.15239316349228224 | Loss 2866531.75 | Entropy 1.5709542632102966
# Episode 45 | step 400 : KL 0.14829102208216985 | Loss 1665345.75 | Entropy 1.5845860759417216
# Episode 45 | step 500 : KL 0.11146177761256695 | Loss 1513621.625 | Entropy 1.5898122628529867
# Episode 45 | step 600 : KL 0.19027037223180135 | Loss 456674.09375 | Entropy 1.5763627926508585
# Episode 45 | step 700 : KL 0.09788496733332673 | Loss 2669748.75 | Entropy 1.5949186086654663
# Episode 45 | step 800 : KL 0.13294054362922908 | Loss 2490422.5 | Entropy 1.5906725843747458
# Episode 45 | step 900 : KL 0.1309316196789344 | Loss 2562229.5 | Entropy 1.5833494385083517
# Episode 45 | step 1000 : KL 0.11489790106813112 | Loss 2598221.75 | Entropy 1.5891299883524577
# Episode 45: TR(with walls) -4869.000 | TT 1439.941 | TS 1000
# Episode 46 | step 100 : KL 0.13472955767065287 | Loss 3483798.25 | Entropy 1.5800193826357523
# Episode 46 | step 200 : KL 0.11346601154655218 | Loss 2451923.75 | Entropy 1.5851142605145772
# Episode 46 | step 300 : KL 0.10099959572156271 | Loss 2384599.0 | Entropy 1.5893051107724507
# Episode 46 | step 400 : KL 0.10533337481319904 | Loss 2116087.75 | Entropy 1.592037053902944
# Episode 46 | step 500 : KL 0.11793898989756903 | Loss 1268498.625 | Entropy 1.5872851332028708
# Episode 46 | step 600 : KL 0.11488366977622112 | Loss 2416127.75 | Entropy 1.5878989338874816
# Episode 46 | step 700 : KL 0.11998721491545439 | Loss 2942929.25 | Entropy 1.5810914754867553
# Episode 46 | step 800 : KL 0.11929164181152979 | Loss 2859888.75 | Entropy 1.5880525787671407
# Episode 46 | step 900 : KL 0.26007484644651413 | Loss 1603985.25 | Entropy 1.4780953486760458
# Episode 46 | step 1000 : KL 0.2877140775322914 | Loss 2857133.25 | Entropy 1.4695239861806233
# Episode 46: TR(with walls) -34268.000 | TT 1603.933 | TS 1000
# Episode 47 | step 100 : KL 0.2737506528695424 | Loss 3118688.5 | Entropy 1.474586284160614
# Episode 47 | step 200 : KL 0.24644237955411274 | Loss 2724105.25 | Entropy 1.4850245555241903
# Episode 47 | step 300 : KL 0.26254923939704894 | Loss 2617553.5 | Entropy 1.4912461479504904
# Episode 47 | step 400 : KL 0.2657166376709938 | Loss 2281423.25 | Entropy 1.4950294137001037
# Episode 47 | step 500 : KL 0.22036685744921367 | Loss 1120034.125 | Entropy 1.5037617762883504
# Episode 47 | step 600 : KL 0.27599994763731955 | Loss 5315105.0 | Entropy 1.5042874733606975
# Episode 47 | step 700 : KL 0.21959845448533694 | Loss 4325012.5 | Entropy 1.5153149922688802
# Episode 47 | step 800 : KL 0.20272454842925072 | Loss 3105476.5 | Entropy 1.5162312308947246
# Episode 47 | step 900 : KL 0.2182522435983022 | Loss 2191972.5 | Entropy 1.51778351465861
# Episode 47: TR(with walls) 1189.000 | TT 1690.847 | TS 942
# Episode 48 | step 100 : KL 0.2166176435848077 | Loss 2645448.75 | Entropy 1.5276215553283692
# Episode 48 | step 200 : KL 0.20642121955752374 | Loss 3344115.25 | Entropy 1.5319015343983968
# Episode 48 | step 300 : KL 0.205424398680528 | Loss 3275290.25 | Entropy 1.5339106440544128
# Episode 48 | step 400 : KL 0.20162158260742824 | Loss 1092521.375 | Entropy 1.5374844868977864
# Episode 48 | step 500 : KL 0.19229542650282383 | Loss 1857411.25 | Entropy 1.5407819588979086
# Episode 48 | step 600 : KL 0.1912510174016158 | Loss 1286358.5 | Entropy 1.545769214630127
# Episode 48 | step 700 : KL 0.19015669152140618 | Loss 2222803.0 | Entropy 1.5482536474863688
# Episode 48 | step 800 : KL 0.18292729606231053 | Loss 1758462.125 | Entropy 1.5513356765111288
# Episode 48 | step 900 : KL 0.1819379578034083 | Loss 2002455.125 | Entropy 1.5552847425142924
# Episode 48 | step 1000 : KL 0.17510747723281384 | Loss 1766450.125 | Entropy 1.557013213634491
# Episode 48: TR(without walls) -2567.000 | TT 1783.645 | TS 1000
# Episode 49: TR(without walls) 1059.000 | TT 1789.638 | TS 67
# Episode 50 | step 100 : KL 0.19050968413551647 | Loss 848262.125 | Entropy 1.557406489054362
# Episode 50 | step 200 : KL 0.17700086360176404 | Loss 1535135.625 | Entropy 1.5581369916598002
# Episode 50 | step 300 : KL 0.17166837342083455 | Loss 4060699.5 | Entropy 1.5598411679267883
# Episode 50 | step 400 : KL 0.16595809298257033 | Loss 2639658.0 | Entropy 1.5608589887619018
# Episode 50 | step 500 : KL 0.16753188719352086 | Loss 2437547.25 | Entropy 1.560455604394277
# Episode 50 | step 600 : KL 0.1636916381617387 | Loss 2458969.75 | Entropy 1.5609381834665934
# Episode 50 | step 700 : KL 0.16988961262007554 | Loss 3517451.25 | Entropy 1.5582857767740885
# Episode 50 | step 800 : KL 0.16319911703467369 | Loss 2882975.5 | Entropy 1.5612653454144796
# Episode 50 | step 900 : KL 0.16142280586063862 | Loss 1663007.375 | Entropy 1.5647929231325786
# Episode 50 | step 1000 : KL 0.1483681104456385 | Loss 1442955.75 | Entropy 1.570805815855662
# Episode 50: TR(without walls) -32977.000 | TT 1882.366 | TS 1000
# Episode 51 | step 100 : KL 0.15419865859051546 | Loss 2140722.0 | Entropy 1.5719401200612386
# Episode 51 | step 200 : KL 0.15230809313555557 | Loss 1243797.5 | Entropy 1.5717808882395425
# Episode 51 | step 300 : KL 0.15362187853703896 | Loss 2140120.25 | Entropy 1.5702294786771138
# Episode 51 | step 400 : KL 0.17771203300605218 | Loss 4437686.0 | Entropy 1.5694326321283976
# Episode 51 | step 500 : KL 0.14975950457155704 | Loss 2868126.0 | Entropy 1.5702279051144918
# Episode 51 | step 600 : KL 0.15369259001066288 | Loss 3051044.75 | Entropy 1.5705607930819194
# Episode 51 | step 700 : KL 0.14871893959740798 | Loss 1566218.5 | Entropy 1.5719978014628093
# Episode 51 | step 800 : KL 0.14997628312557937 | Loss 2327589.75 | Entropy 1.571669352054596
# Episode 51 | step 900 : KL 0.14753926191478967 | Loss 2069446.75 | Entropy 1.572920016447703
# Episode 51 | step 1000 : KL 0.1455513874068856 | Loss 3076571.0 | Entropy 1.5766186118125916
# Episode 51: TR(without walls) -967.000 | TT 1974.480 | TS 1000
# Episode 52 | step 100 : KL 0.11136517698566119 | Loss 3561132.25 | Entropy 1.5779964764912924
# Episode 52 | step 200 : KL 0.13737863370527822 | Loss 3100503.0 | Entropy 1.5808642109235127
# Episode 52 | step 300 : KL 0.11029501321415107 | Loss 1558365.0 | Entropy 1.59042809009552
# Episode 52 | step 400 : KL 0.10091463128725688 | Loss 1196411.75 | Entropy 1.588950252532959
# Episode 52 | step 500 : KL 0.11329831120868523 | Loss 1918853.5 | Entropy 1.5935784816741942
# Episode 52 | step 600 : KL 0.11085895082602898 | Loss 1894854.375 | Entropy 1.597880208492279
# Episode 52 | step 700 : KL 0.07544098924845458 | Loss 1046109.5625 | Entropy 1.601462757587433
# Episode 52 | step 800 : KL 0.09498581731071075 | Loss 1649866.375 | Entropy 1.6023817181587219
# Episode 52 | step 900 : KL 0.0953372448682785 | Loss 1772350.875 | Entropy 1.604047147432963
# Episode 52 | step 1000 : KL 0.07829194200846055 | Loss 2762304.0 | Entropy 1.6068963925043742
# Episode 52: TR(with walls) -36583.000 | TT 2066.794 | TS 1000
# Episode 53 | step 100 : KL 0.07929942335467785 | Loss 1751621.5 | Entropy 1.6068152785301208
# Episode 53 | step 200 : KL 0.07761323584709316 | Loss 1725544.75 | Entropy 1.6081508954366048
# Episode 53 | step 300 : KL 0.07751267965262135 | Loss 3377251.25 | Entropy 1.6081564545631408
# Episode 53 | step 400 : KL 0.07835860082802053 | Loss 1848691.375 | Entropy 1.6082627654075623
# Episode 53 | step 500 : KL 0.0791305563839463 | Loss 1684620.875 | Entropy 1.6076950907707215
# Episode 53 | step 600 : KL 0.08221372474605838 | Loss 1752872.5 | Entropy 1.6063191771507264
# Episode 53 | step 700 : KL 0.10668524726449201 | Loss 1617374.0 | Entropy 1.605405330657959
# Episode 53 | step 800 : KL 0.0822294189594686 | Loss 1763148.125 | Entropy 1.6055278460184732
# Episode 53 | step 900 : KL 0.08379803926994403 | Loss 2267794.0 | Entropy 1.6046642462412517
# Episode 53 | step 1000 : KL 0.08483841663692146 | Loss 2784021.25 | Entropy 1.6036011815071105
# Episode 53: TR(without walls) -2372.000 | TT 2159.490 | TS 1000
# Episode 54 | step 100 : KL 0.08513382975943387 | Loss 2569371.0 | Entropy 1.602704389890035
# Episode 54 | step 200 : KL 0.0861885813375314 | Loss 1389780.5 | Entropy 1.6013111511866251
# Episode 54 | step 300 : KL 0.08718158119979004 | Loss 1331151.0 | Entropy 1.6005356391270955
# Episode 54 | step 400 : KL 0.08950436126130322 | Loss 1529698.375 | Entropy 1.5996022701263428
# Episode 54 | step 500 : KL 0.10301195634528995 | Loss 2380709.0 | Entropy 1.5996200442314148
# Episode 54 | step 600 : KL 0.08947627131516735 | Loss 2657379.75 | Entropy 1.600650143623352
# Episode 54 | step 700 : KL 0.1038295612980922 | Loss 2120291.0 | Entropy 1.5997605800628663
# Episode 54 | step 800 : KL 0.10845488680837055 | Loss 1431866.5 | Entropy 1.5979560414950054
# Episode 54 | step 900 : KL 0.09497378931070367 | Loss 2529348.5 | Entropy 1.5973992149035137
# Episode 54 | step 1000 : KL 0.08651738994133969 | Loss 2961420.25 | Entropy 1.5986737569173177
# Episode 54: TR(without walls) -16868.000 | TT 2251.872 | TS 1000
# Episode 55 | step 100 : KL 0.09278127467259764 | Loss 3001872.5 | Entropy 1.5984686136245727
# Episode 55 | step 200 : KL 0.09360693950826923 | Loss 2059197.875 | Entropy 1.5948973417282104
# Episode 55 | step 300 : KL 0.09827922116965056 | Loss 2684082.0 | Entropy 1.5922399083773295
# Episode 55 | step 400 : KL 0.09529020739719271 | Loss 2451133.75 | Entropy 1.5939094185829163
# Episode 55 | step 500 : KL 0.09083492527715861 | Loss 2508263.0 | Entropy 1.5958186984062195
# Episode 55 | step 600 : KL 0.09820038749215504 | Loss 2250875.25 | Entropy 1.5956952412923178
# Episode 55 | step 700 : KL 0.09647603017898897 | Loss 2903664.75 | Entropy 1.5944823185602823
# Episode 55 | step 800 : KL 0.137248048838228 | Loss 3478683.75 | Entropy 1.592605459690094
# Episode 55 | step 900 : KL 0.09615169105430445 | Loss 1491139.375 | Entropy 1.5914713581403097
# Episode 55 | step 1000 : KL 0.10524229627723496 | Loss 1646862.375 | Entropy 1.590547533830007
# Episode 55: TR(without walls) -26868.000 | TT 2349.599 | TS 1000
# Episode 56 | step 100 : KL 0.1478538000335296 | Loss 2069241.5 | Entropy 1.5898108998934428
# Episode 56 | step 200 : KL 0.11186511162668467 | Loss 3295067.5 | Entropy 1.5857834458351134
# Episode 56 | step 300 : KL 0.15198167158911627 | Loss 2992711.25 | Entropy 1.5867983420689902
# Episode 56 | step 400 : KL 0.11153288017958403 | Loss 2032564.0 | Entropy 1.5861840486526488
# Episode 56 | step 500 : KL 0.11391309394190709 | Loss 2305953.5 | Entropy 1.5845514297485352
# Episode 56 | step 600 : KL 0.12357906425992647 | Loss 1835735.5 | Entropy 1.582860322793325
# Episode 56 | step 700 : KL 0.11433255566904942 | Loss 2258703.75 | Entropy 1.58474543094635
# Episode 56 | step 800 : KL 0.11269914880394935 | Loss 1746378.5 | Entropy 1.5871285835901896
# Episode 56 | step 900 : KL 0.11703813473383586 | Loss 1407447.5 | Entropy 1.5881117979685466
# Episode 56 | step 1000 : KL 0.11104638862113157 | Loss 1983019.0 | Entropy 1.587948211034139
# Episode 56: TR(with walls) -50776.000 | TT 2481.697 | TS 1000
# Episode 57 | step 100 : KL 0.0975330884878834 | Loss 1948532.25 | Entropy 1.5861807823181153
# Episode 57 | step 200 : KL 0.09703457523137331 | Loss 785840.5625 | Entropy 1.5848366181055704
# Episode 57 | step 300 : KL 0.10382479336112738 | Loss 932840.125 | Entropy 1.584784706433614
# Episode 57 | step 400 : KL 0.10318205369015535 | Loss 1505107.75 | Entropy 1.5866323669751485
# Episode 57 | step 500 : KL 0.10339613140871128 | Loss 1414797.0 | Entropy 1.5881738384564719
# Episode 57 | step 600 : KL 0.10223860883464415 | Loss 1453985.375 | Entropy 1.5890735189119976
# Episode 57 | step 700 : KL 0.10618149191141128 | Loss 3300885.75 | Entropy 1.588765283425649
# Episode 57 | step 800 : KL 0.21720351402958235 | Loss 3270078.5 | Entropy 1.539625636736552
# Episode 57 | step 900 : KL 0.20853713378310204 | Loss 2131621.75 | Entropy 1.5359535813331604
# Episode 57 | step 1000 : KL 0.1732631134490172 | Loss 1499049.375 | Entropy 1.5495263775189718
# Episode 57: TR(without walls) -30590.000 | TT 2658.556 | TS 1000
# Episode 58 | step 100 : KL 0.19254045064250627 | Loss 690128.0 | Entropy 1.549176033337911
# Episode 58 | step 200 : KL 0.17163130628565948 | Loss 1726806.875 | Entropy 1.5493309060732523
# Episode 58 | step 300 : KL 0.18923646758000057 | Loss 2559810.75 | Entropy 1.5500691056251525
# Episode 58 | step 400 : KL 0.17986111529171467 | Loss 2532409.75 | Entropy 1.5512587984402975
# Episode 58 | step 500 : KL 0.19134587347507476 | Loss 2493348.25 | Entropy 1.552130365371704
# Episode 58 | step 600 : KL 0.20315166066090265 | Loss 1585152.875 | Entropy 1.5532506704330444
# Episode 58 | step 700 : KL 0.18466071176032225 | Loss 1691265.875 | Entropy 1.5551478107770285
# Episode 58 | step 800 : KL 0.16078508297602337 | Loss 1089318.0 | Entropy 1.5705744822820027
# Episode 58 | step 900 : KL 0.17453441967566807 | Loss 1083342.0 | Entropy 1.5694541136423747
# Episode 58 | step 1000 : KL 0.1614479209606846 | Loss 2088070.375 | Entropy 1.5699652314186097
# Episode 58: TR(with walls) -10770.000 | TT 2835.252 | TS 1000
# Episode 59 | step 100 : KL 0.14250222283105055 | Loss 1296785.0 | Entropy 1.5717551708221436
# Episode 59 | step 200 : KL 0.1715138388176759 | Loss 2046335.25 | Entropy 1.570028018951416
# Episode 59 | step 300 : KL 0.1447103351354599 | Loss 2489739.0 | Entropy 1.5697689692179362
# Episode 59 | step 400 : KL 0.1445646225164334 | Loss 2329983.75 | Entropy 1.5693646629651388
# Episode 59 | step 500 : KL 0.1706321091701587 | Loss 2965555.0 | Entropy 1.5691823283831279
# Episode 59 | step 600 : KL 0.1748072567085425 | Loss 2071499.625 | Entropy 1.5691537698109945
# Episode 59 | step 700 : KL 0.17367605045437812 | Loss 1661468.0 | Entropy 1.568665579954783
# Episode 59 | step 800 : KL 0.18192381033053 | Loss 1996007.375 | Entropy 1.568543843428294
# Episode 59 | step 900 : KL 0.14516823117931685 | Loss 1332352.625 | Entropy 1.5678747495015461
# Episode 59 | step 1000 : KL 0.14889042750000953 | Loss 3022840.25 | Entropy 1.5696988622347514
# Episode 59: TR(with walls) -11967.000 | TT 2939.959 | TS 1000
# Episode 60 | step 100 : KL 0.1753506268064181 | Loss 2339867.0 | Entropy 1.5722268541653952
# Episode 60 | step 200 : KL 0.1466002266854048 | Loss 2461699.5 | Entropy 1.5704593896865844
# Episode 60 | step 300 : KL 0.14662363504370055 | Loss 2319563.5 | Entropy 1.5711079279581706
# Episode 60 | step 400 : KL 0.14768308339019617 | Loss 1426799.25 | Entropy 1.569715925057729
# Episode 60 | step 500 : KL 0.14793935095270475 | Loss 1461870.125 | Entropy 1.5690818905830384
# Episode 60 | step 600 : KL 0.15523026511073112 | Loss 1148450.75 | Entropy 1.571110693613688
# Episode 60 | step 700 : KL 0.14538566172122955 | Loss 2466197.5 | Entropy 1.5718043009440104
# Episode 60 | step 800 : KL 0.14507791623473168 | Loss 1260191.875 | Entropy 1.5662538647651671
# Episode 60 | step 900 : KL 0.1628497422983249 | Loss 2098408.25 | Entropy 1.566666336854299
# Episode 60 | step 1000 : KL 0.15882160315910976 | Loss 3503396.0 | Entropy 1.5797544280687967
# Episode 60: TR(without walls) -868.000 | ER(with wall) -917.600 | ER(without wall) -936.000 | TT 3047.846 | WC 3171.918 | TS 1000
# Episode 61 | step 100 : KL 0.12392283460746209 | Loss 2726930.25 | Entropy 1.5793544411659242
# Episode 61 | step 200 : KL 0.12900550644844772 | Loss 2209121.5 | Entropy 1.5836050192515054
# Episode 61 | step 300 : KL 0.1431370176995794 | Loss 314936.21875 | Entropy 1.576962947845459
# Episode 61 | step 400 : KL 0.15176064651459456 | Loss 2845618.25 | Entropy 1.5871346592903137
# Episode 61 | step 500 : KL 0.1197691415126125 | Loss 2086021.875 | Entropy 1.5849891901016235
# Episode 61 | step 600 : KL 0.14188573583960534 | Loss 1356701.0 | Entropy 1.5854034185409547
# Episode 61 | step 700 : KL 0.10998797565698623 | Loss 773408.9375 | Entropy 1.5864909450213114
# Episode 61 | step 800 : KL 0.12764447157581646 | Loss 2821225.5 | Entropy 1.5810000777244568
# Episode 61: TR(with walls) -11568.000 | TT 3325.035 | TS 891
# Episode 62 | step 100 : KL 0.11283692829310894 | Loss 2503913.75 | Entropy 1.584007942676544
# Episode 62 | step 200 : KL 0.13726816307753326 | Loss 1284202.875 | Entropy 1.5836168964703878
# Episode 62 | step 300 : KL 0.11044683357079824 | Loss 2709040.25 | Entropy 1.5855367541313172
# Episode 62 | step 400 : KL 0.15166018332044284 | Loss 1412618.375 | Entropy 1.5789360602696736
# Episode 62 | step 500 : KL 0.1496997982263565 | Loss 1866147.5 | Entropy 1.5766845663388571
# Episode 62 | step 600 : KL 0.16896947945157686 | Loss 2127472.0 | Entropy 1.5702611645062765
# Episode 62 | step 700 : KL 0.13093808914224306 | Loss 1113247.875 | Entropy 1.5696278134981791
# Episode 62 | step 800 : KL 0.11766906635214885 | Loss 1799582.375 | Entropy 1.5835575024286905
# Episode 62 | step 900 : KL 0.08590839952230453 | Loss 3472936.75 | Entropy 1.6017722805341086
# Episode 62 | step 1000 : KL 0.08434087733427684 | Loss 1768292.25 | Entropy 1.6041105071703592
# Episode 62: TR(with walls) -17668.000 | TT 3484.732 | TS 1000
# Episode 63 | step 100 : KL 0.08890882140646378 | Loss 1135976.0 | Entropy 1.6007063587506611
# Episode 63 | step 200 : KL 0.0908444327612718 | Loss 1068240.625 | Entropy 1.600076961517334
# Episode 63 | step 300 : KL 0.09462150906523069 | Loss 1922399.25 | Entropy 1.599785856405894
# Episode 63 | step 400 : KL 0.1049980130046606 | Loss 1940017.5 | Entropy 1.592606488863627
# Episode 63 | step 500 : KL 0.10590701606124639 | Loss 1927094.25 | Entropy 1.591481351852417
# Episode 63 | step 600 : KL 0.11673643576602141 | Loss 1870651.125 | Entropy 1.5764373103777567
# Episode 63 | step 700 : KL 0.1363891297330459 | Loss 1518101.5 | Entropy 1.56185568968455
# Episode 63 | step 800 : KL 0.13953512981534005 | Loss 2151714.5 | Entropy 1.5674455642700196
# Episode 63 | step 900 : KL 0.12523488563795884 | Loss 2132797.5 | Entropy 1.573848017056783
# Episode 63 | step 1000 : KL 0.1272906040151914 | Loss 2860109.75 | Entropy 1.5726684292157491
# Episode 63: TR(with walls) -46372.000 | TT 3598.592 | TS 1000
# Episode 64 | step 100 : KL 0.12275267640749614 | Loss 2555394.5 | Entropy 1.576793098449707
# Episode 64 | step 200 : KL 0.16827348967393238 | Loss 2541066.25 | Entropy 1.5583539764086405
# Episode 64 | step 300 : KL 0.20239334826668104 | Loss 1984811.25 | Entropy 1.542121962706248
# Episode 64 | step 400 : KL 0.227692216138045 | Loss 2829178.5 | Entropy 1.5365447362263998
# Episode 64 | step 500 : KL 0.24533940677841504 | Loss 2619224.25 | Entropy 1.5335450609525045
# Episode 64 | step 600 : KL 0.21947553977370263 | Loss 1528122.75 | Entropy 1.5370335857073465
# Episode 64 | step 700 : KL 0.23366710171103477 | Loss 1952610.125 | Entropy 1.5386305888493856
# Episode 64 | step 800 : KL 0.193586748590072 | Loss 2603508.75 | Entropy 1.5454636494318643
# Episode 64 | step 900 : KL 0.19396229684352875 | Loss 3062483.75 | Entropy 1.550723954041799
# Episode 64 | step 1000 : KL 0.1801886836687724 | Loss 2207850.75 | Entropy 1.55608385403951
# Episode 64: TR(without walls) -868.000 | TT 3732.898 | TS 1000
# Episode 65 | step 100 : KL 0.18087907135486603 | Loss 1483077.625 | Entropy 1.5622543295224507
# Episode 65 | step 200 : KL 0.1658524636179209 | Loss 1898047.5 | Entropy 1.5681721766789753
# Episode 65 | step 300 : KL 0.21757405350605646 | Loss 1438980.625 | Entropy 1.518752427895864
# Episode 65 | step 400 : KL 0.24899456004301707 | Loss 839132.0 | Entropy 1.516586442788442
# Episode 65 | step 500 : KL 0.17640760267774264 | Loss 2175755.5 | Entropy 1.536863891283671
# Episode 65 | step 600 : KL 0.18607339511315027 | Loss 1681321.75 | Entropy 1.547959307829539
# Episode 65 | step 700 : KL 0.1473750114440918 | Loss 2261451.75 | Entropy 1.555953892072042
# Episode 65 | step 800 : KL 0.13633754389981428 | Loss 988611.875 | Entropy 1.5701563835144043
# Episode 65 | step 900 : KL 0.18421015776693822 | Loss 1882754.625 | Entropy 1.532881494363149
# Episode 65 | step 1000 : KL 0.21205111915866534 | Loss 1636251.375 | Entropy 1.5240189592043558
# Episode 65: TR(with walls) -24177.000 | TT 3891.433 | TS 1000
# Episode 66 | step 100 : KL 0.1847677655518055 | Loss 1713373.5 | Entropy 1.542992321650187
# Episode 66 | step 200 : KL 0.16487937501321237 | Loss 1646840.875 | Entropy 1.5702205379803975
# Episode 66 | step 300 : KL 0.1519939384733637 | Loss 2334285.5 | Entropy 1.583405645688375
# Episode 66 | step 400 : KL 0.17274594257275264 | Loss 1946219.875 | Entropy 1.5656776944796245
# Episode 66 | step 500 : KL 0.1591581060240666 | Loss 2024895.5 | Entropy 1.5682246088981628
# Episode 66 | step 600 : KL 0.18701298125088214 | Loss 1949496.75 | Entropy 1.5461799184481302
# Episode 66 | step 700 : KL 0.21039695739746095 | Loss 1270556.125 | Entropy 1.5511031031608582
# Episode 66 | step 800 : KL 0.20231225118041038 | Loss 2348009.25 | Entropy 1.5365291674931845
# Episode 66 | step 900 : KL 0.18649842975040276 | Loss 1325366.875 | Entropy 1.5560713132222495
# Episode 66 | step 1000 : KL 0.24008625696102778 | Loss 2291961.0 | Entropy 1.5277488708496094
# Episode 66: TR(without walls) -19268.000 | TT 4060.188 | TS 1000
# Episode 67 | step 100 : KL 0.29441878832876683 | Loss 409434.375 | Entropy 1.4780036528905234
# Episode 67 | step 200 : KL 0.4193329585095247 | Loss 4268515.0 | Entropy 1.397370425860087
# Episode 67 | step 300 : KL 0.4841213454802831 | Loss 2807803.0 | Entropy 1.376020642121633
# Episode 67 | step 400 : KL 0.44280764559904734 | Loss 1716800.625 | Entropy 1.4092141429583231
# Episode 67 | step 500 : KL 0.610000818533202 | Loss 1745469.625 | Entropy 1.354125690460205
# Episode 67 | step 600 : KL 0.31146620934208236 | Loss 614125.0 | Entropy 1.4661027113596599
# Episode 67 | step 700 : KL 0.451921958848834 | Loss 1719835.5 | Entropy 1.4157466650009156
# Episode 67 | step 800 : KL 0.33377153364320594 | Loss 1201033.75 | Entropy 1.4735188245773316
# Episode 67 | step 900 : KL 0.7876164878408114 | Loss 2363908.5 | Entropy 1.2905223985513052
# Episode 67 | step 1000 : KL 0.5567099511623382 | Loss 1726479.5 | Entropy 1.3962637464205423
# Episode 67: TR(without walls) -30580.000 | TT 4245.888 | TS 1000
# Episode 68 | step 100 : KL 0.514035142523547 | Loss 2424063.5 | Entropy 1.4147249261538188
# Episode 68 | step 200 : KL 0.6980115737145146 | Loss 1410894.875 | Entropy 1.3407424966494241
# Episode 68 | step 300 : KL 0.6010965477054317 | Loss 1349947.375 | Entropy 1.3749763727188111
# Episode 68 | step 400 : KL 0.6398044656962156 | Loss 2172240.75 | Entropy 1.361392432451248
# Episode 68 | step 500 : KL 0.665517087901632 | Loss 2861133.25 | Entropy 1.3489191691080729
# Episode 68 | step 600 : KL 0.5817882380137841 | Loss 618550.125 | Entropy 1.3858404517173768
# Episode 68 | step 700 : KL 0.7704032093286515 | Loss 1584515.875 | Entropy 1.310760466257731
# Episode 68 | step 800 : KL 0.6797908746947845 | Loss 1726201.875 | Entropy 1.3357119917869569
# Episode 68 | step 900 : KL 0.602784497042497 | Loss 2505033.5 | Entropy 1.3762234648068745
# Episode 68 | step 1000 : KL 0.6432965425153573 | Loss 1521870.5 | Entropy 1.356040632724762
# Episode 68: TR(without walls) -16068.000 | TT 4424.674 | TS 1000
# Episode 69 | step 100 : KL 1.0134857453405857 | Loss 1793686.875 | Entropy 1.1917885690927505
# Episode 69 | step 200 : KL 0.9771744452416897 | Loss 1338075.25 | Entropy 1.2060409585634868
# Episode 69 | step 300 : KL 0.9893453006943067 | Loss 1389756.5 | Entropy 1.1955569247404734
# Episode 69 | step 400 : KL 0.8665831128756205 | Loss 2353003.75 | Entropy 1.247987468043963
# Episode 69 | step 500 : KL 0.6443129914502302 | Loss 977247.25 | Entropy 1.3303767720858255
# Episode 69 | step 600 : KL 0.9428666012982527 | Loss 1729059.625 | Entropy 1.2294044554233552
# Episode 69 | step 700 : KL 1.3481102709968884 | Loss 2451599.5 | Entropy 1.0826200127601624
# Episode 69 | step 800 : KL 1.5257028544942537 | Loss 2204224.0 | Entropy 1.0234110290805498
# Episode 69 | step 900 : KL 1.4381341964006424 | Loss 1398288.875 | Entropy 1.059372474749883
# Episode 69: TR(with walls) -48201.000 | TT 4585.315 | TS 914
# Episode 70 | step 100 : KL 1.1239735201001166 | Loss 2033499.125 | Entropy 1.154306243856748
# Episode 70 | step 200 : KL 1.426930054028829 | Loss 2166063.75 | Entropy 1.0766586035490036
# Episode 70 | step 300 : KL 1.2730845207969348 | Loss 2702687.25 | Entropy 1.108490284283956
# Episode 70 | step 400 : KL 1.4214089155197143 | Loss 1848934.0 | Entropy 1.0517780164877573
# Episode 70 | step 500 : KL 1.584634499748548 | Loss 1128524.125 | Entropy 0.9980359772841135
# Episode 70 | step 600 : KL 1.8079275767008463 | Loss 1506263.5 | Entropy 0.9413694590330124
# Episode 70 | step 700 : KL 1.3883585433165233 | Loss 1501620.5 | Entropy 1.0508524219195048
# Episode 70 | step 800 : KL 1.5472202787796656 | Loss 2526574.5 | Entropy 0.9698861251274745
# Episode 70 | step 900 : KL 1.5988098442554475 | Loss 1330474.75 | Entropy 0.9281944880882899
# Episode 70 | step 1000 : KL 1.7883464256922403 | Loss 1225912.0 | Entropy 0.9216177046298981
# Episode 70: TR(with walls) -49870.000 | TT 4757.987 | TS 1000
# Episode 71 | step 100 : KL 1.8618060688177744 | Loss 2750992.75 | Entropy 0.8925712029139201
# Episode 71 | step 200 : KL 1.8538453221321105 | Loss 1193698.875 | Entropy 0.8730945616960526
# Episode 71 | step 300 : KL 2.412188031276067 | Loss 2312516.0 | Entropy 0.7396991516153018
# Episode 71 | step 400 : KL 2.4939505815505982 | Loss 865540.1875 | Entropy 0.7277151475350062
# Episode 71 | step 500 : KL 2.269452452659607 | Loss 2186705.5 | Entropy 0.7546927432219187
# Episode 71 | step 600 : KL 2.1257707019646963 | Loss 656689.625 | Entropy 0.7690915008385976
# Episode 71 | step 700 : KL 2.7697925686836244 | Loss 1951629.875 | Entropy 0.6397830724716187
# Episode 71 | step 800 : KL 2.536570366223653 | Loss 1655006.25 | Entropy 0.654966402053833
# Episode 71 | step 900 : KL 2.759033660093943 | Loss 1134765.125 | Entropy 0.6058885470032692
# Episode 71 | step 1000 : KL 2.831164824962616 | Loss 2093218.125 | Entropy 0.5857084885239601
# Episode 71: TR(without walls) -33268.000 | TT 4860.674 | TS 1000
# Episode 72 | step 100 : KL 2.6982172608375548 | Loss 2592910.0 | Entropy 0.5775802264610926
# Episode 72 | step 200 : KL 3.179358204205831 | Loss 1886677.875 | Entropy 0.5161073590318362
# Episode 72 | step 300 : KL 3.103908975919088 | Loss 1111952.625 | Entropy 0.503882814447085
# Episode 72 | step 400 : KL 3.3481746713320413 | Loss 1915293.625 | Entropy 0.45767769664525987
# Episode 72 | step 500 : KL 3.5693530241648355 | Loss 1877729.0 | Entropy 0.4171164279182752
# Episode 72 | step 600 : KL 3.7124125719070435 | Loss 983908.25 | Entropy 0.40725800494352976
# Episode 72 | step 700 : KL 3.758753689130147 | Loss 1558016.125 | Entropy 0.3831139822800954
# Episode 72 | step 800 : KL 3.746013077100118 | Loss 1453877.5 | Entropy 0.3763198460141818
# Episode 72 | step 900 : KL 4.055729055404663 | Loss 2283037.75 | Entropy 0.338219523926576
# Episode 72: TR(without walls) 1146.000 | TT 4971.296 | TS 986
# Episode 73 | step 100 : KL 4.223520636558533 | Loss 1150474.875 | Entropy 0.31506746808687847
# Episode 73 | step 200 : KL 4.094989045461019 | Loss 3282839.5 | Entropy 0.3186060130596161
# Episode 73 | step 300 : KL 4.310627770423889 | Loss 1531660.625 | Entropy 0.2924979398647944
# Episode 73 | step 400 : KL 4.454564372698466 | Loss 2839910.0 | Entropy 0.29444032261768976
# Episode 73 | step 500 : KL 4.46051808198293 | Loss 2827301.0 | Entropy 0.2853633463382721
# Episode 73 | step 600 : KL 4.25424816608429 | Loss 2862452.75 | Entropy 0.3145531659324964
# Episode 73 | step 700 : KL 4.679167215029398 | Loss 2588730.25 | Entropy 0.2718931605418523
# Episode 73 | step 800 : KL 4.640999348958333 | Loss 1210813.0 | Entropy 0.3026532828807831
# Episode 73 | step 900 : KL 4.50963994661967 | Loss 2152900.25 | Entropy 0.2934615507721901
# Episode 73 | step 1000 : KL 4.737545339266459 | Loss 2032870.75 | Entropy 0.298336993654569
# Episode 73: TR(with walls) -16676.000 | TT 5065.318 | TS 1000
# Episode 74 | step 100 : KL 4.627779881159465 | Loss 2199333.25 | Entropy 0.31604124704996744
# Episode 74 | step 200 : KL 4.628850452105204 | Loss 970027.375 | Entropy 0.3305614178379377
# Episode 74 | step 300 : KL 4.703736503918965 | Loss 1547729.75 | Entropy 0.34108201165994007
# Episode 74 | step 400 : KL 4.718587764104208 | Loss 1415620.75 | Entropy 0.36458377887805304
# Episode 74 | step 500 : KL 4.680143570899963 | Loss 1745153.5 | Entropy 0.37538636326789854
# Episode 74 | step 600 : KL 4.746327884991964 | Loss 3432716.5 | Entropy 0.3870503634214401
# Episode 74 | step 700 : KL 4.750478521982829 | Loss 1091659.5 | Entropy 0.4276220440864563
# Episode 74 | step 800 : KL 4.788496708869934 | Loss 1743379.125 | Entropy 0.43801103830337523
# Episode 74 | step 900 : KL 4.716093293825785 | Loss 2034126.875 | Entropy 0.4585338403781255
# Episode 74: TR(with walls) -32245.000 | TT 5156.497 | TS 968
# Episode 75 | step 100 : KL 4.69159901936849 | Loss 1887465.375 | Entropy 0.48952764173348745
# Episode 75 | step 200 : KL 4.732845624287923 | Loss 1430378.25 | Entropy 0.5107224255800247
# Episode 75 | step 300 : KL 4.701814802487691 | Loss 3423748.75 | Entropy 0.5466429303089778
# Episode 75 | step 400 : KL 4.673940841356913 | Loss 2955920.5 | Entropy 0.5653513769308726
# Episode 75 | step 500 : KL 4.658818475405375 | Loss 2590972.5 | Entropy 0.5960222860177358
# Episode 75 | step 600 : KL 4.792272790273031 | Loss 2867581.5 | Entropy 0.6132875820000966
# Episode 75 | step 700 : KL 4.621337779362997 | Loss 556270.125 | Entropy 0.6351411879062653
# Episode 75 | step 800 : KL 4.533391332626342 | Loss 1583199.375 | Entropy 0.6430170595645904
# Episode 75 | step 900 : KL 4.594255391756693 | Loss 1458451.125 | Entropy 0.6464629888534545
# Episode 75 | step 1000 : KL 4.523891512552897 | Loss 1234299.25 | Entropy 0.6602700869242351
# Episode 75: TR(without walls) -868.000 | TT 5250.390 | TS 1000
# Episode 76 | step 100 : KL 4.4799333095550535 | Loss 3350508.0 | Entropy 0.665298467874527
# Episode 76 | step 200 : KL 4.508646392822266 | Loss 2413487.0 | Entropy 0.6663447479406993
# Episode 76 | step 300 : KL 4.359962892532349 | Loss 1311579.25 | Entropy 0.6810939649740855
# Episode 76 | step 400 : KL 4.361910422643025 | Loss 2699512.5 | Entropy 0.6843015472094218
# Episode 76 | step 500 : KL 4.370583661397299 | Loss 1615096.5 | Entropy 0.691018142302831
# Episode 76 | step 600 : KL 4.2540233612060545 | Loss 2011935.375 | Entropy 0.7046898106733958
# Episode 76 | step 700 : KL 4.310752820968628 | Loss 1130898.5 | Entropy 0.6943866550922394
# Episode 76 | step 800 : KL 4.089712365468343 | Loss 1484283.75 | Entropy 0.7178067127863567
# Episode 76 | step 900 : KL 4.04469203154246 | Loss 1364899.375 | Entropy 0.7247126320997874
# Episode 76 | step 1000 : KL 4.0287647644678755 | Loss 2006080.0 | Entropy 0.7366204857826233
# Episode 76: TR(without walls) -31268.000 | TT 5344.397 | TS 1000
# Episode 77 | step 100 : KL 3.917509357134501 | Loss 1791552.5 | Entropy 0.7489752729733785
# Episode 77 | step 200 : KL 3.849143632253011 | Loss 2460217.5 | Entropy 0.7534758110841115
# Episode 77 | step 300 : KL 3.8190683841705324 | Loss 2566368.5 | Entropy 0.749496857325236
# Episode 77 | step 400 : KL 3.722821323076884 | Loss 2751284.0 | Entropy 0.7723822732766469
# Episode 77: TR(without walls) 1687.000 | TT 5386.197 | TS 445
# Episode 78 | step 100 : KL 3.5746583859125773 | Loss 1821300.5 | Entropy 0.7807166298230489
# Episode 78 | step 200 : KL 3.5377036650975544 | Loss 1992901.875 | Entropy 0.8081987341245015
# Episode 78 | step 300 : KL 3.4555322170257567 | Loss 1998342.625 | Entropy 0.8052656948566437
# Episode 78 | step 400 : KL 3.3360777457555133 | Loss 1919032.75 | Entropy 0.8619792938232422
# Episode 78 | step 500 : KL 3.223477367560069 | Loss 628425.4375 | Entropy 0.8848468840122223
# Episode 78 | step 600 : KL 3.223276893297831 | Loss 1214375.25 | Entropy 0.9046636203924815
# Episode 78 | step 700 : KL 3.010335878531138 | Loss 2255284.5 | Entropy 0.9008395592371623
# Episode 78 | step 800 : KL 3.0948317726453145 | Loss 1374017.125 | Entropy 0.9361679931481679
# Episode 78 | step 900 : KL 2.9284480651219686 | Loss 1711955.75 | Entropy 0.9939417918523152
# Episode 78 | step 1000 : KL 2.859468964735667 | Loss 1916093.875 | Entropy 1.0079905668894449
# Episode 78: TR(without walls) -47868.000 | TT 5480.441 | TS 1000
# Episode 79 | step 100 : KL 2.8743127743403116 | Loss 923455.25 | Entropy 0.9767085671424866
# Episode 79 | step 200 : KL 2.807405376434326 | Loss 935202.375 | Entropy 1.0278205394744873
# Episode 79 | step 300 : KL 2.5497758348782855 | Loss 1364295.0 | Entropy 1.0788399775822957
# Episode 79 | step 400 : KL 2.387079628308614 | Loss 1844931.375 | Entropy 1.107698631286621
# Episode 79 | step 500 : KL 2.2834093153476713 | Loss 2217827.75 | Entropy 1.1249113162358602
# Episode 79 | step 600 : KL 2.1278612673282624 | Loss 2819260.25 | Entropy 1.1543400526046752
# Episode 79 | step 700 : KL 2.2562223354975384 | Loss 2217341.25 | Entropy 1.1506420731544496
# Episode 79 | step 800 : KL 1.8566614468892415 | Loss 1379848.0 | Entropy 1.1892970124880473
# Episode 79 | step 900 : KL 1.9251129845778148 | Loss 1064129.0 | Entropy 1.2027388572692872
# Episode 79 | step 1000 : KL 1.7927207003037136 | Loss 2314141.0 | Entropy 1.213301694393158
# Episode 79: TR(with walls) -26972.000 | TT 5573.810 | TS 1000
# Episode 80 | step 100 : KL 1.8896268606185913 | Loss 716935.5625 | Entropy 1.2249317685763041
# Episode 80 | step 200 : KL 1.6115759521722794 | Loss 381419.625 | Entropy 1.2424421826998393
# Episode 80 | step 300 : KL 1.7084153552850088 | Loss 1896585.25 | Entropy 1.2855451504389446
# Episode 80 | step 400 : KL 1.4471315364042918 | Loss 1233782.125 | Entropy 1.2906876722971599
# Episode 80 | step 500 : KL 1.4917897502581279 | Loss 1532864.0 | Entropy 1.3042504111925761
# Episode 80 | step 600 : KL 1.3415922482808431 | Loss 2256910.0 | Entropy 1.3168983658154805
# Episode 80 | step 700 : KL 1.3296005686124166 | Loss 1078151.375 | Entropy 1.317121398448944
# Episode 80 | step 800 : KL 1.178587551911672 | Loss 1516583.125 | Entropy 1.3204051693280539
# Episode 80 | step 900 : KL 1.1419417162736256 | Loss 3257104.5 | Entropy 1.3418200651804606
# Episode 80 | step 1000 : KL 1.0744361807902654 | Loss 816640.9375 | Entropy 1.340293808778127
# Episode 80: TR(without walls) -869.000 | ER(with wall) -399.000 | ER(without wall) -895.400 | TT 5667.489 | WC 5732.054 | TS 1000
# Episode 81 | step 100 : KL 1.0046868751446405 | Loss 1494926.5 | Entropy 1.359219487508138
# Episode 81 | step 200 : KL 1.0021567930777868 | Loss 315131.40625 | Entropy 1.3453444123268128
# Episode 81 | step 300 : KL 1.0464099049568176 | Loss 1952857.0 | Entropy 1.3567366441090902
# Episode 81 | step 400 : KL 0.9116862306992213 | Loss 1166074.25 | Entropy 1.3425066550572713
# Episode 81 | step 500 : KL 0.9503531982501348 | Loss 1514076.5 | Entropy 1.338559583822886
# Episode 81 | step 600 : KL 0.7858763833840688 | Loss 2856410.5 | Entropy 1.333260961373647
# Episode 81 | step 700 : KL 0.8265511463085811 | Loss 781952.0625 | Entropy 1.3235827644666036
# Episode 81 | step 800 : KL 0.7626650482416153 | Loss 2340833.0 | Entropy 1.3651185711224874
# Episode 81 | step 900 : KL 0.6955159684022267 | Loss 1332267.125 | Entropy 1.347325849533081
# Episode 81 | step 1000 : KL 0.6484720384081205 | Loss 2318952.25 | Entropy 1.3457499941190083
# Episode 81: TR(with walls) -8072.000 | TT 5825.443 | TS 1000
# Episode 82 | step 100 : KL 0.613060632844766 | Loss 2658932.75 | Entropy 1.3563164750734964
# Episode 82 | step 200 : KL 0.5631245265404383 | Loss 1940684.75 | Entropy 1.3697893619537354
# Episode 82 | step 300 : KL 0.5429437756538391 | Loss 1896571.875 | Entropy 1.3679056843121846
# Episode 82 | step 400 : KL 0.49628753860791525 | Loss 1889807.5 | Entropy 1.3981380065282185
# Episode 82 | step 500 : KL 0.5030392840504646 | Loss 1893564.375 | Entropy 1.3743243892987569
# Episode 82 | step 600 : KL 0.47894461303949354 | Loss 1255414.125 | Entropy 1.378864194949468
# Episode 82 | step 700 : KL 0.4874395380417506 | Loss 2155525.25 | Entropy 1.3654400805632274
# Episode 82 | step 800 : KL 0.4367433061202367 | Loss 1146980.5 | Entropy 1.39464164574941
# Episode 82 | step 900 : KL 0.5270015428463618 | Loss 786359.5625 | Entropy 1.3236693759759268
# Episode 82 | step 1000 : KL 0.4753254257142544 | Loss 2278955.0 | Entropy 1.3492073138554892
# Episode 82: TR(without walls) -14172.000 | TT 5919.103 | TS 1000
# Episode 83 | step 100 : KL 0.46186738461256027 | Loss 790674.6875 | Entropy 1.3606662154197693
# Episode 83: TR(without walls) -10842.000 | TT 5933.868 | TS 159
# Episode 84 | step 100 : KL 0.4617776336769263 | Loss 631647.0 | Entropy 1.3525101006031037
# Episode 84 | step 200 : KL 0.4943813929955165 | Loss 1416206.125 | Entropy 1.3334865669409435
# Episode 84 | step 300 : KL 0.5081214226782322 | Loss 978495.4375 | Entropy 1.3156720022360484
# Episode 84 | step 400 : KL 0.5576649663348993 | Loss 1238703.75 | Entropy 1.2836335718631744
# Episode 84 | step 500 : KL 0.6134950826565425 | Loss 1309114.0 | Entropy 1.2435549954573313
# Episode 84 | step 600 : KL 0.5956456243991852 | Loss 1022445.75 | Entropy 1.2591998199621837
# Episode 84 | step 700 : KL 0.6177011763056119 | Loss 2330582.75 | Entropy 1.2500189860661826
# Episode 84 | step 800 : KL 0.6052141785621643 | Loss 1547614.25 | Entropy 1.2632102469603221
# Episode 84 | step 900 : KL 0.6330306018392245 | Loss 1754346.0 | Entropy 1.2398446718851726
# Episode 84 | step 1000 : KL 0.7208674594759941 | Loss 805673.75 | Entropy 1.1806462705135345
# Episode 84: TR(without walls) -36384.000 | TT 6027.730 | TS 1000
# Episode 85 | step 100 : KL 0.8143341824412346 | Loss 2194169.25 | Entropy 1.1575984994570414
# Episode 85 | step 200 : KL 0.7698746765653293 | Loss 1888024.75 | Entropy 1.157238115866979
# Episode 85 | step 300 : KL 0.9299918790658315 | Loss 2531696.0 | Entropy 1.0693818519512812
# Episode 85: TR(without walls) 1730.000 | TT 6064.507 | TS 392
# Episode 86 | step 100 : KL 0.9780865589777629 | Loss 1340053.125 | Entropy 1.0593492736419041
# Episode 86 | step 200 : KL 1.0035307010014851 | Loss 2228005.25 | Entropy 1.0420056144396463
# Episode 86 | step 300 : KL 0.8547839393218358 | Loss 585558.3125 | Entropy 1.1207530538241068
# Episode 86 | step 400 : KL 0.9474377002567053 | Loss 1221516.875 | Entropy 1.0797634840011596
# Episode 86 | step 500 : KL 0.9645039244244497 | Loss 3471641.75 | Entropy 1.0953248997529348
# Episode 86 | step 600 : KL 0.9920152535041173 | Loss 1445603.875 | Entropy 1.087307329972585
# Episode 86 | step 700 : KL 1.070297689239184 | Loss 1621373.875 | Entropy 1.040858049194018
# Episode 86 | step 800 : KL 0.9661190082629522 | Loss 2525424.25 | Entropy 1.106280694405238
# Episode 86 | step 900 : KL 0.8557844857374827 | Loss 2009612.75 | Entropy 1.1566500941912332
# Episode 86 | step 1000 : KL 0.8043364693721136 | Loss 2633130.0 | Entropy 1.2096012711524964
# Episode 86: TR(with walls) -19481.000 | TT 6158.124 | TS 1000
# Episode 87 | step 100 : KL 0.7404240717490514 | Loss 2471083.75 | Entropy 1.2263711035251617
# Episode 87 | step 200 : KL 0.6673447281122208 | Loss 1139339.0 | Entropy 1.2755845268567403
# Episode 87 | step 300 : KL 0.6546259368459384 | Loss 1477319.875 | Entropy 1.2791490654150646
# Episode 87 | step 400 : KL 0.6263744833568732 | Loss 1207132.5 | Entropy 1.2866196910540262
# Episode 87 | step 500 : KL 0.558361837764581 | Loss 1095963.625 | Entropy 1.3232368191083272
# Episode 87 | step 600 : KL 0.48478037044405936 | Loss 1136224.0 | Entropy 1.3560782194137573
# Episode 87 | step 700 : KL 0.45923634270826974 | Loss 1685160.125 | Entropy 1.3726504226525624
# Episode 87 | step 800 : KL 0.4432890139520168 | Loss 562352.5 | Entropy 1.3742512782414755
# Episode 87 | step 900 : KL 0.44157529771327975 | Loss 1018631.75 | Entropy 1.36600657304128
# Episode 87 | step 1000 : KL 0.4223535905281703 | Loss 3012802.75 | Entropy 1.3688911537329356
# Episode 87: TR(with walls) -44967.000 | TT 6251.580 | TS 1000
# Episode 88 | step 100 : KL 0.3148781771461169 | Loss 1465418.0 | Entropy 1.4284947693347931
# Episode 88 | step 200 : KL 0.26769423310955365 | Loss 686717.75 | Entropy 1.4508914669354758
# Episode 88 | step 300 : KL 0.22560881556322177 | Loss 2102835.75 | Entropy 1.4755831559499104
# Episode 88 | step 400 : KL 0.17951370648418863 | Loss 2604423.0 | Entropy 1.5098065495491029
# Episode 88 | step 500 : KL 0.23831530970831713 | Loss 1802037.75 | Entropy 1.4586510101954142
# Episode 88 | step 600 : KL 0.19006734453141688 | Loss 2197176.5 | Entropy 1.4945150713125865
# Episode 88 | step 700 : KL 0.40446084265907606 | Loss 984121.1875 | Entropy 1.3431515246629715
# Episode 88 | step 800 : KL 0.3764717191457748 | Loss 1237083.375 | Entropy 1.3456502695878347
# Episode 88 | step 900 : KL 0.3908229110141595 | Loss 1073107.125 | Entropy 1.3353346546490987
# Episode 88 | step 1000 : KL 0.48829564998547237 | Loss 1221921.125 | Entropy 1.272675875822703
# Episode 88: TR(without walls) -14068.000 | TT 6345.655 | TS 1000
# Episode 89 | step 100 : KL 0.5758524646361669 | Loss 1544791.125 | Entropy 1.245554498831431
# Episode 89 | step 200 : KL 0.9033557534217834 | Loss 1308776.375 | Entropy 1.061508223414421
# Episode 89 | step 300 : KL 0.956661599377791 | Loss 1276211.0 | Entropy 1.0359034836292267
# Episode 89 | step 400 : KL 1.1324133535226186 | Loss 3170699.75 | Entropy 0.9411949627101421
# Episode 89 | step 500 : KL 1.275144319732984 | Loss 506939.71875 | Entropy 0.9252712622284889
# Episode 89 | step 600 : KL 1.6565256476402284 | Loss 1417013.0 | Entropy 0.7297284938395023
# Episode 89 | step 700 : KL 1.9544727702935536 | Loss 517219.6875 | Entropy 0.5857724913706382
# Episode 89 | step 800 : KL 2.2764272967974346 | Loss 1864266.375 | Entropy 0.493581917633613
# Episode 89 | step 900 : KL 2.6180696288744607 | Loss 1192180.75 | Entropy 0.36938078788419565
# Episode 89 | step 1000 : KL 3.0199238618214923 | Loss 1868402.75 | Entropy 0.3077591116229693
# Episode 89: TR(with walls) -17268.000 | TT 6439.346 | TS 1000
# Episode 90 | step 100 : KL 3.2947245438893638 | Loss 1460534.5 | Entropy 0.2432321241746346
# ...
# Episode 484: TR(without walls) -972.000 | TT 62692.607 | TS 1000
# Episode 485 | step 100 : KL 51.22352930704753 | Loss 791542.1875 | Entropy 3.9846163262270576e-16
# Episode 485 | step 200 : KL 51.6086981455485 | Loss 1774083.625 | Entropy 6.842034431543545e-16
# Episode 485 | step 300 : KL 50.807881927490236 | Loss 764928.75 | Entropy 1.948832685972203e-15
# Episode 485 | step 400 : KL 50.9782211303711 | Loss 83053.1796875 | Entropy 1.117839151092592e-15
# Episode 485 | step 500 : KL 50.632754770914715 | Loss 356360.8125 | Entropy 2.5542465613080508e-15
# Episode 485 | step 600 : KL 50.50320638020833 | Loss 399860.5 | Entropy 1.2616239850446214e-15
# Episode 485 | step 700 : KL 50.28622169494629 | Loss 2279087.75 | Entropy 2.8901902157055202e-15
# Episode 485 | step 800 : KL 49.40133476257324 | Loss 1256549.5 | Entropy 7.155534290858933e-15
# Episode 485 | step 900 : KL 49.74608612060547 | Loss 603345.0 | Entropy 3.806449337920021e-15
# Episode 485 | step 1000 : KL 49.39739176432292 | Loss 1131971.875 | Entropy 2.0011428200341745e-15
# Episode 485: TR(without walls) -868.000 | TT 62866.180 | TS 1000
# Episode 486 | step 100 : KL 51.29059549967448 | Loss 506859.0 | Entropy 8.84152747519097e-17
# Episode 486 | step 200 : KL 50.55621185302734 | Loss 885768.875 | Entropy 8.743264551050508e-17
# Episode 486 | step 300 : KL 51.850476328531904 | Loss 880548.625 | Entropy 2.4173428347870027e-17
# Episode 486 | step 400 : KL 50.31701876322428 | Loss 877866.6875 | Entropy 3.8584717096059993e-16
# Episode 486 | step 500 : KL 50.788106028238936 | Loss 241880.796875 | Entropy 1.7328730637517869e-16
# Episode 486 | step 600 : KL 51.23956782023112 | Loss 378728.09375 | Entropy 6.988205922290823e-17
# Episode 486 | step 700 : KL 51.60847206115723 | Loss 358436.21875 | Entropy 3.407493634323201e-17
# Episode 486 | step 800 : KL 51.84750200907389 | Loss 247006.25 | Entropy 4.3609062987033174e-17
# Episode 486 | step 900 : KL 50.47078234354655 | Loss 286923.46875 | Entropy 4.170835772287221e-17
# Episode 486 | step 1000 : KL 52.326388931274415 | Loss 1166535.125 | Entropy 6.2137231466960315e-18
# Episode 486: TR(with walls) -876.000 | TT 63038.313 | TS 1000
# Episode 487 | step 100 : KL 53.21722882588704 | Loss 248008.125 | Entropy 4.754072433688311e-18
# Episode 487 | step 200 : KL 52.823309834798174 | Loss 594903.9375 | Entropy 7.296352117177944e-18
# Episode 487 | step 300 : KL 55.45295384724935 | Loss 119498.234375 | Entropy 9.90481339767897e-19
# Episode 487 | step 400 : KL 55.66843427022298 | Loss 650987.0625 | Entropy 1.0765910276707685e-18
# Episode 487 | step 500 : KL 55.28930422465007 | Loss 222058.75 | Entropy 7.162862086474137e-18
# Episode 487 | step 600 : KL 55.29968744913737 | Loss 1185432.875 | Entropy 2.8007565038898267e-18
# Episode 487 | step 700 : KL 55.25402704874674 | Loss 109314.09375 | Entropy 2.7813407936825075e-18
# Episode 487 | step 800 : KL 55.02025032043457 | Loss 730015.625 | Entropy 3.685290640090957e-18
# Episode 487 | step 900 : KL 54.22891693115234 | Loss 1486366.0 | Entropy 7.643510672517234e-18
# Episode 487 | step 1000 : KL 54.55591405232747 | Loss 218260.75 | Entropy 4.203893877244656e-18
# Episode 487: TR(without walls) -871.000 | TT 63210.543 | TS 1000
# Episode 488 | step 100 : KL 54.788761138916016 | Loss 486914.375 | Entropy 3.1476618087882635e-18
# Episode 488 | step 200 : KL 55.198913955688475 | Loss 510580.15625 | Entropy 3.1407265398019457e-18
# Episode 488 | step 300 : KL 55.07087313334147 | Loss 391574.5625 | Entropy 3.500440240525022e-18
# Episode 488 | step 400 : KL 55.06936887105306 | Loss 868002.875 | Entropy 4.4659569872275825e-18
# Episode 488 | step 500 : KL 55.00377426147461 | Loss 1087104.375 | Entropy 4.3537397396095175e-18
# Episode 488 | step 600 : KL 55.836795043945315 | Loss 1442229.0 | Entropy 2.9812175002066607e-18
# Episode 488 | step 700 : KL 55.285980987548825 | Loss 47653.5 | Entropy 2.1181464440262904e-18
# Episode 488 | step 800 : KL 57.215871556599936 | Loss 184961.25 | Entropy 2.8811609907542477e-18
# Episode 488 | step 900 : KL 57.10520184834798 | Loss 1353242.0 | Entropy 2.6808043392977193e-18
# Episode 488 | step 1000 : KL 55.643333180745444 | Loss 847030.3125 | Entropy 1.8263945503336354e-18
# Episode 488: TR(without walls) -868.000 | TT 63386.153 | TS 1000
# Episode 489 | step 100 : KL 56.28762232462565 | Loss 812026.3125 | Entropy 1.717452771579879e-17
# Episode 489 | step 200 : KL 54.11029879252116 | Loss 703952.25 | Entropy 1.346311808542569e-16
# Episode 489 | step 300 : KL 56.13037452697754 | Loss 1487605.625 | Entropy 2.130405383077865e-17
# Episode 489 | step 400 : KL 56.28619918823242 | Loss 84928.6640625 | Entropy 4.490249441506195e-18
# Episode 489 | step 500 : KL 56.42471516927083 | Loss 1215821.875 | Entropy 1.6506983686802936e-20
# Episode 489 | step 600 : KL 57.15197957356771 | Loss 1201558.375 | Entropy 6.78596126266279e-20
# Episode 489 | step 700 : KL 57.9082748413086 | Loss 570349.375 | Entropy 1.215441584776226e-18
# Episode 489 | step 800 : KL 57.6877690633138 | Loss 250124.5625 | Entropy 2.5209179413498633e-18
# Episode 489 | step 900 : KL 56.22737032572429 | Loss 569204.1875 | Entropy 1.341882050172245e-17
# Episode 489 | step 1000 : KL 57.874349212646486 | Loss 774792.625 | Entropy 1.5683463319887913e-18
# Episode 489: TR(with walls) -996.000 | TT 63530.046 | TS 1000
# Episode 490 | step 100 : KL 58.101463063557944 | Loss 319986.1875 | Entropy 2.1728078583358076e-21
# Episode 490 | step 200 : KL 56.57006607055664 | Loss 694729.125 | Entropy 5.544050863552479e-18
# Episode 490 | step 300 : KL 57.777205022176105 | Loss 80173.796875 | Entropy 5.41716481956856e-19
# Episode 490 | step 400 : KL 56.888020833333336 | Loss 643638.25 | Entropy 2.7814471509461614e-21
# Episode 490 | step 500 : KL 57.30332667032878 | Loss 1294928.0 | Entropy 7.704143000854511e-19
# Episode 490 | step 600 : KL 56.54976234436035 | Loss 654884.3125 | Entropy 2.842307885639651e-18
# Episode 490 | step 700 : KL 57.542413965861 | Loss 306127.625 | Entropy 1.609771701813788e-18
# Episode 490 | step 800 : KL 57.79477361043294 | Loss 119491.484375 | Entropy 9.58953953450216e-19
# Episode 490 | step 900 : KL 57.04796854654948 | Loss 1251256.75 | Entropy 1.1108346496633023e-21
# Episode 490 | step 1000 : KL 56.618414306640624 | Loss 110983.4453125 | Entropy 1.4643015721232806e-18
# Episode 490: TR(with walls) -868.000 | TT 63645.779 | TS 1000
# Episode 491 | step 100 : KL 55.57137959798177 | Loss 50530.12890625 | Entropy 1.6549708673498467e-18
# Episode 491 | step 200 : KL 55.97636884053548 | Loss 142559.203125 | Entropy 8.770458398092495e-19
# Episode 491 | step 300 : KL 55.59983825683594 | Loss 469420.9375 | Entropy 9.287130643116015e-19
# Episode 491 | step 400 : KL 55.57960586547851 | Loss 847065.625 | Entropy 7.733866834384994e-19
# Episode 491 | step 500 : KL 55.418320973714195 | Loss 454274.46875 | Entropy 7.16501570846262e-19
# Episode 491 | step 600 : KL 55.40862833658854 | Loss 968785.4375 | Entropy 4.736087004842201e-19
# Episode 491 | step 700 : KL 55.50559933980306 | Loss 305685.875 | Entropy 3.35892938735121e-19
# Episode 491 | step 800 : KL 55.76971308390299 | Loss 395714.78125 | Entropy 3.0754207644089246e-19
# Episode 491 | step 900 : KL 56.21828994750977 | Loss 636329.75 | Entropy 1.9675674524859427e-19
# Episode 491 | step 1000 : KL 55.63062782287598 | Loss 350238.15625 | Entropy 1.4108671960465016e-19
# Episode 491: TR(without walls) -972.000 | TT 63762.143 | TS 1000
# Episode 492 | step 100 : KL 56.7171334584554 | Loss 347031.03125 | Entropy 4.974018144041255e-20
# Episode 492 | step 200 : KL 56.135162099202475 | Loss 234444.078125 | Entropy 5.2741904316612226e-20
# Episode 492 | step 300 : KL 56.28787409464518 | Loss 428207.90625 | Entropy 4.331796684321392e-20
# Episode 492 | step 400 : KL 57.17849464416504 | Loss 404351.21875 | Entropy 2.743221759371694e-20
# Episode 492 | step 500 : KL 57.33303349812825 | Loss 1355201.5 | Entropy 2.6427946888915367e-20
# Episode 492 | step 600 : KL 56.44475758870443 | Loss 389287.71875 | Entropy 2.6639418302056918e-20
# Episode 492 | step 700 : KL 56.70815900166829 | Loss 414764.1875 | Entropy 2.5138796187737054e-20
# Episode 492 | step 800 : KL 55.178243764241536 | Loss 124585.7734375 | Entropy 4.5429280246858536e-20
# Episode 492 | step 900 : KL 56.01317672729492 | Loss 46575.97265625 | Entropy 3.0347783622506397e-20
# Episode 492 | step 1000 : KL 56.018090438842776 | Loss 1056896.75 | Entropy 2.3234864250683208e-20
# Episode 492: TR(with walls) -881.000 | TT 63886.931 | TS 1000
# Episode 493 | step 100 : KL 55.85249252319336 | Loss 424547.5625 | Entropy 2.2862329723097313e-20
# Episode 493 | step 200 : KL 55.548162206014 | Loss 577235.6875 | Entropy 3.722674422439729e-20
# Episode 493 | step 300 : KL 55.876939137776695 | Loss 704368.0625 | Entropy 2.5750451925467204e-20
# Episode 493 | step 400 : KL 55.95377731323242 | Loss 49715.14453125 | Entropy 2.4195043725858935e-20
# Episode 493 | step 500 : KL 55.730255635579425 | Loss 118283.2578125 | Entropy 3.543539252880823e-20
# Episode 493 | step 600 : KL 55.9640858968099 | Loss 921692.25 | Entropy 2.9623440207661106e-20
# Episode 493 | step 700 : KL 55.878348159790036 | Loss 1070917.75 | Entropy 4.184182837421221e-20
# Episode 493 | step 800 : KL 55.89961179097494 | Loss 891650.1875 | Entropy 4.2001918592694704e-20
# Episode 493 | step 900 : KL 55.4344118754069 | Loss 57997.25 | Entropy 2.0753894618509648e-19
# Episode 493 | step 1000 : KL 55.38065071105957 | Loss 737868.3125 | Entropy 7.210648103076919e-20
# Episode 493: TR(without walls) -868.000 | TT 64009.303 | TS 1000
# Episode 494 | step 100 : KL 54.99329732259115 | Loss 1449712.375 | Entropy 1.452258753342165e-19
# Episode 494 | step 200 : KL 55.390571212768556 | Loss 381622.0 | Entropy 1.5730630993117485e-19
# Episode 494 | step 300 : KL 54.63109842936198 | Loss 1041828.25 | Entropy 8.026918356085019e-19
# Episode 494 | step 400 : KL 54.506123606363936 | Loss 860929.4375 | Entropy 1.1251673145090969e-18
# Episode 494 | step 500 : KL 53.98200200398763 | Loss 1048194.5625 | Entropy 5.7582816025797306e-18
# Episode 494 | step 600 : KL 53.58392130533854 | Loss 1809489.25 | Entropy 1.933010233026064e-18
# Episode 494 | step 700 : KL 53.497863133748375 | Loss 803152.1875 | Entropy 4.018021177576931e-18
# Episode 494 | step 800 : KL 52.56212959289551 | Loss 1095206.875 | Entropy 2.4801274883581244e-17
# Episode 494 | step 900 : KL 52.08549041748047 | Loss 346877.53125 | Entropy 1.125254614614042e-16
# Episode 494 | step 1000 : KL 52.46641858418783 | Loss 172906.96875 | Entropy 8.037265657085807e-17
# Episode 494: TR(with walls) -987.000 | TT 64128.930 | TS 1000
# Episode 495 | step 100 : KL 51.92048136393229 | Loss 438992.0 | Entropy 1.4020922679590405e-16
# Episode 495 | step 200 : KL 51.728118387858075 | Loss 669972.8125 | Entropy 3.9593327812498714e-16
# Episode 495 | step 300 : KL 51.81912740071615 | Loss 229587.828125 | Entropy 1.2125813838320294e-16
# Episode 495 | step 400 : KL 50.568320719401044 | Loss 805832.5625 | Entropy 3.4618531910812517e-16
# Episode 495 | step 500 : KL 50.88098996480306 | Loss 648810.8125 | Entropy 2.1392888733016864e-16
# Episode 495 | step 600 : KL 50.17513516743978 | Loss 455004.5625 | Entropy 3.397944550985843e-16
# Episode 495 | step 700 : KL 51.35568021138509 | Loss 249123.359375 | Entropy 1.116759563868141e-16
# Episode 495 | step 800 : KL 50.87768948872884 | Loss 1107536.25 | Entropy 2.9835279873382874e-16
# Episode 495 | step 900 : KL 50.132865524291994 | Loss 159993.6875 | Entropy 3.8008696876638157e-16
# Episode 495 | step 1000 : KL 49.760620498657225 | Loss 445391.375 | Entropy 1.0733329920743672e-15
# Episode 495: TR(with walls) -981.000 | TT 64247.674 | TS 1000
# Episode 496 | step 100 : KL 49.03977139790853 | Loss 1789029.375 | Entropy 1.7429166386160356e-15
# Episode 496 | step 200 : KL 49.60524024963379 | Loss 334954.0 | Entropy 2.1867324699663065e-15
# Episode 496 | step 300 : KL 49.61969172159831 | Loss 837249.375 | Entropy 1.6827087587766376e-15
# Episode 496 | step 400 : KL 50.616969935099284 | Loss 1602914.375 | Entropy 4.2015260016278456e-16
# Episode 496 | step 500 : KL 49.413225428263345 | Loss 505275.125 | Entropy 1.1513141925607322e-15
# Episode 496 | step 600 : KL 49.02512092590332 | Loss 1323270.25 | Entropy 2.5379420195854355e-15
# Episode 496 | step 700 : KL 48.24245885213216 | Loss 1097849.625 | Entropy 1.3049575413211149e-15
# Episode 496 | step 800 : KL 48.59281374613444 | Loss 135023.890625 | Entropy 3.520380800775578e-15
# Episode 496 | step 900 : KL 48.67979456583659 | Loss 2211165.0 | Entropy 1.2032891604820944e-15
# Episode 496 | step 1000 : KL 49.49401715596517 | Loss 1447515.75 | Entropy 1.0358587430543644e-15
# Episode 496: TR(with walls) -980.000 | TT 64366.227 | TS 1000
# Episode 497 | step 100 : KL 48.63947347005208 | Loss 536748.8125 | Entropy 1.3906277387705892e-15
# Episode 497 | step 200 : KL 47.63011906941732 | Loss 1228011.25 | Entropy 5.1112518582696116e-15
# Episode 497 | step 300 : KL 47.60111300150553 | Loss 1017690.625 | Entropy 2.8160189786702863e-15
# Episode 497 | step 400 : KL 47.08761316935222 | Loss 638575.25 | Entropy 7.196107647735152e-15
# Episode 497 | step 500 : KL 46.63692092895508 | Loss 852407.875 | Entropy 8.005447266790196e-15
# Episode 497 | step 600 : KL 46.96682993570963 | Loss 922647.5 | Entropy 2.7322796612287518e-15
# Episode 497 | step 700 : KL 47.52093989054362 | Loss 216506.53125 | Entropy 1.907398457633429e-15
# Episode 497 | step 800 : KL 47.26891822814942 | Loss 130639.5546875 | Entropy 2.5331720451982898e-15
# Episode 497 | step 900 : KL 46.56778729756673 | Loss 161636.8125 | Entropy 4.7916442575975406e-15
# Episode 497 | step 1000 : KL 47.33752670288086 | Loss 741734.8125 | Entropy 3.438238334484205e-15
# Episode 497: TR(with walls) -871.000 | TT 64483.997 | TS 1000
# Episode 498 | step 100 : KL 46.46759770711263 | Loss 1297998.875 | Entropy 7.069963639228391e-15
# Episode 498 | step 200 : KL 46.44538904825846 | Loss 909336.0 | Entropy 7.0732841955956725e-15
# Episode 498 | step 300 : KL 46.307194010416666 | Loss 771573.6875 | Entropy 7.770335470493662e-15
# Episode 498 | step 400 : KL 45.83704783121745 | Loss 241536.140625 | Entropy 1.025974879654041e-14
# Episode 498 | step 500 : KL 46.72020441691081 | Loss 101819.3671875 | Entropy 4.275339842639116e-15
# Episode 498 | step 600 : KL 46.05853856404622 | Loss 407928.9375 | Entropy 8.580853872414365e-15
# Episode 498 | step 700 : KL 45.42376708984375 | Loss 195355.765625 | Entropy 1.4108573749891565e-14
# Episode 498 | step 800 : KL 45.38969167073568 | Loss 629889.375 | Entropy 1.3421399048608347e-14
# Episode 498 | step 900 : KL 45.400173314412434 | Loss 1648117.625 | Entropy 1.2311224843347975e-14
# Episode 498 | step 1000 : KL 45.15007057189941 | Loss 557967.75 | Entropy 1.4046082391028721e-14
# Episode 498: TR(without walls) -868.000 | TT 64598.815 | TS 1000
# Episode 499 | step 100 : KL 45.64285138448079 | Loss 83968.40625 | Entropy 4.236421199853688e-15
# Episode 499 | step 200 : KL 45.010798645019534 | Loss 1218990.375 | Entropy 1.3434360110094973e-14
# Episode 499 | step 300 : KL 44.79527918497721 | Loss 263865.34375 | Entropy 1.5059429507441006e-14
# Episode 499 | step 400 : KL 45.173547236124676 | Loss 268043.0 | Entropy 4.1323018539572665e-15
# Episode 499 | step 500 : KL 44.224012247721355 | Loss 1477961.625 | Entropy 2.1462424626412552e-14
# Episode 499 | step 600 : KL 45.06542828877767 | Loss 426613.59375 | Entropy 8.567434551905242e-15
# Episode 499 | step 700 : KL 44.390541076660156 | Loss 786104.6875 | Entropy 2.4334405680295373e-14
# Episode 499 | step 800 : KL 44.55901832580567 | Loss 433684.40625 | Entropy 2.3766400562252706e-14
# Episode 499 | step 900 : KL 45.3325745900472 | Loss 1248544.5 | Entropy 1.2415965139725369e-14
# Episode 499 | step 1000 : KL 44.39005610148112 | Loss 2275487.75 | Entropy 1.409381153101816e-14
# Episode 499: TR(without walls) -868.000 | TT 64713.515 | TS 1000
# Episode 500 | step 100 : KL 44.552789052327476 | Loss 1062264.125 | Entropy 1.269775425012892e-14
# Episode 500 | step 200 : KL 44.768506622314455 | Loss 568144.3125 | Entropy 1.0172737153520972e-14
# Episode 500: TR(with walls) 1876.000 | ER(with wall) -420.800 | ER(without wall) -909.600 | TT 64742.649 | WC 64830.319 | TS 255

# %%
results = {
    "train_rewards": kdTrainRewardList,
    "train_time": kdTrainTimeList,
    "eval_rewards_env1": kdEvalRewardsList1,
    "eval_rewards_env2": kdEvalRewardsList2,
    "wall_clock_time": kdWallClockTimeList,
    "total_steps": kdTotalStepsList,
    "kl": klList,
    "entropy": entropyList,
    "loss": lossList
}

save_path = f"{config['model_path']}/kd_results1.pt"
torch.save(results, save_path)

print(f"Saved results to {save_path}")
# Out:
# Saved results to ../model_weights/model_weights_eval_kd1/kd_results1.pt

# %%
import matplotlib.pyplot as plt
import numpy as np

episodes = np.arange(1, len(kdTrainRewardList) + 1)

fig, axes = plt.subplots(3, 1, figsize=(12, 15))

# Global style tuning
title_size = 15
label_size = 15
tick_size = 15

# Training Reward
axes[0].plot(episodes, kdTrainRewardList, linewidth=2)
axes[0].set_title("Training Reward vs Episode", fontsize=title_size)
axes[0].set_xlabel("Episode", fontsize=label_size)
axes[0].set_ylabel("Reward", fontsize=label_size)
axes[0].tick_params(axis='both', labelsize=tick_size)
axes[0].grid(alpha=0.3)

# Total Steps
axes[1].plot(episodes, kdTotalStepsList, linewidth=2)
axes[1].set_title("Total Steps per Episode", fontsize=title_size)
axes[1].set_xlabel("Episode", fontsize=label_size)
axes[1].set_ylabel("Steps", fontsize=label_size)
axes[1].tick_params(axis='both', labelsize=tick_size)
axes[1].grid(alpha=0.3)

# Training Time
axes[2].plot(episodes, kdTrainTimeList, linewidth=2)
axes[2].set_title("Training Time vs Episode", fontsize=title_size)
axes[2].set_xlabel("Episode", fontsize=label_size)
axes[2].set_ylabel("Time (s)", fontsize=label_size)
axes[2].tick_params(axis='both', labelsize=tick_size)
axes[2].grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
eval_episodes = np.arange(20, 20 * len(kdEvalRewardsList1) + 1, 20)

fig, axes = plt.subplots(2, 1, figsize=(12, 15))

# Evaluation Rewards
axes[0].plot(eval_episodes, kdEvalRewardsList1, linewidth=2, label="With Walls")
axes[0].plot(eval_episodes, kdEvalRewardsList2, linewidth=2, label="Without Walls")
axes[0].set_title("Evaluation Rewards", fontsize=title_size)
axes[0].set_xlabel("Episode", fontsize=label_size)
axes[0].set_ylabel("Reward", fontsize=label_size)
axes[0].tick_params(axis='both', labelsize=tick_size)
axes[0].legend(fontsize=12)
axes[0].grid(alpha=0.3)
axes[0].margins(y=0.1)

# Wall Clock Time
axes[1].plot(eval_episodes, kdWallClockTimeList, linewidth=2)
axes[1].set_title("Wall Clock Time", fontsize=title_size)
axes[1].set_xlabel("Episode", fontsize=label_size)
axes[1].set_ylabel("Time (s)", fontsize=label_size)
axes[1].tick_params(axis='both', labelsize=tick_size)
axes[1].grid(alpha=0.3)
axes[1].margins(y=0.1)

plt.subplots_adjust(hspace=0.35)
plt.tight_layout()
plt.show()

# %%
def smooth(data, window=50):
    return np.convolve(data, np.ones(window)/window, mode='valid')

fig, axes = plt.subplots(3, 1, figsize=(12, 15))

# KL
axes[0].plot(smooth(klList), linewidth=2)
axes[0].set_title("KL Divergence (Smoothed)", fontsize=title_size)
axes[0].set_xlabel("Training Step", fontsize=label_size)
axes[0].set_ylabel("KL", fontsize=label_size)
axes[0].tick_params(axis='both', labelsize=tick_size)
axes[0].grid(alpha=0.3)
axes[0].margins(y=0.1)

# Entropy
axes[1].plot(smooth(entropyList), linewidth=2)
axes[1].set_title("Entropy (Smoothed)", fontsize=title_size)
axes[1].set_xlabel("Training Step", fontsize=label_size)
axes[1].set_ylabel("Entropy", fontsize=label_size)
axes[1].tick_params(axis='both', labelsize=tick_size)
axes[1].grid(alpha=0.3)
axes[1].margins(y=0.1)

# Loss
axes[2].plot(smooth(lossList), linewidth=2)
axes[2].set_title("Loss (Smoothed)", fontsize=title_size)
axes[2].set_xlabel("Training Step", fontsize=label_size)
axes[2].set_ylabel("Loss", fontsize=label_size)
axes[2].tick_params(axis='both', labelsize=tick_size)
axes[2].grid(alpha=0.3)
axes[2].margins(y=0.1)

plt.subplots_adjust(hspace=0.35)
plt.tight_layout()
plt.show()
